# %% [markdown]
# <a href="https://colab.research.google.com/github/anoop954/3rdSemProject/blob/31-may/Text_to_CSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f9290a9b-5b2d-455c-a351-9260d07db7a6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f9290a9b-5b2d-455c-a351-9260d07db7a6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Analysis.txt to Analysis.txt

# %%
#fd

# %%
file_name = "Analysis.txt"
uploaded[file_name].decode("utf-8")
data = uploaded[file_name].decode("utf-8").split("\n")

# %%
data
# Out:
# ['Frame No:1\r',
#  'boxes:[730, 803, 47, 57]\tname:eset iceerl _bikkyl \\leskle-\tScore:neutral:69.0\r',
#  'boxes:[295, 783, 50, 62]\tname:4 NiteshAfahari\tScore:sad:43.0\r',
#  'boxes:[1146, 127, 52, 63]\tname:aseivris eanal\tScore:sad:43.0\r',
#  'boxes:[1161, 288, 68, 79]\tname:HARSH SHARMA\tScore:neutral:80.0\r',
#  'boxes:[88, 621, 57, 70]\tname:032 Harsch Rai\tScore:neutral:79.0\r',
#  'boxes:[1791, 142, 39, 50]\tname:Shyam is Flare 102 >\tScore:neutral:92.0\r',
#  'boxes:[932, 480, 44, 53]\tname:Shrivast BStrelst ls alll TVa\tScore:neutral:65.0\r',
#  'boxes:[303, 150, 49, 62]\tname:Pooja Yadav\tScore:neutral:66.0\r',
#  'boxes:[1376, 303, 44, 55]\tname:Tat-t-34 Kumar 078\tScore:neutral:81.0\r',
#  'boxes:[928, 274, 77, 99]\tname:Kumar Amit |\tScore:neutral:76.0\r',
#  'boxes:[725, 134, 58, 74]\tname:NAVNITA KLIMARI,\tScore:neutral:78.0\r',
#  'boxes:[506, 644, 71, 86]\tname:Gupta Sonu | 104\tScore:sad:42.0\r',
#  'boxes:[1576, 618, 46, 59]\tname:Meena mey.i0) Neetu.\tScore:neutral:46.0\r',
#  'boxes:[529, 511, 38, 49]\tname:Nitesh kum\tScore:happy:57.99999999999999\r',
#  'boxes:[929, 129, 44, 50]\tname:Oeihalisteiaetiiee rao\tScore:angry:45.0\r',
#  'boxes:[114, 312, 41, 51]\tname:jel eisell elat: Mehta Mehta\tScore:neutral:49.0\r',
#  'boxes:[83, 807, 57, 74]\tname:Neeraj Fels;\tScore:neutral:68.0\r',
#  'boxes:[1785, 819, 39, 45]\tname:[@istitielscin Sarita foy-.\tScore:neutral:52.0\r',
#  'boxes:[1771, 477, 58, 71]\tname:Manich alles t-| om ney-tc\tScore:neutral:82.0\r',
#  'boxes:[1557, 318, 73, 92]\tname:lalelal o18 AMKI\tScore:happy:59.0\r',
#  'boxes:[116, 98, 63, 78]\tname:st Barnabas st Barnabas\tScore:happy:97.0\r',
#  'boxes:[1366, 822, 52, 63]\tname:Amar 012 Sarkan\tScore:neutral:53.0\r',
#  'boxes:[1368, 457, 35, 44]\tname:\tScore:neutral:93.0\r',
#  'boxes:[1138, 786, 75, 98]\tname:Ruchi Panse\tScore:happy:36.0\r',
#  'boxes:[1372, 983, 45, 52]\tname:\tScore:neutral:65.0\r',
#  'boxes:[1577, 468, 50, 62]\tname:Nandsani SF cele\tScore:neutral:53.0\r',
#  "boxes:[1581, 129, 53, 64]\tname:a'e-tateistelal rey-te) kumar th\tScore:neutral:53.0\r",
#  'boxes:[1775, 275, 46, 54]\tname:\tScore:sad:28.000000000000004\r',
#  'boxes:[717, 289, 72, 92]\tname:1) Garg Simran |\tScore:neutral:69.0\r',
#  'boxes:[783, 963, 51, 62]\tname:@ite ieisitia iva\tScore:happy:55.00000000000001\r',
#  'boxes:[521, 159, 39, 48]\tname:[Sie Sagar 086\tScore:happy:48.0\r',
#  'boxes:[518, 809, 42, 51]\tname:1 Singh Sharam. 098\tScore:neutral:70.0\r',
#  'boxes:[1792, 660, 42, 50]\tname:Raja\tScore:sad:49.0\r',
#  'boxes:[1150, 650, 30, 37]\tname:"laste ween Aditya foley\tScore:fear:35.0\r',
#  'Frame No:2\r',
#  'boxes:[730, 803, 47, 57]\tname:eset iceerl _bikkyl \\leskle-\tScore:neutral:69.0\r',
#  'boxes:[295, 783, 50, 62]\tname:4 NiteshwAfahari\tScore:sad:43.0\r',
#  'boxes:[1146, 127, 52, 63]\tname:aseivris eanal\tScore:sad:42.0\r',
#  'boxes:[1161, 288, 68, 79]\tname:HARSH SHARMA\tScore:neutral:80.0\r',
#  'boxes:[88, 621, 57, 70]\tname:032 Harch Rai\tScore:neutral:79.0\r',
#  'boxes:[1791, 143, 39, 49]\tname:Shukis Shvam 10?\tScore:neutral:89.0\r',
#  'boxes:[303, 150, 49, 62]\tname:Pooja Yadav\tScore:neutral:67.0\r',
#  'boxes:[1376, 303, 44, 55]\tname:Tat-t-34 Kumar 078\tScore:neutral:81.0\r',
#  'boxes:[928, 274, 77, 99]\tname:Kumar Amit |\tScore:neutral:76.0\r',
#  'boxes:[725, 134, 58, 74]\tname:NAVNITA KLIMARI,\tScore:neutral:78.0\r',
#  'boxes:[1576, 618, 46, 59]\tname:Meena mey.i0) Neetu.\tScore:neutral:46.0\r',
#  'boxes:[529, 511, 38, 49]\tname:Nitesh kum\tScore:happy:59.0\r',
#  'boxes:[505, 643, 72, 88]\tname:|Gupta Sonu 104\tScore:fear:48.0\r',
#  'boxes:[114, 312, 41, 51]\tname:jel eisell elat: Mehta Mehta\tScore:neutral:49.0\r',
#  'boxes:[83, 807, 57, 74]\tname:Neeraj Fels;\tScore:neutral:68.0\r',
#  'boxes:[1771, 477, 58, 71]\tname:Manich ney-t: alles t-| om\tScore:neutral:82.0\r',
#  'boxes:[1785, 819, 39, 45]\tname:[@istitielscin Sarita foy-.\tScore:neutral:52.0\r',
#  'boxes:[116, 98, 63, 78]\tname:st Barnabas st Barnabas\tScore:happy:97.0\r',
#  'boxes:[1366, 822, 52, 63]\tname:Amar 012 Sarkan\tScore:neutral:53.0\r',
#  'boxes:[1368, 457, 35, 44]\tname:\tScore:neutral:93.0\r',
#  'boxes:[1557, 317, 74, 91]\tname:Telelal 018 AKI\tScore:happy:45.0\r',
#  'boxes:[931, 128, 42, 49]\tname:eltattsseiseliiee rao\tScore:angry:33.0\r',
#  'boxes:[1138, 786, 75, 98]\tname:Ruchi Panse\tScore:happy:39.0\r',
#  'boxes:[1372, 983, 45, 52]\tname:\tScore:neutral:65.0\r',
#  'boxes:[1577, 468, 50, 62]\tname:NanGsani St cele\tScore:neutral:53.0\r',
#  'boxes:[932, 481, 45, 54]\tname:SudhSnshu ) Shrivastova |\tScore:neutral:56.99999999999999\r',
#  "boxes:[1581, 129, 53, 64]\tname:a'e-tateistelal rey-te) kumar th.\tScore:neutral:53.0\r",
#  'boxes:[717, 289, 72, 92]\tname:1) Garg Simran |\tScore:neutral:71.0\r',
#  'boxes:[1775, 275, 46, 54]\tname:\tScore:sad:28.000000000000004\r',
#  'boxes:[784, 962, 49, 63]\tname:Gite, lelisitia riva\tScore:happy:57.99999999999999\r',
#  'boxes:[522, 158, 38, 50]\tname:Sagar [Chie 086\tScore:happy:59.0\r',
#  'boxes:[518, 809, 42, 51]\tname:1 Singh Sharam. 098\tScore:neutral:70.0\r',
#  'boxes:[1792, 660, 42, 50]\tname:Raja\tScore:sad:49.0\r',
#  'boxes:[1150, 650, 30, 37]\tname:"laste ween Aditya foley\tScore:fear:34.0\r',
#  'Frame No:3\r',
#  'boxes:[295, 783, 50, 62]\tname:4 NiteshwAfahari\tScore:sad:42.0\r',
#  'boxes:[1146, 127, 52, 63]\tname:aseivris eanal\tScore:sad:42.0\r',
#  'boxes:[88, 621, 57, 70]\tname:032 Harch Rai\tScore:neutral:79.0\r',
#  'boxes:[731, 801, 46, 58]\tname:_ bikkyl Yoaser-ines- a bvedleerl:\tScore:neutral:47.0\r',
#  'boxes:[1791, 141, 39, 51]\tname:Shvam Shukla 102 Yo\tScore:neutral:91.0\r',
#  'boxes:[1375, 302, 45, 56]\tname:ola t-34 Kumar 078\tScore:neutral:88.0\r',
#  'boxes:[303, 150, 49, 62]\tname:Pooja Yadav\tScore:neutral:67.0\r',
#  'boxes:[1557, 318, 75, 92]\tname:018 Singh AMKI\tScore:happy:51.0\r',
#  'boxes:[725, 135, 59, 73]\tname:KLMARI NAVNITA.\tScore:neutral:81.0\r',
#  'boxes:[1366, 822, 52, 62]\tname:Sarkar Amar 012\tScore:neutral:59.0\r',
#  'boxes:[929, 276, 74, 97]\tname:Kumar Amit\tScore:neutral:72.0\r',
#  'boxes:[529, 511, 38, 49]\tname:Nitesh kum\tScore:happy:59.0\r',
#  'boxes:[505, 643, 72, 88]\tname:| Gupta Sonu 104\tScore:fear:48.0\r',
#  'boxes:[1166, 291, 64, 78]\tname:SHARMA HARSH\tScore:neutral:76.0\r',
#  'boxes:[114, 312, 41, 51]\tname:jel eisell elat: Mehta Mehta\tScore:neutral:49.0\r',
#  'boxes:[83, 807, 57, 74]\tname:Neeraj Fels;\tScore:neutral:68.0\r',
#  'boxes:[1771, 477, 58, 71]\tname:Manich 048 alles t-| om\tScore:neutral:82.0\r',
#  'boxes:[1785, 819, 39, 45]\tname:[@istitielscin Sarita foy-.\tScore:neutral:52.0\r',
#  'boxes:[116, 98, 63, 78]\tname:st Barnabas st Barnabas\tScore:happy:97.0\r',
#  'boxes:[1368, 457, 36, 45]\tname:\tScore:neutral:89.0\r',
#  'boxes:[931, 128, 42, 48]\tname:irao -purushottama r\tScore:angry:37.0\r',
#  'boxes:[1138, 786, 75, 98]\tname:Ruchi Panse\tScore:happy:39.0\r',
#  'boxes:[1372, 983, 45, 52]\tname:\tScore:neutral:65.0\r',
#  'boxes:[1577, 468, 50, 62]\tname:NanGsani St cele\tScore:neutral:53.0\r',
#  'boxes:[932, 481, 45, 54]\tname:SudhSnshu ) Shrivastova |\tScore:neutral:56.99999999999999\r',
#  'boxes:[717, 289, 72, 92]\tname:1) Garg Simran |\tScore:neutral:69.0\r',
#  'boxes:[1775, 275, 47, 55]\tname:\tScore:happy:28.999999999999996\r',
#  'boxes:[1581, 620, 41, 56]\tname:i Meena  melon ) Neetu |\tScore:neutral:44.0\r',
#  'boxes:[784, 962, 50, 63]\tname:@ite Velsltla iva\tScore:happy:56.99999999999999\r',
#  'boxes:[521, 159, 40, 49]\tname:Sagar [Cltleir: 086\tScore:happy:61.0\r',
#  'boxes:[1580, 128, 54, 69]\tname:-kanchan kumar erie) th\tScore:angry:42.0\r',
#  'boxes:[518, 809, 42, 51]\tname:1 Singh Sharam. 098\tScore:neutral:70.0\r',
#  'boxes:[1792, 660, 42, 50]\tname:Raja\tScore:sad:49.0\r',
#  'boxes:[1150, 649, 30, 38]\tname:y Velie) Kumar Soni reley.\tScore:fear:36.0\r',
#  'Frame No:4\r',
#  'boxes:[295, 783, 50, 62]\tname:4 NiteshwAfahari\tScore:sad:42.0\r',
#  'boxes:[1146, 127, 52, 63]\tname:aseivris eanal\tScore:sad:42.0\r',
#  'boxes:[88, 621, 57, 70]\tname:032 Harch Rai\tScore:neutral:79.0\r',
#  'boxes:[1791, 143, 38, 49]\tname:Shukis Shvam 10?\tScore:neutral:89.0\r',
#  'boxes:[731, 801, 46, 58]\tname:_bikkyl lace laee a atleehy\tScore:neutral:48.0\r',
#  'boxes:[1375, 302, 45, 56]\tname:ola t-34 Kumar 078\tScore:neutral:88.0\r',
#  'boxes:[1557, 318, 75, 92]\tname:018 Singh AMKI\tScore:happy:52.0\r',
#  'boxes:[303, 150, 49, 62]\tname:Pooja Yadav\tScore:neutral:67.0\r',
#  'boxes:[725, 135, 59, 73]\tname:KLMARI NAVNITA.\tScore:neutral:81.0\r',
#  'boxes:[1366, 822, 52, 62]\tname:Sarkar Amar 012\tScore:neutral:59.0\r',
#  'boxes:[113, 312, 42, 50]\tname:jelaisell elated Mehta Mehta\tScore:angry:37.0\r',
#  'boxes:[1772, 477, 57, 71]\tname:Manich 048 alles t-| om\tScore:neutral:83.0\r',
#  'boxes:[929, 279, 73, 95]\tname:m40lesteial Amit K\tScore:neutral:56.99999999999999\r',
#  'boxes:[505, 643, 72, 88]\tname:| Gupta Sonu 104\tScore:fear:48.0\r',
#  'boxes:[1166, 291, 64, 78]\tname:SHARMA HARSH\tScore:neutral:75.0\r',
#  'boxes:[83, 807, 57, 74]\tname:Neeraj Fels;\tScore:neutral:68.0\r',
#  'boxes:[1785, 819, 39, 45]\tname:[@istitielscin Sarita foy-.\tScore:neutral:52.0\r',
#  'boxes:[116, 98, 63, 78]\tname:st Barnabas st Barnabas\tScore:happy:97.0\r',
#  'boxes:[529, 511, 38, 49]\tname:Nitesh kum\tScore:happy:56.99999999999999\r',
#  'boxes:[1368, 457, 36, 45]\tname:\tScore:neutral:89.0\r',
#  'boxes:[931, 128, 42, 48]\tname:irao -purushottama r\tScore:angry:37.0\r',
#  'boxes:[1138, 786, 75, 98]\tname:Ruchi Panse\tScore:happy:39.0\r',
#  'boxes:[1372, 983, 45, 52]\tname:\tScore:neutral:65.0\r',
#  'boxes:[1577, 468, 50, 62]\tname:NanGsani St cele\tScore:neutral:53.0\r',
#  'boxes:[932, 481, 45, 54]\tname:SudhSnshu ) Shrivastova |\tScore:neutral:56.99999999999999\r',
#  'boxes:[717, 289, 72, 92]\tname:1) Garg Simran |\tScore:neutral:70.0\r',
#  'boxes:[1775, 275, 47, 55]\tname:\tScore:happy:28.999999999999996\r',
#  'boxes:[1581, 620, 41, 56]\tname:i Meena  melon ) Neetu |\tScore:neutral:44.0\r',
#  'boxes:[784, 962, 50, 63]\tname:@ite Velsltla iva\tScore:happy:56.99999999999999\r',
#  'boxes:[522, 158, 38, 48]\tname:Cities iSlerid 086\tScore:happy:54.0\r',
#  'boxes:[518, 809, 43, 52]\tname:Singh Shivam 098\tScore:neutral:64.0\r',
#  'boxes:[1580, 128, 54, 69]\tname:-kanchan kumar erie) th\tScore:angry:43.0\r',
#  'boxes:[1792, 660, 42, 50]\tname:Raja\tScore:sad:49.0\r',
#  'boxes:[1150, 649, 30, 38]\tname:y Velie) Kumar Soni reley.\tScore:fear:36.0\r',
#  'Frame No:5\r',
#  'boxes:[295, 783, 50, 62]\tname:4 NiteshwAfahari\tScore:sad:42.0\r',
#  'boxes:[88, 621, 57, 70]\tname:032 Harch Rai\tScore:neutral:79.0\r',
#  'boxes:[1162, 288, 67, 78]\tname:HARSH CUIAPMA\tScore:neutral:72.0\r',
#  'boxes:[1791, 143, 38, 49]\tname:Shukis Shvam 10?\tScore:neutral:89.0\r',
#  'boxes:[731, 801, 46, 58]\tname:_bikkyl facste-laee- ia adleehry\tScore:neutral:48.0\r',
#  'boxes:[726, 135, 58, 74]\tname:rrAVs\\ing-@ KLMARI\tScore:neutral:88.0\r',
#  'boxes:[1375, 302, 45, 56]\tname:ola t-34 Kumar 078\tScore:neutral:88.0\r',
#  'boxes:[303, 150, 49, 62]\tname:Pooja Yadav\tScore:neutral:67.0\r',
#  'boxes:[1558, 319, 74, 90]\tname:Singh 018 ATTK)\tScore:happy:53.0\r',
#  'boxes:[1366, 822, 52, 62]\tname:Sarkar Amar 012\tScore:neutral:59.0\r',
#  'boxes:[113, 312, 42, 50]\tname:jelaisell elated Mehta Mehta\tScore:angry:37.0\r',
#  'boxes:[1772, 477, 57, 71]\tname:Manich 048 alles t-| om\tScore:neutral:83.0\r',
#  'boxes:[929, 279, 73, 95]\tname:a 4tlesteial Amit K\tScore:neutral:56.99999999999999\r',
#  'boxes:[83, 807, 57, 74]\tname:Neeraj Fels;\tScore:neutral:68.0\r',
#  'boxes:[1785, 819, 39, 45]\tname:[@istitielscin Sarita foy-.\tScore:neutral:52.0\r',
#  'boxes:[116, 98, 63, 78]\tname:st Barnabas st Barnabas\tScore:happy:97.0\r',
#  'boxes:[529, 511, 38, 49]\tname:Nitesh kum\tScore:happy:56.99999999999999\r',
#  'boxes:[1368, 457, 35, 44]\tname:\tScore:neutral:93.0\r',
#  'boxes:[503, 642, 74, 89]\tname:Gupta Sonu | 104\tScore:fear:36.0\r',
#  'boxes:[1138, 785, 77, 99]\tname:Ruchi Panse\tScore:happy:33.0\r',
#  'boxes:[931, 128, 42, 48]\tname:irao -purushottama r\tScore:angry:37.0\r',
#  'boxes:[1372, 983, 45, 52]\tname:\tScore:neutral:65.0\r',
#  'boxes:[932, 481, 45, 54]\tname:SudhSnshu ) Shrivastova |\tScore:neutral:56.99999999999999\r',
#  'boxes:[717, 289, 72, 92]\tname:1) Garg Simran |\tScore:neutral:70.0\r',
#  'boxes:[1148, 128, 50, 65]\tname:Kumawat Kainal\tScore:sad:42.0\r',
#  'boxes:[1775, 275, 47, 55]\tname:\tScore:happy:27.0\r',
#  'boxes:[1578, 470, 50, 61]\tname:Nan@ani Shz\tScore:neutral:68.0\r',
#  'boxes:[1581, 620, 41, 56]\tname:i Meena  melon ) Neetu |\tScore:neutral:44.0\r',
#  'boxes:[784, 962, 50, 63]\tname:@ite Velsltla iva\tScore:happy:56.00000000000001\r',
#  'boxes:[522, 158, 38, 48]\tname:Cities ilerid 086\tScore:happy:53.0\r',
#  'boxes:[518, 809, 43, 52]\tname:Singh Shivam 098\tScore:neutral:64.0\r',
#  'boxes:[1580, 128, 54, 69]\tname:-kanchan kumar erie) th\tScore:angry:43.0\r',
#  'boxes:[1792, 660, 42, 50]\tname:Raja\tScore:sad:49.0\r',
#  'boxes:[1150, 649, 30, 38]\tname:y Velie) Kumar Soni reley.\tScore:fear:36.0\r',
#  'Frame No:6\r',
#  'boxes:[932, 278, 72, 97]\tname:Kumar\tScore:neutral:61.0\r',
#  'boxes:[88, 621, 57, 70]\tname:032 Harch Rai\tScore:neutral:79.0\r',
#  'boxes:[1162, 288, 67, 78]\tname:HARSH CUIAPMA\tScore:neutral:71.0\r',
#  'boxes:[295, 783, 50, 63]\tname:mele Nifeewestshari\tScore:sad:38.0\r',
#  'boxes:[1791, 143, 38, 49]\tname:Shukla Shvam 10?\tScore:neutral:88.0\r',
#  'boxes:[1377, 304, 43, 54]\tname:tis = 738 Kumar Kumar\tScore:neutral:79.0\r',
#  'boxes:[731, 801, 46, 58]\tname:_bikkyl facste-laee- ia adleehry\tScore:neutral:48.0\r',
#  'boxes:[726, 135, 58, 74]\tname:rrAVs\\ing-@ KLMARI\tScore:neutral:89.0\r',
#  'boxes:[303, 150, 49, 62]\tname:Pooja Yadav\tScore:neutral:67.0\r',
#  'boxes:[1366, 822, 52, 61]\tname:Sarkar Amar 012\tScore:neutral:90.0\r',
#  'boxes:[113, 312, 42, 50]\tname:jelaisell elated Mehta Mehta\tScore:angry:37.0\r',
#  'boxes:[1772, 477, 57, 71]\tname:Manich 048 alles t-| om\tScore:neutral:83.0\r',
#  'boxes:[83, 807, 57, 74]\tname:Neeraj Fels;\tScore:neutral:68.0\r',
#  'boxes:[1785, 819, 39, 45]\tname:[@istitielscin Sarita foy-.\tScore:neutral:52.0\r',
#  'boxes:[116, 98, 63, 78]\tname:st Barnabas st Barnabas\tScore:happy:97.0\r',
#  'boxes:[1557, 318, 74, 92]\tname:o18 mS lalelal AQIKI\tScore:happy:74.0\r',
#  'boxes:[529, 511, 38, 49]\tname:Nitesh kum\tScore:happy:56.99999999999999\r',
#  'boxes:[1368, 457, 36, 45]\tname:\tScore:neutral:88.0\r',
#  'boxes:[503, 642, 74, 89]\tname:Gupta Sonu | 104\tScore:sad:37.0\r',
#  'boxes:[1138, 785, 77, 99]\tname:Ruchi Panse\tScore:happy:32.0\r',
#  'boxes:[931, 128, 42, 48]\tname:irao -purushottama r\tScore:angry:37.0\r',
#  'boxes:[1372, 983, 45, 52]\tname:\tScore:neutral:65.0\r',
#  'boxes:[932, 481, 45, 54]\tname:SudhSnshu ) Shrivastova |\tScore:neutral:56.99999999999999\r',
#  'boxes:[717, 289, 72, 92]\tname:1) Garg Simran |\tScore:neutral:69.0\r',
#  'boxes:[1148, 128, 50, 65]\tname:Kumawat Kainal\tScore:sad:42.0\r',
#  'boxes:[1578, 470, 50, 61]\tname:Nandani Shz\tScore:neutral:68.0\r',
#  'boxes:[1774, 274, 48, 57]\tname:\tScore:sad:32.0\r',
#  'boxes:[784, 964, 50, 61]\tname:Gite, lelsitia iva\tScore:happy:56.99999999999999\r',
#  'boxes:[518, 809, 43, 52]\tname:Singh Shivam 098\tScore:neutral:64.0\r',
#  'boxes:[1578, 618, 44, 59]\tname:Meena Neetu! mey-0)\tScore:neutral:51.0\r',
#  'boxes:[1580, 128, 54, 69]\tname:-kanchan kumar erie) th\tScore:angry:43.0\r',
#  'boxes:[522, 157, 38, 48]\tname:[Citiei = Siecle 086\tScore:happy:28.000000000000004\r',
#  'boxes:[1792, 660, 42, 50]\tname:Raja\tScore:sad:49.0\r',
#  'boxes:[1149, 648, 30, 40]\tname:Kumar Soni Seley Aditya\tScore:sad:35.0\r',
#  'Frame No:7\r',
#  'boxes:[89, 621, 56, 69]\tname:032 Harsh Rai\tScore:neutral:79.0\r',
#  'boxes:[932, 277, 75, 97]\tname:Amit Miumar\tScore:neutral:74.0\r',
#  'boxes:[1162, 288, 67, 78]\tname:HARSH CUIAPMA\tScore:neutral:71.0\r',
#  'boxes:[113, 312, 43, 51]\tname:jer ecisell eilat: Mehta Mehta\tScore:neutral:59.0\r',
#  'boxes:[295, 783, 50, 63]\tname:mele Nifeewestshari\tScore:sad:40.0\r',
#  'boxes:[1377, 304, 43, 55]\tname:Tl t-34 Kumar 078\tScore:neutral:81.0\r',
#  'boxes:[1791, 143, 38, 49]\tname:Shukla Shvam 10?\tScore:neutral:88.0\r',
#  'boxes:[731, 801, 47, 58]\tname:Be tay leerleesericern\tScore:neutral:59.0\r',
#  'boxes:[726, 135, 58, 74]\tname:rrAVs\\ing-@ KLMARI\tScore:neutral:88.0\r',
#  'boxes:[303, 150, 49, 62]\tname:Pooja Yadav\tScore:neutral:67.0\r',
#  'boxes:[83, 807, 57, 74]\tname:Neeraj Fels;\tScore:neutral:68.0\r',
#  'boxes:[1772, 477, 57, 71]\tname:Manich 048 alles | am\tScore:neutral:82.0\r',
#  'boxes:[1785, 819, 39, 45]\tname:[@istitielscin Sarita foy-.\tScore:neutral:52.0\r',
#  'boxes:[1367, 822, 51, 62]\tname:Sarkar Amar. 012\tScore:neutral:61.0\r',
#  'boxes:[116, 98, 63, 78]\tname:st Barnabas st Barnabas\tScore:happy:97.0\r',
#  'boxes:[1557, 318, 74, 92]\tname:o18 om lalelal AQIKI\tScore:happy:74.0\r',
#  'boxes:[529, 511, 38, 49]\tname:Nitesh kum\tScore:happy:56.99999999999999\r',
#  'boxes:[1368, 457, 36, 45]\tname:\tScore:neutral:88.0\r',
#  'boxes:[501, 640, 74, 92]\tname:Gupta Sonu Sey!\tScore:fear:35.0\r',
#  'boxes:[1138, 785, 77, 99]\tname:Ruchi Panse\tScore:happy:32.0\r',
#  'boxes:[931, 128, 42, 48]\tname:irao -purushottama r\tScore:angry:37.0\r',
#  'boxes:[1372, 983, 45, 52]\tname:\tScore:neutral:65.0\r',
#  'boxes:[1582, 129, 52, 65]\tname:"et ateistelal rey-te) kumar th.\tScore:neutral:37.0\r',
#  'boxes:[932, 481, 45, 54]\tname:SudhSnshu ) Shrivastova |\tScore:neutral:56.99999999999999\r',
#  'boxes:[717, 289, 72, 92]\tname:1) Garg Simran |\tScore:neutral:69.0\r',
#  'boxes:[1775, 274, 47, 57]\tname:\tScore:sad:32.0\r',
#  'boxes:[1148, 128, 50, 65]\tname:Kumawat Kainal\tScore:sad:42.0\r',
#  'boxes:[1578, 470, 50, 61]\tname:Nandani Shz\tScore:neutral:68.0\r',
#  'boxes:[784, 964, 50, 61]\tname:Gite, leisitia iva\tScore:happy:57.99999999999999\r',
#  'boxes:[518, 809, 43, 52]\tname:Singh Shivam 098\tScore:neutral:64.0\r',
#  'boxes:[1578, 618, 44, 59]\tname:Meena Neetu! mey-0)\tScore:neutral:51.0\r',
#  'boxes:[522, 157, 38, 48]\tname:[Citiei = Siecle 086\tScore:happy:27.0\r',
#  'boxes:[1792, 660, 42, 50]\tname:Raja\tScore:sad:49.0\r',
#  'boxes:[1149, 648, 30, 40]\tname:Kumar Soni Seley Aditya\tScore:sad:35.0\r',
#  'Frame No:8\r',
#  'boxes:[89, 621, 56, 69]\tname:032 Harsh Rai\tScore:neutral:79.0\r',
#  'boxes:[932, 277, 75, 97]\tname:Amit Miumar\tScore:neutral:74.0\r',
#  'boxes:[113, 312, 43, 51]\tname:jer ecisell eilat: Mehta Mehta\tScore:neutral:60.0\r',
#  'boxes:[295, 783, 50, 63]\tname:mele Nifeewestshari\tScore:sad:40.0\r',
#  'boxes:[1377, 304, 43, 55]\tname:Tl t-34 Kumar 078\tScore:neutral:81.0\r',
#  'boxes:[731, 801, 47, 58]\tname:Be tay llesllaeseriaerch\tScore:neutral:59.0\r',
#  'boxes:[1791, 141, 39, 51]\tname:Shvam Shukis 102\tScore:neutral:92.0\r',
#  'boxes:[726, 135, 58, 74]\tname:rrAVs\\ing-@ KLMARI\tScore:neutral:88.0\r',
#  'boxes:[303, 150, 49, 62]\tname:Pooja Yadav\tScore:neutral:67.0\r',
#  'boxes:[1368, 457, 35, 45]\tname:\tScore:neutral:88.0\r',
#  'boxes:[1786, 819, 38, 45]\tname:Chaudhary "Sarita 044\tScore:neutral:40.0\r',
#  'boxes:[83, 807, 57, 74]\tname:Neeraj Fels;\tScore:neutral:68.0\r',
#  'boxes:[1772, 477, 57, 71]\tname:Manich 048 alles | am\tScore:neutral:82.0\r',
#  'boxes:[1367, 822, 51, 62]\tname:Sarkar Amar. 012\tScore:neutral:61.0\r',
#  'boxes:[116, 98, 63, 78]\tname:st Barnabas st Barnabas\tScore:happy:97.0\r',
#  'boxes:[1167, 291, 63, 76]\tname:SHARMA LARSL\tScore:neutral:77.0\r',
#  'boxes:[1557, 318, 74, 92]\tname:o18 om lalelal AQIKI\tScore:happy:74.0\r',
#  'boxes:[529, 511, 38, 49]\tname:Nitesh kum\tScore:happy:56.99999999999999\r',
#  'boxes:[501, 640, 74, 93]\tname:Sonu Gupta 104\tScore:sad:39.0\r',
#  'boxes:[931, 128, 42, 48]\tname:irao -purushottama r\tScore:angry:37.0\r',
#  'boxes:[1372, 983, 45, 52]\tname:\tScore:neutral:65.0\r',
#  'boxes:[1138, 786, 75, 98]\tname:Ruchi Panse\tScore:happy:37.0\r',
#  'boxes:[1582, 129, 52, 65]\tname:"et ateistelal rey-te) kumar th.\tScore:neutral:37.0\r',
#  'boxes:[523, 157, 37, 47]\tname:SHleris Che 086\tScore:happy:32.0\r',
#  'boxes:[717, 290, 72, 91]\tname:Garg Thaales ial\tScore:neutral:63.0\r',
#  'boxes:[1775, 274, 47, 57]\tname:\tScore:sad:33.0\r',
#  'boxes:[1148, 128, 50, 65]\tname:Kumawat Kainal\tScore:sad:42.0\r',
#  'boxes:[1578, 470, 50, 61]\tname:Nandani Shz\tScore:neutral:68.0\r',
#  'boxes:[933, 480, 44, 55]\tname:Sudh4nshu Shrivastava\tScore:neutral:65.0\r',
#  'boxes:[784, 964, 50, 61]\tname:Gite, leisitia iva\tScore:happy:57.99999999999999\r',
#  'boxes:[1578, 618, 44, 59]\tname:Meena Neetu! mey-0)\tScore:neutral:51.0\r',
#  'boxes:[519, 809, 43, 51]\tname:Shrram )Singh 098\tScore:neutral:63.0\r',
#  'boxes:[1792, 660, 42, 50]\tname:Raja\tScore:sad:49.0\r',
#  'boxes:[1149, 648, 30, 40]\tname:Kumar Soni Seley Aditya\tScore:sad:35.0\r',
#  'Frame No:9\r',
#  'boxes:[90, 622, 55, 68]\tname:032 Harsh Rai\tScore:neutral:80.0\r',
#  'boxes:[113, 312, 43, 51]\tname:jel aisell elal: Mehta Mehta\tScore:neutral:60.0\r',
#  'boxes:[295, 783, 50, 63]\tname:mele Nifeewestshari\tScore:sad:40.0\r',
#  'boxes:[1377, 304, 43, 55]\tname:Tl t-34 Kumar 078\tScore:neutral:81.0\r',
#  'boxes:[932, 277, 75, 100]\tname:Amit Kumar\tScore:neutral:69.0\r',
#  'boxes:[1791, 144, 38, 48]\tname:Shyam Shukla 102 vo\tScore:neutral:87.0\r',
#  'boxes:[731, 801, 47, 58]\tname:Be tay leslaeseriaeerch\tScore:neutral:59.0\r',
#  'boxes:[726, 135, 58, 73]\tname:NAVNITA | KIIMARI\tScore:neutral:77.0\r',
#  'boxes:[1575, 619, 47, 59]\tname:1 Meena Rey.10) _Neetu\tScore:neutral:55.00000000000001\r',
#  'boxes:[1367, 824, 49, 60]\tname:Amar Sarkan 012\tScore:neutral:53.0\r',
#  'boxes:[303, 150, 49, 62]\tname:Pooja Yadav\tScore:neutral:67.0\r',
#  'boxes:[1368, 457, 35, 45]\tname:\tScore:neutral:88.0\r',
#  'boxes:[1786, 819, 38, 45]\tname:Chaudhary "Sarita 044\tScore:neutral:41.0\r',
#  'boxes:[83, 807, 57, 74]\tname:Neeraj Fels;\tScore:neutral:68.0\r',
#  'boxes:[1772, 477, 57, 71]\tname:Manich 048 alles | am\tScore:neutral:82.0\r',
#  'boxes:[116, 98, 63, 78]\tname:st Barnabas st Barnabas\tScore:happy:97.0\r',
#  'boxes:[1167, 291, 63, 76]\tname:SHARMA LARSL\tScore:neutral:77.0\r',
#  'boxes:[1557, 318, 74, 92]\tname:o18 om lalelal AQIKI\tScore:happy:74.0\r',
#  'boxes:[501, 640, 74, 93]\tname:Sonu Gupta 104\tScore:sad:39.0\r',
#  'boxes:[529, 511, 39, 49]\tname:Nitesh kum\tScore:happy:60.0\r',
#  'boxes:[1138, 785, 77, 100]\tname:Ruchi | Panse\tScore:happy:45.0\r',
#  'boxes:[1372, 983, 45, 52]\tname:\tScore:neutral:65.0\r',
#  'boxes:[1582, 129, 52, 65]\tname:"et ateistelal rey-te) kumar th.\tScore:neutral:37.0\r',
#  'boxes:[930, 128, 43, 49]\tname:oetllaltisteiaetiie ns rao\tScore:angry:32.0\r',
#  'boxes:[522, 157, 38, 46]\tname:Che Sagar 086\tScore:happy:43.0\r',
#  'boxes:[717, 290, 72, 91]\tname:Garg Thaales ial\tScore:neutral:63.0\r',
#  'boxes:[1775, 276, 47, 56]\tname:\tScore:happy:33.0\r',
#  'boxes:[1148, 128, 50, 65]\tname:Kumawat Kainal\tScore:sad:42.0\r',
#  'boxes:[933, 480, 44, 55]\tname:Sudh4nshu_ Shrivastava\tScore:neutral:66.0\r',
#  'boxes:[1577, 470, 50, 60]\tname:Nandsni St hah\tScore:neutral:70.0\r',
#  'boxes:[784, 964, 50, 61]\tname:Gite, leisitia iva\tScore:happy:62.0\r',
#  'boxes:[1149, 650, 30, 38]\tname:Kumar feley-a Aditya Teta]\tScore:fear:33.0\r',
#  'boxes:[519, 809, 43, 51]\tname:Shrram )Singh 098\tScore:neutral:61.0\r',
#  'boxes:[1792, 660, 42, 50]\tname:Raja\tScore:sad:49.0\r',
#  'Frame No:10\r',
#  'boxes:[90, 622, 55, 68]\tname:032 Harsh Rai\tScore:neutral:80.0\r',
#  'boxes:[933, 279, 75, 94]\tname:Kumar Amit\tScore:neutral:76.0\r',
#  'boxes:[113, 312, 43, 51]\tname:jel aisell elal: Mehta Mehta\tScore:neutral:60.0\r',
#  'boxes:[1376, 304, 44, 55]\tname:Tl t-34 Kumar 078\tScore:neutral:80.0\r',
#  'boxes:[295, 783, 51, 62]\tname:mely 9 4 NitstwAfahari\tScore:sad:46.0\r',
#  'boxes:[731, 801, 47, 58]\tname:Be tay lleslaeseriaerchn\tScore:neutral:59.0\r',
#  'boxes:[1791, 141, 39, 51]\tname:Shvam Shukis 102\tScore:neutral:93.0\r',
#  'boxes:[726, 135, 58, 73]\tname:NAVNITA | KIIMARI\tScore:neutral:76.0\r',
#  'boxes:[1575, 619, 47, 59]\tname:1 Meena Rey.10) _Neetu\tScore:neutral:55.00000000000001\r',
#  'boxes:[1367, 824, 49, 60]\tname:Amar Sarkan 012\tScore:neutral:54.0\r',
#  'boxes:[303, 150, 49, 62]\tname:Pooja Yadav\tScore:neutral:67.0\r',
#  'boxes:[1368, 457, 35, 45]\tname:\tScore:neutral:88.0\r',
#  'boxes:[1786, 819, 38, 45]\tname:Chaudhary "Sarita 044\tScore:neutral:41.0\r',
#  'boxes:[83, 807, 57, 74]\tname:Neeraj Fels;\tScore:neutral:68.0\r',
#  'boxes:[1772, 477, 57, 71]\tname:Manich 048 alles | am\tScore:neutral:82.0\r',
#  'boxes:[1167, 291, 63, 76]\tname:SHARMA LARSL\tScore:neutral:78.0\r',
#  'boxes:[116, 98, 63, 78]\tname:st Barnabas st Barnabas\tScore:happy:97.0\r',
#  'boxes:[1559, 319, 73, 90]\tname:otislelal o18 ,\tScore:happy:61.0\r',
#  'boxes:[500, 641, 74, 92]\tname:Sonu Gupta 104\tScore:angry:30.0\r',
#  'boxes:[529, 511, 39, 49]\tname:Nitesh kum\tScore:happy:60.0\r',
#  'boxes:[1775, 276, 47, 57]\tname:\tScore:sad:28.999999999999996\r',
#  'boxes:[1138, 785, 77, 100]\tname:Ruchi | Panse\tScore:happy:45.0\r',
#  'boxes:[1372, 983, 45, 52]\tname:\tScore:neutral:65.0\r',
#  'boxes:[1582, 129, 51, 65]\tname:kanchan kumar rer-te th...\tScore:neutral:42.0\r',
#  'boxes:[930, 128, 43, 49]\tname:oetllaltisteiaetiie ns rao\tScore:angry:33.0\r',
#  'boxes:[1148, 127, 50, 66]\tname:Kumawat Runal\tScore:sad:39.0\r',
#  'boxes:[717, 290, 72, 91]\tname:Garg Thaales ial\tScore:neutral:63.0\r',
#  'boxes:[1577, 469, 50, 61]\tname:Ve 2S oe\tScore:neutral:70.0\r',
#  'boxes:[933, 480, 44, 55]\tname:Sudh4nshu Shrivastava\tScore:neutral:66.0\r',
#  'boxes:[1149, 650, 30, 38]\tname:Kumar feley-a Aditya Teta]\tScore:fear:33.0\r',
#  'boxes:[784, 964, 50, 61]\tname:@ite, lelsitia iva\tScore:happy:67.0\r',
#  'boxes:[522, 155, 37, 49]\tname:Chet Sagar (O}s{.)\tScore:happy:70.0\r',
#  'boxes:[1792, 660, 42, 50]\tname:Raja\tScore:sad:49.0\r',
#  'boxes:[519, 809, 43, 52]\tname:1 Singh Sham. 098\tScore:neutral:63.0\r',
#  'Frame No:11\r',
#  'boxes:[90, 622, 55, 68]\tname:032 Harsh Rai\tScore:neutral:80.0\r',
#  'boxes:[113, 312, 43, 51]\tname:jel aisell elal: Mehta Mehta\tScore:neutral:60.0\r',
#  'boxes:[932, 277, 75, 100]\tname:7 \\eslia Kumar\tScore:neutral:70.0\r',
#  'boxes:[1376, 304, 44, 55]\tname:Tl t-34 Kumar 078\tScore:neutral:79.0\r',
#  'boxes:[295, 783, 51, 62]\tname:mely 9 4 NitstwAfahari\tScore:sad:46.0\r',
#  'boxes:[731, 801, 47, 58]\tname:Be tay lleslaeseriaerchn\tScore:neutral:59.0\r',
#  'boxes:[1791, 141, 39, 51]\tname:Shvam Shukis 102\tScore:neutral:93.0\r',
#  'boxes:[726, 135, 58, 73]\tname:NAVNITA | KIIMARI\tScore:neutral:77.0\r',
#  'boxes:[1575, 619, 47, 59]\tname:1 Meena Rey.10) _Neetu\tScore:neutral:55.00000000000001\r',
#  'boxes:[1367, 824, 49, 60]\tname:Amar Sarkan 012\tScore:neutral:53.0\r',
#  'boxes:[1368, 457, 35, 45]\tname:\tScore:neutral:88.0\r',
#  'boxes:[1772, 476, 57, 72]\tname:Manich 048 loirmear\tScore:neutral:73.0\r',
#  'boxes:[1786, 819, 38, 45]\tname:Chaudhary "Sarita 044\tScore:neutral:41.0\r',
#  'boxes:[83, 807, 57, 74]\tname:Neeraj Fels;\tScore:neutral:68.0\r',
#  'boxes:[116, 98, 63, 78]\tname:st Barnabas st Barnabas\tScore:happy:97.0\r',
#  'boxes:[1559, 319, 73, 90]\tname:otislelal o18 ,\tScore:happy:62.0\r',
#  'boxes:[500, 641, 74, 92]\tname:Sonu Gupta 104\tScore:angry:30.0\r',
#  'boxes:[1162, 288, 65, 79]\tname:HARSH SHARMA\tScore:neutral:76.0\r',
#  'boxes:[529, 511, 39, 49]\tname:Nitesh kum\tScore:happy:61.0\r',
#  'boxes:[303, 149, 49, 63]\tname:Pooja Yadav\tScore:neutral:61.0\r',
#  'boxes:[1775, 276, 47, 57]\tname:\tScore:happy:28.000000000000004\r',
#  'boxes:[933, 482, 44, 54]\tname:Shrivaet  SodhSnchu TV3\tScore:neutral:42.0\r',
#  'boxes:[1137, 787, 76, 97]\tname:-Ruchi Panse\tScore:happy:38.0\r',
#  'boxes:[1372, 983, 45, 52]\tname:\tScore:neutral:65.0\r',
#  'boxes:[930, 128, 43, 49]\tname:oetllaltisteiaetiie ns rao\tScore:angry:33.0\r',
#  'boxes:[1148, 127, 50, 66]\tname:Kumawat Runal\tScore:sad:39.0\r',
#  'boxes:[717, 290, 72, 91]\tname:Garg Thaales ial\tScore:neutral:59.0\r',
#  'boxes:[1581, 128, 52, 65]\tname:i "eatelst lat rer-te kumar th.\tScore:neutral:46.0\r',
#  'boxes:[1577, 469, 50, 61]\tname:Ve 2S oe\tScore:neutral:70.0\r',
#  'boxes:[1149, 650, 30, 38]\tname:Kumar feley-a Aditya Teta]\tScore:fear:33.0\r',
#  'boxes:[784, 964, 50, 61]\tname:@ite, lelsitia iva\tScore:happy:67.0\r',
#  'boxes:[522, 155, 37, 49]\tname:Chet Sagar (O}s{.)\tScore:happy:72.0\r',
#  'boxes:[1792, 660, 42, 50]\tname:Raja\tScore:sad:49.0\r',
#  'boxes:[519, 809, 43, 52]\tname:1 Singh Sham. 098\tScore:neutral:63.0\r',
#  'Frame No:12\r',
#  'boxes:[89, 622, 56, 68]\tname:032 Harsh Rai\tScore:neutral:84.0\r',
#  'boxes:[1376, 304, 44, 55]\tname:Tl t-34 Kumar 078\tScore:neutral:79.0\r',
#  'boxes:[932, 277, 77, 100]\tname:yYestia Kumar\tScore:neutral:74.0\r',
#  'boxes:[295, 783, 51, 62]\tname:mely 9 4 NitstwAfahari\tScore:sad:46.0\r',
#  'boxes:[731, 802, 46, 57]\tname:Bel tay sSlieertlc Ser leee ae\tScore:neutral:56.99999999999999\r',
#  'boxes:[726, 135, 58, 73]\tname:NAVNITA | KIIMARI\tScore:neutral:77.0\r',
#  'boxes:[1367, 824, 49, 60]\tname:Amar Sarkan 012\tScore:neutral:53.0\r',
#  'boxes:[1790, 141, 40, 51]\tname:Shvam Shukis 102\tScore:neutral:93.0\r',
#  'boxes:[1771, 476, 58, 72]\tname:Manish 048 loormar\tScore:neutral:87.0\r',
#  'boxes:[1368, 457, 35, 45]\tname:\tScore:neutral:88.0\r',
#  'boxes:[528, 511, 39, 49]\tname:Nitesh detlestel\tScore:happy:56.00000000000001\r',
#  'boxes:[83, 807, 57, 74]\tname:Neeraj Fels;\tScore:neutral:68.0\r',
#  'boxes:[1786, 819, 39, 46]\tname:Chaudhary Sarita 044\tScore:neutral:43.0\r',
#  'boxes:[116, 98, 63, 78]\tname:st Barnabas st Barnabas\tScore:happy:97.0\r',
#  'boxes:[1559, 319, 73, 90]\tname:otislelal o18 ,\tScore:happy:62.0\r',
#  'boxes:[113, 311, 42, 51]\tname:be laisall eilait Mehta Mehta\tScore:neutral:48.0\r',
#  'boxes:[1162, 288, 65, 79]\tname:HARSH SHARMA\tScore:neutral:77.0\r',
#  'boxes:[1137, 786, 76, 98]\tname:-Ruchi | /Panse\tScore:sad:40.0\r',
#  'boxes:[303, 149, 49, 63]\tname:Pooja Yadav\tScore:neutral:61.0\r',
#  'boxes:[1372, 983, 45, 52]\tname:\tScore:neutral:65.0\r',
#  'boxes:[933, 481, 43, 54]\tname:Sudh3nshu Shrivasteyv\tScore:neutral:56.99999999999999\r',
#  'boxes:[930, 128, 43, 49]\tname:oetllaltisteiaetiie ns rao\tScore:angry:33.0\r',
#  'boxes:[1148, 127, 50, 66]\tname:Kumawat Runal\tScore:sad:39.0\r',
#  'boxes:[717, 289, 73, 92]\tname:|Garg Simran\tScore:neutral:64.0\r',
#  'boxes:[1581, 128, 52, 65]\tname:i "eatelst lat rer-te kumar th.\tScore:neutral:46.0\r',
#  'boxes:[1577, 469, 50, 61]\tname:Ve 2S oe\tScore:neutral:70.0\r',
#  'boxes:[521, 154, 38, 50]\tname:[Cities 086 Sagar\tScore:happy:80.0\r',
#  'boxes:[1580, 620, 42, 55]\tname:iMeena  | Neetu | Neetu\tScore:neutral:49.0\r',
#  'boxes:[1774, 274, 48, 58]\tname:\tScore:sad:34.0\r',
#  'boxes:[784, 964, 50, 61]\tname:@ite, lelsitia iva\tScore:happy:67.0\r',
#  'boxes:[1149, 650, 30, 39]\tname:Kumar Soni Aditya rele\tScore:fear:39.0\r',
#  'boxes:[1792, 660, 42, 50]\tname:Raja\tScore:sad:49.0\r',
#  'boxes:[519, 809, 43, 52]\tname:1 Singh Sham. 098\tScore:neutral:63.0\r',
#  'Frame No:13\r',
#  'boxes:[89, 622, 56, 68]\tname:032 Harsh Rai\tScore:neutral:85.0\r',
#  'boxes:[1377, 303, 43, 56]\tname:tle ==) 4 Kumar 078\tScore:neutral:81.0\r',
#  'boxes:[932, 277, 76, 100]\tname:wy \\estia Kumar\tScore:neutral:73.0\r',
#  'boxes:[295, 783, 51, 62]\tname:mely 9 4 NitstwAfahari\tScore:sad:46.0\r',
#  'boxes:[731, 802, 46, 57]\tname:Bel tay stlieertle Ser icee ae\tScore:neutral:56.99999999999999\r',
#  'boxes:[726, 135, 58, 73]\tname:NAVNITA | KIIMARI\tScore:neutral:77.0\r',
#  'boxes:[1367, 824, 49, 60]\tname:Amar Sarkan 012\tScore:neutral:53.0\r',
#  'boxes:[1790, 141, 40, 51]\tname:Shvam Shukis 102\tScore:neutral:93.0\r',
#  'boxes:[1771, 476, 58, 72]\tname:Manish 048 loormar\tScore:neutral:87.0\r',
#  'boxes:[528, 511, 39, 49]\tname:Nitesh detlestel\tScore:happy:56.99999999999999\r',
#  'boxes:[1368, 457, 35, 45]\tname:\tScore:neutral:87.0\r',
#  'boxes:[83, 807, 57, 74]\tname:Neeraj Fels;\tScore:neutral:68.0\r',
#  'boxes:[1786, 819, 39, 46]\tname:Chaudhary Sarita 044\tScore:neutral:43.0\r',
#  'boxes:[116, 98, 63, 78]\tname:st Barnabas st Barnabas\tScore:happy:97.0\r',
#  'boxes:[1559, 319, 73, 90]\tname:otislelal o18 ,\tScore:happy:62.0\r',
#  'boxes:[113, 311, 42, 51]\tname:be laisall eilait Mehta Mehta\tScore:neutral:48.0\r',
#  'boxes:[1162, 288, 65, 79]\tname:HARSH SHARMA\tScore:neutral:77.0\r',
#  'boxes:[1137, 786, 76, 98]\tname:-Ruchi | /Panse\tScore:sad:40.0\r',
#  'boxes:[303, 149, 49, 63]\tname:Pooja Yadav\tScore:neutral:61.0\r',
#  'boxes:[1372, 983, 45, 52]\tname:\tScore:neutral:65.0\r',
#  'boxes:[1575, 466, 51, 65]\tname:Nandsani S! hah\tScore:neutral:48.0\r',
#  'boxes:[933, 481, 43, 54]\tname:Sudh3nshu Shrivastoyv\tScore:neutral:56.99999999999999\r',
#  'boxes:[930, 128, 43, 49]\tname:oetllaltisteiaetiie ns rao\tScore:angry:33.0\r',
#  'boxes:[1148, 127, 50, 66]\tname:Kumawat Runal\tScore:sad:39.0\r',
#  'boxes:[717, 289, 73, 92]\tname:|Garg Simran\tScore:neutral:64.0\r',
#  'boxes:[1581, 128, 52, 65]\tname:ie atelst lat rer-te kumar th.\tScore:neutral:47.0\r',
#  'boxes:[1580, 620, 42, 55]\tname:i Meena  | Neetu | Neetu\tScore:neutral:49.0\r',
#  'boxes:[1775, 275, 47, 57]\tname:\tScore:happy:46.0\r',
#  'boxes:[784, 964, 50, 61]\tname:@ite, lelsitia iva\tScore:happy:67.0\r',
#  'boxes:[521, 155, 37, 47]\tname:Sagar fettie = 086\tScore:happy:74.0\r',
#  'boxes:[1149, 650, 30, 39]\tname:Kumar Soni Aditya rele\tScore:fear:38.0\r',
#  'boxes:[519, 809, 43, 51]\tname:Sanam. | Singh 098\tScore:neutral:65.0\r',
#  'boxes:[1792, 660, 42, 50]\tname:Raja\tScore:sad:49.0\r',
#  'Frame No:14\r',
#  'boxes:[89, 622, 56, 68]\tname:032 Harsh Rai\tScore:neutral:85.0\r',
#  'boxes:[1162, 287, 67, 79]\tname:HARSH SHARMA\tScore:neutral:71.0\r',
#  'boxes:[113, 312, 43, 52]\tname:Ment: tel aisall ilel! tel aisall ilel!\tScore:neutral:62.0\r',
#  'boxes:[1377, 303, 43, 56]\tname:tle ==) 4 Kumar 078\tScore:neutral:81.0\r',
#  'boxes:[1790, 141, 40, 51]\tname:Shvam Shukis 102\tScore:neutral:94.0\r',
#  'boxes:[295, 783, 51, 62]\tname:mely 9 4 NitstwAfahari\tScore:sad:46.0\r',
#  'boxes:[731, 802, 46, 57]\tname:Bel tay sSlieerlcg Ser leee ee\tScore:neutral:56.99999999999999\r',
#  'boxes:[932, 278, 76, 99]\tname:Amit. Kumar\tScore:neutral:62.0\r',
#  'boxes:[726, 135, 58, 73]\tname:NAVNITA | KIIMARI\tScore:neutral:77.0\r',
#  'boxes:[1771, 476, 58, 72]\tname:Manish 048 loormar\tScore:neutral:87.0\r',
#  'boxes:[528, 511, 39, 49]\tname:Nitesh detlestel\tScore:happy:56.99999999999999\r',
#  'boxes:[1368, 457, 35, 45]\tname:\tScore:neutral:87.0\r',
#  'boxes:[303, 149, 49, 63]\tname:Pooja Yadav\tScore:neutral:63.0\r',
#  'boxes:[83, 807, 57, 74]\tname:Neeraj Fels;\tScore:neutral:68.0\r',
#  'boxes:[1786, 819, 39, 46]\tname:Chaudhary Sarita 044\tScore:neutral:43.0\r',
#  'boxes:[116, 98, 63, 78]\tname:st Barnabas st Barnabas\tScore:happy:97.0\r',
#  'boxes:[1775, 275, 47, 57]\tname:\tScore:happy:37.0\r',
#  'boxes:[1137, 786, 76, 98]\tname:-Ruchi | /Panse\tScore:sad:40.0\r',
#  'boxes:[1372, 983, 45, 52]\tname:\tScore:neutral:65.0\r',
#  'boxes:[933, 481, 43, 54]\tname:Sudh3nshu Shrivastoyv\tScore:neutral:56.99999999999999\r',
#  'boxes:[930, 128, 43, 49]\tname:oetllaltisteiaetiie ns rao\tScore:angry:33.0\r',
#  'boxes:[1575, 467, 51, 63]\tname:Nan@ani SI hah\tScore:neutral:46.0\r',
#  'boxes:[1148, 127, 50, 66]\tname:Kumawat Runal\tScore:sad:39.0\r',
#  'boxes:[1555, 318, 76, 96]\tname:elalelal | Ait 018\tScore:angry:35.0\r',
#  'boxes:[1368, 823, 49, 61]\tname:Sarkan Amar 012\tScore:neutral:50.0\r',
#  'boxes:[717, 289, 73, 92]\tname:|Garg Simran\tScore:neutral:65.0\r',
#  'boxes:[1581, 128, 52, 65]\tname:ie atelst lat rer-te kumar th.\tScore:neutral:48.0\r',
#  'boxes:[1580, 620, 42, 55]\tname:i Meena  | Neetu | Neetu\tScore:neutral:49.0\r',
#  'boxes:[784, 964, 49, 60]\tname:[Gisele isisitia iva\tScore:happy:57.99999999999999\r',
#  'boxes:[1149, 650, 30, 39]\tname:Kumar Soni Aditya rele\tScore:fear:39.0\r',
#  'boxes:[521, 155, 37, 48]\tname:fCitiest Saaar 086\tScore:happy:64.0\r',
#  'boxes:[519, 809, 43, 51]\tname:Sanam | | Singh 098\tScore:neutral:66.0\r',
#  'boxes:[1792, 660, 42, 50]\tname:Raja\tScore:sad:49.0\r',
#  'Frame No:15\r',
#  'boxes:[89, 622, 56, 68]\tname:032 Harsh Rai\tScore:neutral:85.0\r',
#  'boxes:[113, 312, 43, 52]\tname:Ment: tel aisall ilel! tel aisall ilel!\tScore:neutral:62.0\r',
#  'boxes:[1162, 288, 67, 78]\tname:HARSH CUIAPMA\tScore:neutral:77.0\r',
#  'boxes:[1377, 303, 43, 56]\tname:tle ==) 4 Kumar 078\tScore:neutral:81.0\r',
#  'boxes:[1790, 141, 40, 51]\tname:Shvam Shukis 102\tScore:neutral:94.0\r',
#  'boxes:[295, 783, 51, 62]\tname:mely 9 4 NitstwAfahari\tScore:sad:46.0\r',
#  'boxes:[729, 803, 49, 59]\tname:_ bikky mae-\\lgeseren Cua\tScore:neutral:65.0\r',
#  'boxes:[1146, 126, 52, 66]\tname:Kumawat Kunal\tScore:neutral:45.0\r',
#  'boxes:[932, 278, 75, 100]\tname:Amit Kumar.\tScore:neutral:75.0\r',
#  'boxes:[726, 135, 57, 73]\tname:KLMARI NAVNITA.\tScore:neutral:81.0\r',
#  'boxes:[1771, 476, 58, 72]\tname:Manish 048 loormar\tScore:neutral:87.0\r',
#  'boxes:[528, 511, 39, 49]\tname:Nitesh detlestel\tScore:happy:56.99999999999999\r',
#  'boxes:[303, 149, 49, 63]\tname:Pooja Yadav\tScore:neutral:63.0\r',
#  'boxes:[83, 807, 57, 74]\tname:Neeraj Fels;\tScore:neutral:68.0\r',
#  'boxes:[1786, 819, 39, 46]\tname:Chaudhary Sarita 044\tScore:neutral:43.0\r',
#  'boxes:[1368, 457, 36, 45]\tname:\tScore:neutral:87.0\r',
#  'boxes:[116, 98, 63, 78]\tname:st Barnabas st Barnabas\tScore:happy:97.0\r',
#  'boxes:[1137, 786, 76, 98]\tname:-Ruchi | /Panse\tScore:sad:40.0\r',
#  'boxes:[1372, 983, 45, 52]\tname:\tScore:neutral:65.0\r',
#  'boxes:[1557, 318, 74, 96]\tname:slalelal 018 may\tScore:angry:31.0\r',
#  'boxes:[933, 479, 44, 55]\tname:Shrivast Sudh4nshu sel\tScore:neutral:53.0\r',
#  'boxes:[930, 128, 43, 49]\tname:oetllaltisteiaetiie ns rao\tScore:angry:33.0\r',
#  'boxes:[1575, 467, 51, 63]\tname:Nan@ani SI hah\tScore:neutral:46.0\r',
#  'boxes:[1775, 275, 47, 56]\tname:\tScore:sad:31.0\r',
#  'boxes:[1368, 823, 49, 61]\tname:Sarkan Amar 012\tScore:neutral:49.0\r',
#  'boxes:[717, 289, 73, 92]\tname:|Garg Simran\tScore:neutral:66.0\r',
#  'boxes:[1581, 128, 52, 65]\tname:ie atelst lat rer-te kumar th.\tScore:neutral:48.0\r',
#  'boxes:[1580, 620, 42, 55]\tname:i Meena  | Neetu | Neetu\tScore:neutral:49.0\r',
#  'boxes:[784, 964, 49, 60]\tname:[Gisele isisitia iva\tScore:happy:57.99999999999999\r',
#  'boxes:[521, 155, 37, 48]\tname:fCitiest Saaar 086\tScore:happy:63.0\r',
#  'boxes:[519, 809, 43, 51]\tname:Sanam | | Singh 098\tScore:neutral:66.0\r',
#  'boxes:[1792, 660, 42, 50]\tname:Raja\tScore:sad:49.0\r',
#  'boxes:[1149, 649, 29, 37]\tname:y Velie) Kumar feleyl Son\tScore:fear:40.0\r',
#  'Frame No:16\r',
#  'boxes:[89, 622, 56, 68]\tname:032 Harsh Rai\tScore:neutral:85.0\r',
#  'boxes:[113, 312, 43, 52]\tname:Ment: tel aisall ilel! tel aisall ilel!\tScore:neutral:62.0\r',
#  'boxes:[1377, 304, 43, 55]\tname:Tl t-34 Kumar 078\tScore:neutral:79.0\r',
#  'boxes:[1790, 141, 40, 51]\tname:Shvam Shukla 102\tScore:neutral:95.0\r',
#  'boxes:[295, 783, 51, 62]\tname:mely 9 4 NitstwAfahari\tScore:sad:46.0\r',
#  'boxes:[932, 278, 76, 100]\tname:Amit Kumar.\tScore:neutral:75.0\r',
#  'boxes:[729, 803, 49, 59]\tname:_ bikky aae-\\laee lm Cua\tScore:neutral:66.0\r',
#  'boxes:[1146, 126, 52, 66]\tname:Kumawat Kunal\tScore:neutral:47.0\r',
#  'boxes:[726, 135, 57, 73]\tname:KUMARI NAVNITA.\tScore:neutral:82.0\r',
#  'boxes:[1771, 476, 58, 72]\tname:Manish 048 loormar\tScore:neutral:87.0\r',
#  'boxes:[528, 511, 39, 49]\tname:Nitesh detlestel\tScore:happy:56.99999999999999\r',
#  'boxes:[303, 149, 49, 63]\tname:Pooja Yadav\tScore:neutral:63.0\r',
#  'boxes:[83, 807, 57, 74]\tname:Neeraj Fels;\tScore:neutral:68.0\r',
#  'boxes:[1368, 457, 36, 45]\tname:\tScore:neutral:87.0\r',
#  'boxes:[116, 98, 63, 78]\tname:st Barnabas st Barnabas\tScore:happy:97.0\r',
#  'boxes:[1786, 819, 39, 45]\tname:Chaudhary "Sarita 044\tScore:neutral:46.0\r',
#  'boxes:[1137, 786, 76, 98]\tname:-Ruchi | /Panse\tScore:sad:40.0\r',
#  'boxes:[1162, 288, 64, 78]\tname:HARSH CLIAPMA .\tScore:neutral:76.0\r',
#  'boxes:[1372, 983, 45, 52]\tname:\tScore:neutral:65.0\r',
#  'boxes:[1557, 318, 74, 96]\tname:slalelal 018 may\tScore:angry:31.0\r',
#  'boxes:[933, 479, 44, 55]\tname:Shrivast Sudh4nshu sel\tScore:neutral:53.0\r',
#  'boxes:[930, 128, 43, 49]\tname:oetllaltisteiaetiie ns rao\tScore:angry:33.0\r',
#  'boxes:[1575, 467, 51, 63]\tname:Nan@ani SI hah\tScore:neutral:46.0\r',
#  'boxes:[1775, 275, 47, 57]\tname:\tScore:happy:46.0\r',
#  'boxes:[1581, 128, 52, 65]\tname:i "eatelst lat rer-te kumar th.\tScore:neutral:46.0\r',
#  'boxes:[1368, 823, 49, 61]\tname:Sarkan Amar 012\tScore:neutral:49.0\r',
#  'boxes:[717, 289, 73, 92]\tname:|Garg Simran\tScore:neutral:65.0\r',
#  'boxes:[520, 154, 37, 48]\tname:BS ler\\s Cue 086\tScore:happy:47.0\r',
#  'boxes:[1580, 620, 42, 55]\tname:i Meena  | Neetu | Neetu\tScore:neutral:49.0\r',
#  'boxes:[784, 964, 49, 60]\tname:[Gisele isisitia iva\tScore:happy:57.99999999999999\r',
#  'boxes:[519, 809, 43, 51]\tname:Sanam | | Singh 098\tScore:neutral:66.0\r',
#  'boxes:[1792, 659, 44, 52]\tname:Sangam ele)\tScore:sad:53.0\r',
#  'boxes:[1149, 649, 29, 37]\tname:y Velie) Kumar feleyl Son\tScore:fear:40.0\r',
#  'Frame No:17\r',
#  'boxes:[88, 620, 56, 70]\tname:032 Harsh Rai\tScore:neutral:88.0\r',
#  'boxes:[113, 312, 43, 52]\tname:Ment: tel aisall ilel! tel aisall ilel!\tScore:neutral:62.0\r',
#  'boxes:[1377, 304, 43, 55]\tname:Tl t-34 Kumar 078\tScore:neutral:79.0\r',
#  'boxes:[1790, 141, 40, 51]\tname:Shvam Shukla 102\tScore:neutral:95.0\r',
#  'boxes:[295, 783, 51, 62]\tname:mely 9 4 NitstwAfahari\tScore:sad:47.0\r',
#  'boxes:[932, 278, 76, 100]\tname:Amit Kumar.\tScore:neutral:75.0\r',
#  'boxes:[729, 803, 49, 59]\tname:_ bikky aae-\\laee lm cular\tScore:neutral:66.0\r',
#  'boxes:[726, 135, 58, 74]\tname:rrAVibe-@ KLMARI\tScore:neutral:88.0\r',
#  'boxes:[1146, 126, 52, 66]\tname:Kumawat Kunal\tScore:neutral:48.0\r',
#  'boxes:[83, 807, 57, 74]\tname:Neeraj Fels;\tScore:neutral:68.0\r',
#  'boxes:[1162, 288, 64, 77]\tname:TWIARPCL CLIAPMA\tScore:neutral:82.0\r',
#  'boxes:[1786, 819, 39, 45]\tname:Chaudhary "Sarita O44\tScore:neutral:45.0\r',
#  'boxes:[1368, 457, 36, 45]\tname:\tScore:neutral:87.0\r',
#  'boxes:[116, 98, 63, 78]\tname:st Barnabas st Barnabas\tScore:happy:97.0\r',
#  'boxes:[529, 510, 39, 50]\tname:Nitesh kum\tScore:happy:65.0\r',
#  'boxes:[1138, 785, 77, 99]\tname:Ruchi Panse\tScore:neutral:33.0\r',
#  'boxes:[1775, 275, 47, 58]\tname:\tScore:happy:40.0\r',
#  'boxes:[302, 149, 50, 63]\tname:Pooja Yadav\tScore:neutral:65.0\r',
#  'boxes:[1372, 983, 45, 52]\tname:\tScore:neutral:65.0\r',
#  'boxes:[1557, 318, 74, 96]\tname:welatelal 018 may\tScore:angry:31.0\r',
#  'boxes:[933, 479, 44, 55]\tname:Shrivast Sudh4nshu sel\tScore:neutral:53.0\r',
#  'boxes:[930, 128, 43, 49]\tname:oetllaltisteiaetiie ns rao\tScore:angry:32.0\r',
#  'boxes:[1581, 128, 52, 65]\tname:i "eatelst lat rer-te kumar th.\tScore:neutral:46.0\r',
#  'boxes:[1368, 823, 49, 61]\tname:Sarkan Amar 012\tScore:neutral:48.0\r',
#  'boxes:[717, 289, 73, 92]\tname:|Garg Simran\tScore:neutral:66.0\r',
#  'boxes:[1576, 468, 50, 63]\tname:Ne ea oe\tScore:neutral:61.0\r',
#  'boxes:[520, 154, 37, 48]\tname:BSler\\s Cue 086\tScore:happy:47.0\r',
#  'boxes:[1580, 620, 42, 55]\tname:i Meena  | Neetu | Neetu\tScore:neutral:49.0\r',
#  'boxes:[1770, 479, 59, 70]\tname:ey-t:} Vi etattte kumar\tScore:neutral:85.0\r',
#  'boxes:[784, 964, 49, 60]\tname:[Gisele isisitia iva\tScore:happy:67.0\r',
#  'boxes:[1792, 659, 44, 52]\tname:Sangam ele)\tScore:sad:53.0\r',
#  'boxes:[1149, 649, 29, 37]\tname:y Velie) Kumar feleyl Son\tScore:fear:40.0\r',
#  'boxes:[518, 811, 42, 50]\tname:Shivam 1 Singh 098\tScore:neutral:68.0\r',
#  'Frame No:18\r',
#  'boxes:[88, 620, 56, 70]\tname:032 Harsh Rai\tScore:neutral:88.0\r',
#  'boxes:[113, 312, 43, 52]\tname:Ment: tel aisall ilel! tel aisall ilel!\tScore:neutral:62.0\r',
#  'boxes:[1377, 304, 43, 55]\tname:Tl t-34 Kumar 078\tScore:neutral:79.0\r',
#  'boxes:[932, 280, 75, 98]\tname:Amit. ilar\tScore:neutral:77.0\r',
#  'boxes:[1791, 141, 39, 52]\tname:Shvam his Flare 102 Yo\tScore:neutral:86.0\r',
#  'boxes:[295, 783, 51, 62]\tname:mely 9 4 NitstwAfahari\tScore:sad:47.0\r',
#  'boxes:[726, 135, 58, 74]\tname:rrAVibe-@ KLMARI\tScore:neutral:89.0\r',
#  'boxes:[729, 803, 49, 59]\tname:_ bikky aae-\\laee lm cular\tScore:neutral:66.0\r',
#  'boxes:[1146, 126, 52, 66]\tname:Kumawat Kunal\tScore:neutral:48.0\r',
#  'boxes:[83, 807, 57, 74]\tname:Neeraj Fels;\tScore:neutral:68.0\r',
#  'boxes:[1162, 288, 64, 77]\tname:TWIARPCL CLIAPMA\tScore:neutral:82.0\r',
#  'boxes:[1786, 819, 39, 45]\tname:Chaudhary "Sarita O44\tScore:neutral:45.0\r',
#  'boxes:[529, 510, 39, 50]\tname:Nitesh kum\tScore:happy:66.0\r',
#  'boxes:[116, 98, 63, 78]\tname:st Barnabas st Barnabas\tScore:happy:97.0\r',
#  'boxes:[1138, 785, 77, 99]\tname:Ruchi Panse\tScore:happy:32.0\r',
#  'boxes:[1367, 457, 36, 44]\tname:\tScore:neutral:93.0\r',
#  'boxes:[1554, 320, 75, 93]\tname:ela lal 018 | Aki\tScore:happy:39.0\r',
#  'boxes:[302, 149, 50, 63]\tname:Pooja Yadav\tScore:neutral:65.0\r',
#  'boxes:[1372, 983, 45, 52]\tname:\tScore:neutral:65.0\r',
#  'boxes:[1774, 275, 48, 58]\tname:\tScore:happy:40.0\r',
#  'boxes:[933, 479, 44, 55]\tname:Shrivast Sudh4nshu sel\tScore:neutral:53.0\r',
#  'boxes:[930, 128, 43, 49]\tname:oetllaltisteiaetiie ns rao\tScore:angry:32.0\r',
#  'boxes:[1581, 128, 52, 65]\tname:i "eatelst lat rer-te kumar th.\tScore:neutral:46.0\r',
#  'boxes:[1368, 823, 49, 61]\tname:Sarkan Amar 012\tScore:neutral:48.0\r',
#  'boxes:[717, 289, 73, 92]\tname:|Garg Simran\tScore:neutral:66.0\r',
#  'boxes:[1576, 468, 50, 63]\tname:Nanton; Sha!\tScore:neutral:61.0\r',
#  'boxes:[520, 154, 37, 48]\tname:BSler\\s Cue 086\tScore:happy:48.0\r',
#  'boxes:[1580, 620, 42, 55]\tname:iMeena  | Neetu | Neetu\tScore:neutral:49.0\r',
#  'boxes:[1770, 479, 59, 70]\tname:ey-t:} Vi etattte alles | on\tScore:neutral:85.0\r',
#  'boxes:[783, 964, 50, 60]\tname:Gales ielsltia iva\tScore:happy:62.0\r',
#  'boxes:[1792, 659, 44, 52]\tname:Sangam ele)\tScore:sad:53.0\r',
#  'boxes:[1149, 649, 29, 37]\tname:y Velie) Kumar feleyl Son\tScore:fear:43.0\r',
#  'boxes:[519, 810, 44, 52]\tname:Shriram. 098 1 Singh\tScore:neutral:59.0\r',
#  'Frame No:19\r',
#  'boxes:[88, 620, 56, 70]\tname:032 Harsh Rai\tScore:neutral:88.0\r',
#  'boxes:[731, 803, 48, 59]\tname:_bikkyl jeselecoes\tScore:neutral:55.00000000000001\r',
#  'boxes:[932, 280, 75, 98]\tname:Amit. ilar\tScore:neutral:77.0\r',
#  'boxes:[1790, 141, 40, 51]\tname:Shvam Shukla 102\tScore:neutral:95.0\r',
#  'boxes:[295, 783, 51, 62]\tname:mely 9 4 NifstwAfahari\tScore:sad:47.0\r',
#  'boxes:[1376, 304, 43, 54]\tname:Tat-t-34 Kumar O78\tScore:neutral:80.0\r',
#  'boxes:[113, 311, 43, 53]\tname:Mehta jel aisall eilat: jel aisall eilat:\tScore:neutral:46.0\r',
#  'boxes:[1146, 126, 52, 66]\tname:Kumawat Kunal\tScore:neutral:48.0\r',
#  'boxes:[726, 135, 57, 73]\tname:KUMARI NAVNITA.\tScore:neutral:82.0\r',
#  'boxes:[1162, 287, 65, 78]\tname:HARSH SHARMA\tScore:neutral:68.0\r',
#  'boxes:[934, 480, 43, 54]\tname:Malahcincle ase Ss .lU\tScore:neutral:56.00000000000001\r',
#  'boxes:[83, 807, 57, 74]\tname:Neeraj Fels;\tScore:neutral:68.0\r',
#  'boxes:[1786, 819, 39, 45]\tname:Chaudhary "Sarita O44\tScore:neutral:45.0\r',
#  'boxes:[529, 510, 39, 50]\tname:Nitesh kum\tScore:happy:66.0\r',
#  'boxes:[116, 98, 63, 78]\tname:st Barnabas st Barnabas\tScore:happy:97.0\r',
#  'boxes:[1138, 785, 77, 99]\tname:Ruchi Panse\tScore:neutral:32.0\r',
#  'boxes:[1367, 456, 36, 45]\tname:\tScore:neutral:89.0\r',
#  'boxes:[1554, 320, 75, 93]\tname:ela lal 018 | Aki\tScore:happy:38.0\r',
#  'boxes:[1774, 275, 49, 58]\tname:\tScore:happy:45.0\r',
#  'boxes:[302, 149, 50, 63]\tname:Pooja Yadav\tScore:neutral:65.0\r',
#  'boxes:[1372, 983, 45, 52]\tname:\tScore:neutral:65.0\r',
#  'boxes:[930, 128, 43, 49]\tname:oetllaltisteiaetiie ns rao\tScore:angry:32.0\r',
#  'boxes:[1581, 128, 52, 65]\tname:i "eatelst lat rer-te kumar th.\tScore:neutral:47.0\r',
#  'boxes:[717, 289, 73, 92]\tname:|Garg Simran\tScore:neutral:66.0\r',
#  'boxes:[1367, 822, 51, 63]\tname:Amar 012 Sarkan\tScore:angry:54.0\r',
#  'boxes:[1576, 468, 50, 63]\tname:Nantian; Sha!\tScore:neutral:61.0\r',
#  'boxes:[520, 154, 37, 48]\tname:Sagar Cue 086\tScore:happy:53.0\r',
#  'boxes:[1580, 620, 42, 55]\tname:iMeena  | Neetu | Neetu\tScore:neutral:49.0\r',
#  'boxes:[1770, 479, 59, 70]\tname:ey-t:} Vi etattte alles | on\tScore:neutral:85.0\r',
#  'boxes:[783, 964, 50, 60]\tname:Gales ielsltia iva\tScore:happy:62.0\r',
#  'boxes:[1792, 659, 44, 52]\tname:Sangam ele)\tScore:sad:53.0\r',
#  'boxes:[1149, 649, 29, 37]\tname:y Velie) Kumar feleyl Son\tScore:fear:43.0\r',
#  'boxes:[519, 810, 44, 52]\tname:Shriram. 098 1 Singh\tScore:neutral:60.0\r',
#  'Frame No:20\r',
# ...
#  'boxes:[934, 479, 44, 55]\tname:Shrivacr Sudh4Snshu . TVa\tScore:neutral:64.0\r',
#  'boxes:[1137, 787, 76, 97]\tname:-Ruchi Panse\tScore:sad:42.0\r',
#  'boxes:[302, 149, 50, 64]\tname:Pooja Yadav\tScore:neutral:50.0\r',
#  'boxes:[1372, 983, 45, 52]\tname:\tScore:neutral:65.0\r',
#  'boxes:[930, 129, 43, 49]\tname:puruchottama | rao\tScore:happy:46.0\r',
#  'boxes:[931, 277, 74, 100]\tname:Amit Kumar\tScore:neutral:76.0\r',
#  'boxes:[1147, 127, 50, 65]\tname:Mlsrivc ls Raunal\tScore:neutral:62.0\r',
#  'boxes:[521, 154, 37, 48]\tname:[Cities Sagar 086\tScore:happy:65.0\r',
#  'boxes:[1581, 128, 52, 66]\tname:kanchan: rey-te) kumar th..\tScore:neutral:46.0\r',
#  'boxes:[717, 289, 73, 92]\tname:|Garg Simran\tScore:neutral:60.0\r',
#  'boxes:[1574, 467, 50, 62]\tname:Nan@ani SI seial\tScore:neutral:38.0\r',
#  'boxes:[1367, 822, 51, 62]\tname:Sarkar Amar. 012\tScore:neutral:48.0\r',
#  'boxes:[783, 964, 50, 60]\tname:@ sles ielsltia iva\tScore:happy:62.0\r',
#  'boxes:[520, 804, 52, 64]\tname:)Singh 098 |. Saar\tScore:neutral:64.0\r',
#  'boxes:[1792, 659, 44, 52]\tname:Sangam ele)\tScore:sad:53.0\r',
#  'boxes:[1149, 649, 28, 36]\tname:Aditya releya Kumar Son\tScore:fear:45.0\r',
#  'Frame No:24\r',
#  'boxes:[89, 622, 56, 68]\tname:032 Harsh Rai\tScore:neutral:84.0\r',
#  "boxes:[1163, 287, 66, 78]\tname:HARSH 'CLIADMA\tScore:neutral:70.0\r",
#  'boxes:[1790, 142, 40, 50]\tname:Shvam Shukla 10?\tScore:neutral:95.0\r',
#  'boxes:[296, 783, 50, 62]\tname:mely 9 4 NifstwAfahari\tScore:sad:47.0\r',
#  'boxes:[1376, 304, 43, 54]\tname:Tat-t-34 Kumar O78\tScore:neutral:82.0\r',
#  'boxes:[113, 311, 43, 53]\tname:Mehta i latsell clei i latsell clei\tScore:neutral:45.0\r',
#  'boxes:[1575, 618, 47, 60]\tname:u Meena mm ey.10) _Neetu\tScore:neutral:57.99999999999999\r',
#  'boxes:[1550, 320, 79, 96]\tname:Siatelal el abe 018\tScore:angry:28.000000000000004\r',
#  'boxes:[726, 134, 57, 75]\tname:KUMARI NAVNITA.\tScore:neutral:85.0\r',
#  'boxes:[731, 802, 49, 60]\tname:iar. _bikkyl Sharh\tScore:neutral:56.99999999999999\r',
#  'boxes:[1367, 457, 36, 45]\tname:\tScore:neutral:87.0\r',
#  'boxes:[529, 511, 39, 49]\tname:Nitesh kum\tScore:happy:70.0\r',
#  'boxes:[83, 807, 57, 74]\tname:Neeraj Fels;\tScore:neutral:68.0\r',
#  'boxes:[500, 641, 74, 91]\tname:Gupta Sonu 104\tScore:angry:35.0\r',
#  'boxes:[116, 98, 63, 78]\tname:st Barnabas st Barnabas\tScore:happy:97.0\r',
#  'boxes:[1771, 476, 58, 72]\tname:Manish 048 loormar\tScore:neutral:88.0\r',
#  'boxes:[1786, 819, 39, 45]\tname:Chaudhary "Sarita 044\tScore:neutral:50.0\r',
#  'boxes:[934, 479, 44, 55]\tname:Shrivacr Sudh4Snshu . TVa\tScore:neutral:64.0\r',
#  'boxes:[1147, 127, 50, 65]\tname:Mlsrivc ls Raunal\tScore:neutral:62.0\r',
#  'boxes:[1137, 786, 76, 98]\tname:-Ruchi | Panse\tScore:sad:53.0\r',
#  'boxes:[931, 129, 42, 48]\tname:-purushottama r rao\tScore:happy:41.0\r',
#  'boxes:[930, 277, 75, 99]\tname:Amit Kumar\tScore:neutral:68.0\r',
#  'boxes:[302, 149, 50, 64]\tname:Pooja Yadav\tScore:neutral:50.0\r',
#  'boxes:[521, 154, 38, 48]\tname:fCitieis Sagar 086\tScore:happy:75.0\r',
#  'boxes:[1372, 983, 45, 52]\tname:\tScore:neutral:65.0\r',
#  'boxes:[1581, 128, 52, 66]\tname:kanchan: rey-te) kumar th..\tScore:neutral:45.0\r',
#  'boxes:[717, 289, 73, 92]\tname:|Garg Simran\tScore:neutral:60.0\r',
#  'boxes:[1774, 275, 49, 58]\tname:\tScore:happy:42.0\r',
#  'boxes:[1574, 467, 50, 62]\tname:Nan@ani SI seial\tScore:neutral:38.0\r',
#  'boxes:[1367, 822, 51, 62]\tname:Sark> Amar. 012\tScore:neutral:48.0\r',
#  'boxes:[783, 964, 50, 60]\tname:@ sles ielsltia iva\tScore:happy:62.0\r',
#  'boxes:[520, 804, 52, 64]\tname:)Singh 098 |. Saar\tScore:neutral:63.0\r',
#  'boxes:[1792, 659, 44, 52]\tname:Sangam ele)\tScore:sad:53.0\r',
#  'boxes:[1148, 649, 29, 36]\tname:Aditya releya dase Son\tScore:fear:44.0\r',
#  'Frame No:25\r',
#  'boxes:[89, 622, 56, 68]\tname:032 Harsh Rai\tScore:neutral:84.0\r',
#  "boxes:[1163, 287, 66, 78]\tname:HARSH 'CLIADMA\tScore:neutral:70.0\r",
#  'boxes:[1790, 143, 40, 49]\tname:Shukla Shvam 102 Yoo\tScore:neutral:92.0\r',
#  'boxes:[296, 783, 50, 62]\tname:mel 9 4 NifstwAfahari\tScore:sad:47.0\r',
#  'boxes:[1377, 303, 43, 56]\tname:tls ==) 4 Kumar 078\tScore:neutral:80.0\r',
#  'boxes:[113, 311, 43, 53]\tname:Mehta i latsell clei i latsell clei\tScore:neutral:45.0\r',
#  'boxes:[1575, 618, 47, 60]\tname:i Meena mm ey.10) Neetu\tScore:neutral:59.0\r',
#  'boxes:[1550, 320, 79, 96]\tname:Siatelal el abe 018\tScore:angry:28.000000000000004\r',
#  'boxes:[726, 134, 57, 74]\tname:NAVNITA. KLIMARI\tScore:neutral:75.0\r',
#  'boxes:[731, 802, 49, 60]\tname:iar. _bikkyl Sharh\tScore:neutral:56.99999999999999\r',
#  'boxes:[1367, 457, 36, 45]\tname:\tScore:neutral:87.0\r',
#  'boxes:[529, 511, 39, 49]\tname:Nitesh kum\tScore:happy:70.0\r',
#  'boxes:[83, 807, 57, 74]\tname:Neeraj Fels;\tScore:neutral:68.0\r',
#  'boxes:[1786, 819, 39, 46]\tname:Chaudhary Sarita 044\tScore:neutral:42.0\r',
#  'boxes:[116, 98, 63, 78]\tname:st Barnabas st Barnabas\tScore:happy:97.0\r',
#  'boxes:[1777, 278, 46, 55]\tname:\tScore:happy:67.0\r',
#  'boxes:[934, 479, 44, 55]\tname:Shrivacr Sudh4Snshu . TVa\tScore:neutral:64.0\r',
#  'boxes:[1137, 786, 76, 98]\tname:-Ruchi | Panse\tScore:sad:53.0\r',
#  'boxes:[302, 149, 50, 64]\tname:Pooja Yadav\tScore:neutral:50.0\r',
#  'boxes:[930, 277, 75, 99]\tname:Amit Kumar\tScore:neutral:67.0\r',
#  'boxes:[1147, 127, 50, 65]\tname:Mlsrivc ls Raunal\tScore:neutral:67.0\r',
#  'boxes:[1372, 983, 45, 52]\tname:\tScore:neutral:65.0\r',
#  'boxes:[500, 642, 73, 88]\tname:Sonu |Gupta ey.\tScore:surprise:38.0\r',
#  'boxes:[520, 154, 38, 49]\tname:Sagar [Ciiet 086\tScore:happy:66.0\r',
#  'boxes:[717, 289, 73, 92]\tname:|Garg Simran\tScore:neutral:59.0\r',
#  'boxes:[1367, 822, 51, 62]\tname:Sark> Amar. 012\tScore:neutral:48.0\r',
#  'boxes:[1581, 128, 52, 65]\tname:kanchan rer-te kumar th.\tScore:neutral:47.0\r',
#  'boxes:[1575, 468, 51, 63]\tname:Nandsani St\tScore:neutral:53.0\r',
#  'boxes:[930, 128, 43, 50]\tname:purushottama | rao\tScore:angry:32.0\r',
#  'boxes:[1771, 478, 58, 72]\tname:rey: Manish kumar\tScore:neutral:82.0\r',
#  'boxes:[783, 964, 50, 60]\tname:@ sles ielsltia iva\tScore:happy:62.0\r',
#  'boxes:[520, 804, 52, 64]\tname:)Singh 098 |. Saar\tScore:neutral:63.0\r',
#  'boxes:[1792, 659, 44, 52]\tname:Sangam ele)\tScore:sad:53.0\r',
#  'boxes:[1148, 649, 29, 35]\tname:Kumar Sor Aditya foley\tScore:fear:47.0\r',
#  'Frame No:26\r',
#  'boxes:[89, 622, 56, 68]\tname:032 Harsh Rai\tScore:neutral:84.0\r',
#  "boxes:[1163, 287, 66, 78]\tname:HARSH 'CLIADMA\tScore:neutral:70.0\r",
#  'boxes:[1790, 141, 40, 51]\tname:Shvam Shukis 102 Yc\tScore:neutral:94.0\r',
#  'boxes:[296, 783, 50, 62]\tname:mel 9 4 NifstwAfahari\tScore:sad:47.0\r',
#  'boxes:[1377, 303, 43, 56]\tname:tls ==) 4 Kumar 078\tScore:neutral:80.0\r',
#  'boxes:[113, 311, 43, 53]\tname:Mehta i latsell clei i latsell clei\tScore:neutral:45.0\r',
#  'boxes:[726, 134, 57, 74]\tname:NAVNITA. KLIMARI\tScore:neutral:75.0\r',
#  'boxes:[731, 802, 49, 60]\tname:iar. _bikkyl Sharh\tScore:neutral:56.99999999999999\r',
#  'boxes:[1367, 457, 36, 45]\tname:\tScore:neutral:87.0\r',
#  'boxes:[529, 511, 39, 49]\tname:Nitesh kum\tScore:happy:70.0\r',
#  'boxes:[83, 807, 57, 74]\tname:Neeraj Fels;\tScore:neutral:68.0\r',
#  'boxes:[1786, 819, 39, 46]\tname:Chaudhary Sarita 044\tScore:neutral:42.0\r',
#  'boxes:[116, 98, 63, 78]\tname:st Barnabas st Barnabas\tScore:happy:97.0\r',
#  'boxes:[1777, 278, 46, 54]\tname:\tScore:happy:59.0\r',
#  'boxes:[1137, 786, 76, 98]\tname:Ruchi | Panse\tScore:sad:38.0\r',
#  'boxes:[934, 479, 44, 55]\tname:Shrivacr Sudh4Snshu . TVa\tScore:neutral:64.0\r',
#  'boxes:[930, 277, 74, 99]\tname:Amit i allestle\tScore:neutral:65.0\r',
#  'boxes:[302, 149, 50, 64]\tname:Pooja Yadav\tScore:neutral:50.0\r',
#  'boxes:[1147, 127, 50, 65]\tname:Mlsrivc ls Raunal\tScore:neutral:68.0\r',
#  'boxes:[1372, 983, 45, 52]\tname:\tScore:neutral:65.0\r',
#  'boxes:[500, 642, 73, 88]\tname:Sonu |Gupta ey.\tScore:surprise:38.0\r',
#  'boxes:[717, 289, 73, 92]\tname:|Garg Simran\tScore:neutral:59.0\r',
#  'boxes:[930, 129, 42, 49]\tname:puruchottama | rao\tScore:happy:53.0\r',
#  'boxes:[1368, 823, 49, 61]\tname:Amar Sarkan 012\tScore:neutral:48.0\r',
#  'boxes:[1581, 128, 52, 65]\tname:kanchan rer-te kumar th.\tScore:neutral:47.0\r',
#  'boxes:[1575, 468, 51, 63]\tname:Ne aS:\tScore:neutral:53.0\r',
#  'boxes:[1580, 619, 42, 56]\tname:iMveena  ) Neetu. ) Neetu.\tScore:neutral:45.0\r',
#  'boxes:[1771, 478, 58, 72]\tname:rey: Manish kumar\tScore:neutral:82.0\r',
#  'boxes:[1554, 321, 73, 89]\tname:Singh o18 Skit\tScore:sad:30.0\r',
#  'boxes:[783, 962, 51, 63]\tname:@isle, Velaltia. riva\tScore:happy:62.0\r',
#  'boxes:[521, 153, 38, 49]\tname:Sagar Che 086\tScore:happy:76.0\r',
#  'boxes:[519, 803, 53, 66]\tname:Singh 098 | Saver\tScore:neutral:47.0\r',
#  'boxes:[1792, 659, 44, 52]\tname:Sangam ele)\tScore:sad:53.0\r',
#  'boxes:[1148, 649, 29, 35]\tname:Kumar Sor Aditya foley\tScore:fear:47.0\r',
#  'Frame No:27\r',
#  'boxes:[88, 621, 56, 69]\tname:032 Harsh Rai\tScore:neutral:85.0\r',
#  'boxes:[732, 802, 49, 62]\tname:charryma cis bikkyl y Kun\tScore:neutral:49.0\r',
#  'boxes:[1790, 141, 40, 51]\tname:Shvam Shukis 102 > <\tScore:neutral:94.0\r',
#  'boxes:[296, 783, 50, 62]\tname:mel 9 4 Nif@stwAfahari\tScore:sad:47.0\r',
#  'boxes:[1377, 303, 43, 56]\tname:tls ==) 4 Kumar 078\tScore:neutral:80.0\r',
#  'boxes:[113, 311, 43, 53]\tname:Mehta i latsell clei i latsell clei\tScore:neutral:46.0\r',
#  'boxes:[726, 134, 57, 74]\tname:NAVNITA. KLIMARI\tScore:neutral:75.0\r',
#  'boxes:[1367, 457, 36, 45]\tname:\tScore:neutral:87.0\r',
#  "boxes:[1163, 287, 65, 78]\tname:HARSH 'CLIADMAA\tScore:neutral:70.0\r",
#  'boxes:[529, 511, 39, 49]\tname:Nitesh kum\tScore:happy:70.0\r',
#  'boxes:[83, 807, 57, 74]\tname:Neeraj Fels;\tScore:neutral:68.0\r',
#  'boxes:[1786, 819, 39, 46]\tname:Chaudhary Sarita 044\tScore:neutral:42.0\r',
#  'boxes:[116, 98, 63, 78]\tname:st Barnabas st Barnabas\tScore:happy:97.0\r',
#  'boxes:[302, 148, 50, 65]\tname:Pooja Vaday\tScore:neutral:59.0\r',
#  'boxes:[1137, 786, 76, 98]\tname:Ruchi | Panse\tScore:sad:38.0\r',
#  'boxes:[934, 479, 44, 55]\tname:Shrivacr Sudh4Snshu . TVa\tScore:neutral:64.0\r',
#  'boxes:[930, 277, 74, 99]\tname:Amit i ablestle\tScore:neutral:64.0\r',
#  'boxes:[1147, 127, 50, 65]\tname:Mlsrivc ls Raunal\tScore:neutral:68.0\r',
#  'boxes:[1372, 983, 45, 52]\tname:\tScore:neutral:65.0\r',
#  'boxes:[717, 289, 73, 92]\tname:|Garg Simran\tScore:neutral:60.0\r',
#  'boxes:[1775, 275, 48, 58]\tname:\tScore:happy:38.0\r',
#  'boxes:[499, 641, 74, 92]\tname:|Gupta Sonu 104\tScore:angry:41.0\r',
#  'boxes:[1368, 823, 49, 61]\tname:Amar Sarkan 012\tScore:neutral:48.0\r',
#  'boxes:[930, 129, 42, 48]\tname:-purushottamar rao\tScore:happy:42.0\r',
#  'boxes:[1581, 128, 52, 65]\tname:kanchan rer-te kumar th.\tScore:neutral:47.0\r',
#  'boxes:[1575, 468, 51, 63]\tname:Nandsani St\tScore:neutral:53.0\r',
#  'boxes:[1580, 619, 42, 56]\tname:iMvMeena  ) Neetu. ) Neetu.\tScore:neutral:46.0\r',
#  'boxes:[522, 154, 37, 48]\tname:Sagar [Cities 086\tScore:happy:77.0\r',
#  'boxes:[1771, 478, 58, 72]\tname:rey: Manish kumar\tScore:neutral:82.0\r',
#  'boxes:[1554, 321, 73, 89]\tname:Singh o18 kit\tScore:sad:30.0\r',
#  'boxes:[783, 962, 51, 63]\tname:@isle, Velaltia. riva\tScore:happy:62.0\r',
#  'boxes:[1792, 659, 44, 52]\tname:Sangam ele)\tScore:sad:53.0\r',
#  'boxes:[518, 812, 43, 49]\tname:+ Shawvam | Singh 098\tScore:neutral:59.0\r',
#  'boxes:[1148, 648, 28, 37]\tname:Aditya foley Kumar Son\tScore:fear:39.0\r',
#  'Frame No:28\r',
#  'boxes:[88, 621, 56, 69]\tname:032 Harsh Rai\tScore:neutral:85.0\r',
#  'boxes:[731, 802, 50, 62]\tname:charms _bikky#l yar\tScore:neutral:53.0\r',
#  'boxes:[1790, 141, 40, 51]\tname:Shvam Shukla 102 a &\tScore:neutral:93.0\r',
#  'boxes:[1377, 303, 43, 56]\tname:tls ==) 4 Kumar 078\tScore:neutral:80.0\r',
#  'boxes:[296, 783, 50, 62]\tname:mel 9 4 Nif@stwAfahari\tScore:sad:47.0\r',
#  'boxes:[113, 311, 43, 53]\tname:Mehta elatsallelatt elatsallelatt\tScore:neutral:45.0\r',
#  'boxes:[726, 134, 57, 74]\tname:NAVNITA. KLIMARI\tScore:neutral:75.0\r',
#  'boxes:[1367, 457, 36, 45]\tname:\tScore:neutral:87.0\r',
#  "boxes:[1163, 287, 65, 78]\tname:HARSH 'CLIADMAA\tScore:neutral:70.0\r",
#  'boxes:[529, 510, 39, 50]\tname:Nitesh kum\tScore:happy:69.0\r',
#  'boxes:[936, 479, 43, 54]\tname:Boiss ce. Birelst le taltl ava\tScore:neutral:56.00000000000001\r',
#  'boxes:[83, 807, 57, 74]\tname:Neeraj Fels;\tScore:neutral:68.0\r',
#  'boxes:[1138, 785, 77, 99]\tname:Ruchi Panse\tScore:happy:39.0\r',
#  'boxes:[1786, 819, 39, 45]\tname:Chaudhary "Sarita 044\tScore:neutral:50.0\r',
#  'boxes:[116, 98, 63, 78]\tname:st Barnabas st Barnabas\tScore:happy:97.0\r',
#  'boxes:[302, 148, 50, 65]\tname:Pooja Vaday\tScore:neutral:59.0\r',
#  'boxes:[930, 277, 74, 99]\tname:Amit i ablestle\tScore:neutral:64.0\r',
#  'boxes:[499, 642, 74, 90]\tname:| Gupta Sonu 104\tScore:surprise:30.0\r',
#  'boxes:[1147, 127, 50, 65]\tname:Mlsrivc ls Raunal\tScore:neutral:68.0\r',
#  'boxes:[1372, 983, 45, 52]\tname:\tScore:neutral:65.0\r',
#  'boxes:[717, 289, 73, 92]\tname:|Garg Simran\tScore:neutral:60.0\r',
#  'boxes:[1775, 275, 48, 58]\tname:\tScore:happy:42.0\r',
#  'boxes:[1581, 128, 52, 65]\tname:kanchan rer-te kumar th.\tScore:neutral:44.0\r',
#  'boxes:[1368, 823, 49, 61]\tname:Amar Sarkan 012\tScore:neutral:48.0\r',
#  'boxes:[930, 128, 42, 50]\tname:eitalisteiaetiiee rao\tScore:angry:42.0\r',
#  'boxes:[1575, 468, 51, 63]\tname:Nandsani St\tScore:neutral:53.0\r',
#  'boxes:[1580, 618, 42, 57]\tname:iMeena _ ) Neetu. ) Neetu.\tScore:neutral:44.0\r',
#  'boxes:[1771, 478, 58, 72]\tname:rey: Manish kumar\tScore:neutral:82.0\r',
#  'boxes:[1554, 321, 73, 89]\tname:Singh o18 Skit\tScore:sad:30.0\r',
#  'boxes:[783, 962, 51, 63]\tname:@isle, Velaltia. riva\tScore:happy:62.0\r',
#  'boxes:[521, 154, 37, 47]\tname:ote BSler|, 086\tScore:happy:57.99999999999999\r',
#  'boxes:[1792, 659, 44, 52]\tname:Sangam ele)\tScore:sad:53.0\r',
#  'boxes:[518, 811, 43, 50]\tname:Shrram Beis 098\tScore:neutral:56.00000000000001\r',
#  'boxes:[1148, 649, 28, 35]\tname:Kumar Sor Aditya foley\tScore:fear:45.0\r',
#  'Frame No:29\r',
#  'boxes:[88, 621, 56, 69]\tname:032 Harsh Rai\tScore:neutral:85.0\r',
#  'boxes:[731, 802, 50, 62]\tname:charms _bikky#l yar\tScore:neutral:53.0\r',
#  'boxes:[1377, 303, 43, 56]\tname:tls ==) 4 Kumar 078\tScore:neutral:80.0\r',
#  'boxes:[1790, 141, 40, 51]\tname:Shvam Shukla 102 a &\tScore:neutral:93.0\r',
#  'boxes:[296, 783, 50, 62]\tname:mel 9 4 Nif@stwAfahari\tScore:sad:47.0\r',
#  'boxes:[113, 311, 43, 53]\tname:Mehta iS latsell eile! iS latsell eile!\tScore:neutral:45.0\r',
#  'boxes:[1366, 821, 52, 62]\tname:Amar Sarkar 012\tScore:neutral:83.0\r',
#  'boxes:[1367, 457, 36, 45]\tname:\tScore:neutral:89.0\r',
#  'boxes:[725, 134, 58, 74]\tname:NAVNITA KLIMARI,\tScore:neutral:78.0\r',
#  "boxes:[1163, 287, 65, 78]\tname:HARSH 'CLIADMAA\tScore:neutral:70.0\r",
#  'boxes:[529, 510, 39, 50]\tname:Nitesh kum\tScore:happy:68.0\r',
#  'boxes:[936, 479, 43, 54]\tname:Boisigi ce. BS Trelste le taltl Tava\tScore:neutral:56.00000000000001\r',
#  'boxes:[83, 807, 57, 74]\tname:Neeraj Fels;\tScore:neutral:68.0\r',
#  'boxes:[116, 98, 63, 78]\tname:st Barnabas st Barnabas\tScore:happy:97.0\r',
#  'boxes:[1786, 819, 39, 45]\tname:Chaudhary "Sarita 044\tScore:neutral:49.0\r',
#  'boxes:[1137, 786, 76, 98]\tname:Ruchi | /Panse\tScore:sad:45.0\r',
#  'boxes:[302, 148, 50, 65]\tname:Pooja Vaday\tScore:neutral:59.0\r',
#  'boxes:[499, 642, 74, 90]\tname:| Gupta Sonu 104\tScore:surprise:31.0\r',
#  'boxes:[929, 278, 77, 100]\tname:Amit Kumar\tScore:neutral:84.0\r',
#  'boxes:[1147, 127, 50, 65]\tname:Mlsrivc ls Raunal\tScore:neutral:68.0\r',
#  'boxes:[930, 129, 43, 48]\tname:weltatitsleiaeliie ns rao\tScore:happy:36.0\r',
#  'boxes:[1372, 983, 45, 52]\tname:\tScore:neutral:65.0\r',
#  'boxes:[717, 289, 73, 92]\tname:|Garg Simran\tScore:neutral:60.0\r',
#  'boxes:[1575, 468, 50, 61]\tname:Nanton i SI shah\tScore:angry:39.0\r',
#  'boxes:[1775, 275, 48, 58]\tname:\tScore:happy:40.0\r',
#  'boxes:[1580, 128, 53, 65]\tname:etatelselal kumar certo th.\tScore:neutral:46.0\r',
#  'boxes:[783, 964, 51, 60]\tname:Girls isisitias iva\tScore:happy:62.0\r',
#  ...]

# %%
d = []
for i in data:
  d.append(i.split('\t'))
d
# Out:
# [['Frame No:1\r'],
#  ['boxes:[730, 803, 47, 57]',
#   'name:eset iceerl _bikkyl \\leskle-',
#   'Score:neutral:69.0\r'],
#  ['boxes:[295, 783, 50, 62]', 'name:4 NiteshAfahari', 'Score:sad:43.0\r'],
#  ['boxes:[1146, 127, 52, 63]', 'name:aseivris eanal', 'Score:sad:43.0\r'],
#  ['boxes:[1161, 288, 68, 79]', 'name:HARSH SHARMA', 'Score:neutral:80.0\r'],
#  ['boxes:[88, 621, 57, 70]', 'name:032 Harsch Rai', 'Score:neutral:79.0\r'],
#  ['boxes:[1791, 142, 39, 50]',
#   'name:Shyam is Flare 102 >',
#   'Score:neutral:92.0\r'],
#  ['boxes:[932, 480, 44, 53]',
#   'name:Shrivast BStrelst ls alll TVa',
#   'Score:neutral:65.0\r'],
#  ['boxes:[303, 150, 49, 62]', 'name:Pooja Yadav', 'Score:neutral:66.0\r'],
#  ['boxes:[1376, 303, 44, 55]',
#   'name:Tat-t-34 Kumar 078',
#   'Score:neutral:81.0\r'],
#  ['boxes:[928, 274, 77, 99]', 'name:Kumar Amit |', 'Score:neutral:76.0\r'],
#  ['boxes:[725, 134, 58, 74]', 'name:NAVNITA KLIMARI,', 'Score:neutral:78.0\r'],
#  ['boxes:[506, 644, 71, 86]', 'name:Gupta Sonu | 104', 'Score:sad:42.0\r'],
#  ['boxes:[1576, 618, 46, 59]',
#   'name:Meena mey.i0) Neetu.',
#   'Score:neutral:46.0\r'],
#  ['boxes:[529, 511, 38, 49]',
#   'name:Nitesh kum',
#   'Score:happy:57.99999999999999\r'],
#  ['boxes:[929, 129, 44, 50]',
#   'name:Oeihalisteiaetiiee rao',
#   'Score:angry:45.0\r'],
#  ['boxes:[114, 312, 41, 51]',
#   'name:jel eisell elat: Mehta Mehta',
#   'Score:neutral:49.0\r'],
#  ['boxes:[83, 807, 57, 74]', 'name:Neeraj Fels;', 'Score:neutral:68.0\r'],
#  ['boxes:[1785, 819, 39, 45]',
#   'name:[@istitielscin Sarita foy-.',
#   'Score:neutral:52.0\r'],
#  ['boxes:[1771, 477, 58, 71]',
#   'name:Manich alles t-| om ney-tc',
#   'Score:neutral:82.0\r'],
#  ['boxes:[1557, 318, 73, 92]', 'name:lalelal o18 AMKI', 'Score:happy:59.0\r'],
#  ['boxes:[116, 98, 63, 78]',
#   'name:st Barnabas st Barnabas',
#   'Score:happy:97.0\r'],
#  ['boxes:[1366, 822, 52, 63]', 'name:Amar 012 Sarkan', 'Score:neutral:53.0\r'],
#  ['boxes:[1368, 457, 35, 44]', 'name:', 'Score:neutral:93.0\r'],
#  ['boxes:[1138, 786, 75, 98]', 'name:Ruchi Panse', 'Score:happy:36.0\r'],
#  ['boxes:[1372, 983, 45, 52]', 'name:', 'Score:neutral:65.0\r'],
#  ['boxes:[1577, 468, 50, 62]',
#   'name:Nandsani SF cele',
#   'Score:neutral:53.0\r'],
#  ['boxes:[1581, 129, 53, 64]',
#   "name:a'e-tateistelal rey-te) kumar th",
#   'Score:neutral:53.0\r'],
#  ['boxes:[1775, 275, 46, 54]', 'name:', 'Score:sad:28.000000000000004\r'],
#  ['boxes:[717, 289, 72, 92]', 'name:1) Garg Simran |', 'Score:neutral:69.0\r'],
#  ['boxes:[783, 963, 51, 62]',
#   'name:@ite ieisitia iva',
#   'Score:happy:55.00000000000001\r'],
#  ['boxes:[521, 159, 39, 48]', 'name:[Sie Sagar 086', 'Score:happy:48.0\r'],
#  ['boxes:[518, 809, 42, 51]',
#   'name:1 Singh Sharam. 098',
#   'Score:neutral:70.0\r'],
#  ['boxes:[1792, 660, 42, 50]', 'name:Raja', 'Score:sad:49.0\r'],
#  ['boxes:[1150, 650, 30, 37]',
#   'name:"laste ween Aditya foley',
#   'Score:fear:35.0\r'],
#  ['Frame No:2\r'],
#  ['boxes:[730, 803, 47, 57]',
#   'name:eset iceerl _bikkyl \\leskle-',
#   'Score:neutral:69.0\r'],
#  ['boxes:[295, 783, 50, 62]', 'name:4 NiteshwAfahari', 'Score:sad:43.0\r'],
#  ['boxes:[1146, 127, 52, 63]', 'name:aseivris eanal', 'Score:sad:42.0\r'],
#  ['boxes:[1161, 288, 68, 79]', 'name:HARSH SHARMA', 'Score:neutral:80.0\r'],
#  ['boxes:[88, 621, 57, 70]', 'name:032 Harch Rai', 'Score:neutral:79.0\r'],
#  ['boxes:[1791, 143, 39, 49]',
#   'name:Shukis Shvam 10?',
#   'Score:neutral:89.0\r'],
#  ['boxes:[303, 150, 49, 62]', 'name:Pooja Yadav', 'Score:neutral:67.0\r'],
#  ['boxes:[1376, 303, 44, 55]',
#   'name:Tat-t-34 Kumar 078',
#   'Score:neutral:81.0\r'],
#  ['boxes:[928, 274, 77, 99]', 'name:Kumar Amit |', 'Score:neutral:76.0\r'],
#  ['boxes:[725, 134, 58, 74]', 'name:NAVNITA KLIMARI,', 'Score:neutral:78.0\r'],
#  ['boxes:[1576, 618, 46, 59]',
#   'name:Meena mey.i0) Neetu.',
#   'Score:neutral:46.0\r'],
#  ['boxes:[529, 511, 38, 49]', 'name:Nitesh kum', 'Score:happy:59.0\r'],
#  ['boxes:[505, 643, 72, 88]', 'name:|Gupta Sonu 104', 'Score:fear:48.0\r'],
#  ['boxes:[114, 312, 41, 51]',
#   'name:jel eisell elat: Mehta Mehta',
#   'Score:neutral:49.0\r'],
#  ['boxes:[83, 807, 57, 74]', 'name:Neeraj Fels;', 'Score:neutral:68.0\r'],
#  ['boxes:[1771, 477, 58, 71]',
#   'name:Manich ney-t: alles t-| om',
#   'Score:neutral:82.0\r'],
#  ['boxes:[1785, 819, 39, 45]',
#   'name:[@istitielscin Sarita foy-.',
#   'Score:neutral:52.0\r'],
#  ['boxes:[116, 98, 63, 78]',
#   'name:st Barnabas st Barnabas',
#   'Score:happy:97.0\r'],
#  ['boxes:[1366, 822, 52, 63]', 'name:Amar 012 Sarkan', 'Score:neutral:53.0\r'],
#  ['boxes:[1368, 457, 35, 44]', 'name:', 'Score:neutral:93.0\r'],
#  ['boxes:[1557, 317, 74, 91]', 'name:Telelal 018 AKI', 'Score:happy:45.0\r'],
#  ['boxes:[931, 128, 42, 49]',
#   'name:eltattsseiseliiee rao',
#   'Score:angry:33.0\r'],
#  ['boxes:[1138, 786, 75, 98]', 'name:Ruchi Panse', 'Score:happy:39.0\r'],
#  ['boxes:[1372, 983, 45, 52]', 'name:', 'Score:neutral:65.0\r'],
#  ['boxes:[1577, 468, 50, 62]',
#   'name:NanGsani St cele',
#   'Score:neutral:53.0\r'],
#  ['boxes:[932, 481, 45, 54]',
#   'name:SudhSnshu ) Shrivastova |',
#   'Score:neutral:56.99999999999999\r'],
#  ['boxes:[1581, 129, 53, 64]',
#   "name:a'e-tateistelal rey-te) kumar th.",
#   'Score:neutral:53.0\r'],
#  ['boxes:[717, 289, 72, 92]', 'name:1) Garg Simran |', 'Score:neutral:71.0\r'],
#  ['boxes:[1775, 275, 46, 54]', 'name:', 'Score:sad:28.000000000000004\r'],
#  ['boxes:[784, 962, 49, 63]',
#   'name:Gite, lelisitia riva',
#   'Score:happy:57.99999999999999\r'],
#  ['boxes:[522, 158, 38, 50]', 'name:Sagar [Chie 086', 'Score:happy:59.0\r'],
#  ['boxes:[518, 809, 42, 51]',
#   'name:1 Singh Sharam. 098',
#   'Score:neutral:70.0\r'],
#  ['boxes:[1792, 660, 42, 50]', 'name:Raja', 'Score:sad:49.0\r'],
#  ['boxes:[1150, 650, 30, 37]',
#   'name:"laste ween Aditya foley',
#   'Score:fear:34.0\r'],
#  ['Frame No:3\r'],
#  ['boxes:[295, 783, 50, 62]', 'name:4 NiteshwAfahari', 'Score:sad:42.0\r'],
#  ['boxes:[1146, 127, 52, 63]', 'name:aseivris eanal', 'Score:sad:42.0\r'],
#  ['boxes:[88, 621, 57, 70]', 'name:032 Harch Rai', 'Score:neutral:79.0\r'],
#  ['boxes:[731, 801, 46, 58]',
#   'name:_ bikkyl Yoaser-ines- a bvedleerl:',
#   'Score:neutral:47.0\r'],
#  ['boxes:[1791, 141, 39, 51]',
#   'name:Shvam Shukla 102 Yo',
#   'Score:neutral:91.0\r'],
#  ['boxes:[1375, 302, 45, 56]',
#   'name:ola t-34 Kumar 078',
#   'Score:neutral:88.0\r'],
#  ['boxes:[303, 150, 49, 62]', 'name:Pooja Yadav', 'Score:neutral:67.0\r'],
#  ['boxes:[1557, 318, 75, 92]', 'name:018 Singh AMKI', 'Score:happy:51.0\r'],
#  ['boxes:[725, 135, 59, 73]', 'name:KLMARI NAVNITA.', 'Score:neutral:81.0\r'],
#  ['boxes:[1366, 822, 52, 62]', 'name:Sarkar Amar 012', 'Score:neutral:59.0\r'],
#  ['boxes:[929, 276, 74, 97]', 'name:Kumar Amit', 'Score:neutral:72.0\r'],
#  ['boxes:[529, 511, 38, 49]', 'name:Nitesh kum', 'Score:happy:59.0\r'],
#  ['boxes:[505, 643, 72, 88]', 'name:| Gupta Sonu 104', 'Score:fear:48.0\r'],
#  ['boxes:[1166, 291, 64, 78]', 'name:SHARMA HARSH', 'Score:neutral:76.0\r'],
#  ['boxes:[114, 312, 41, 51]',
#   'name:jel eisell elat: Mehta Mehta',
#   'Score:neutral:49.0\r'],
#  ['boxes:[83, 807, 57, 74]', 'name:Neeraj Fels;', 'Score:neutral:68.0\r'],
#  ['boxes:[1771, 477, 58, 71]',
#   'name:Manich 048 alles t-| om',
#   'Score:neutral:82.0\r'],
#  ['boxes:[1785, 819, 39, 45]',
#   'name:[@istitielscin Sarita foy-.',
#   'Score:neutral:52.0\r'],
#  ['boxes:[116, 98, 63, 78]',
#   'name:st Barnabas st Barnabas',
#   'Score:happy:97.0\r'],
#  ['boxes:[1368, 457, 36, 45]', 'name:', 'Score:neutral:89.0\r'],
#  ['boxes:[931, 128, 42, 48]',
#   'name:irao -purushottama r',
#   'Score:angry:37.0\r'],
#  ['boxes:[1138, 786, 75, 98]', 'name:Ruchi Panse', 'Score:happy:39.0\r'],
#  ['boxes:[1372, 983, 45, 52]', 'name:', 'Score:neutral:65.0\r'],
#  ['boxes:[1577, 468, 50, 62]',
#   'name:NanGsani St cele',
#   'Score:neutral:53.0\r'],
#  ['boxes:[932, 481, 45, 54]',
#   'name:SudhSnshu ) Shrivastova |',
#   'Score:neutral:56.99999999999999\r'],
#  ['boxes:[717, 289, 72, 92]', 'name:1) Garg Simran |', 'Score:neutral:69.0\r'],
#  ['boxes:[1775, 275, 47, 55]', 'name:', 'Score:happy:28.999999999999996\r'],
#  ['boxes:[1581, 620, 41, 56]',
#   'name:i Meena  melon ) Neetu |',
#   'Score:neutral:44.0\r'],
#  ['boxes:[784, 962, 50, 63]',
#   'name:@ite Velsltla iva',
#   'Score:happy:56.99999999999999\r'],
#  ['boxes:[521, 159, 40, 49]',
#   'name:Sagar [Cltleir: 086',
#   'Score:happy:61.0\r'],
#  ['boxes:[1580, 128, 54, 69]',
#   'name:-kanchan kumar erie) th',
#   'Score:angry:42.0\r'],
#  ['boxes:[518, 809, 42, 51]',
#   'name:1 Singh Sharam. 098',
#   'Score:neutral:70.0\r'],
#  ['boxes:[1792, 660, 42, 50]', 'name:Raja', 'Score:sad:49.0\r'],
#  ['boxes:[1150, 649, 30, 38]',
#   'name:y Velie) Kumar Soni reley.',
#   'Score:fear:36.0\r'],
#  ['Frame No:4\r'],
#  ['boxes:[295, 783, 50, 62]', 'name:4 NiteshwAfahari', 'Score:sad:42.0\r'],
#  ['boxes:[1146, 127, 52, 63]', 'name:aseivris eanal', 'Score:sad:42.0\r'],
#  ['boxes:[88, 621, 57, 70]', 'name:032 Harch Rai', 'Score:neutral:79.0\r'],
#  ['boxes:[1791, 143, 38, 49]',
#   'name:Shukis Shvam 10?',
#   'Score:neutral:89.0\r'],
#  ['boxes:[731, 801, 46, 58]',
#   'name:_bikkyl lace laee a atleehy',
#   'Score:neutral:48.0\r'],
#  ['boxes:[1375, 302, 45, 56]',
#   'name:ola t-34 Kumar 078',
#   'Score:neutral:88.0\r'],
#  ['boxes:[1557, 318, 75, 92]', 'name:018 Singh AMKI', 'Score:happy:52.0\r'],
#  ['boxes:[303, 150, 49, 62]', 'name:Pooja Yadav', 'Score:neutral:67.0\r'],
#  ['boxes:[725, 135, 59, 73]', 'name:KLMARI NAVNITA.', 'Score:neutral:81.0\r'],
#  ['boxes:[1366, 822, 52, 62]', 'name:Sarkar Amar 012', 'Score:neutral:59.0\r'],
#  ['boxes:[113, 312, 42, 50]',
#   'name:jelaisell elated Mehta Mehta',
#   'Score:angry:37.0\r'],
#  ['boxes:[1772, 477, 57, 71]',
#   'name:Manich 048 alles t-| om',
#   'Score:neutral:83.0\r'],
#  ['boxes:[929, 279, 73, 95]',
#   'name:m40lesteial Amit K',
#   'Score:neutral:56.99999999999999\r'],
#  ['boxes:[505, 643, 72, 88]', 'name:| Gupta Sonu 104', 'Score:fear:48.0\r'],
#  ['boxes:[1166, 291, 64, 78]', 'name:SHARMA HARSH', 'Score:neutral:75.0\r'],
#  ['boxes:[83, 807, 57, 74]', 'name:Neeraj Fels;', 'Score:neutral:68.0\r'],
#  ['boxes:[1785, 819, 39, 45]',
#   'name:[@istitielscin Sarita foy-.',
#   'Score:neutral:52.0\r'],
#  ['boxes:[116, 98, 63, 78]',
#   'name:st Barnabas st Barnabas',
#   'Score:happy:97.0\r'],
#  ['boxes:[529, 511, 38, 49]',
#   'name:Nitesh kum',
#   'Score:happy:56.99999999999999\r'],
#  ['boxes:[1368, 457, 36, 45]', 'name:', 'Score:neutral:89.0\r'],
#  ['boxes:[931, 128, 42, 48]',
#   'name:irao -purushottama r',
#   'Score:angry:37.0\r'],
#  ['boxes:[1138, 786, 75, 98]', 'name:Ruchi Panse', 'Score:happy:39.0\r'],
#  ['boxes:[1372, 983, 45, 52]', 'name:', 'Score:neutral:65.0\r'],
#  ['boxes:[1577, 468, 50, 62]',
#   'name:NanGsani St cele',
#   'Score:neutral:53.0\r'],
#  ['boxes:[932, 481, 45, 54]',
#   'name:SudhSnshu ) Shrivastova |',
#   'Score:neutral:56.99999999999999\r'],
#  ['boxes:[717, 289, 72, 92]', 'name:1) Garg Simran |', 'Score:neutral:70.0\r'],
#  ['boxes:[1775, 275, 47, 55]', 'name:', 'Score:happy:28.999999999999996\r'],
#  ['boxes:[1581, 620, 41, 56]',
#   'name:i Meena  melon ) Neetu |',
#   'Score:neutral:44.0\r'],
#  ['boxes:[784, 962, 50, 63]',
#   'name:@ite Velsltla iva',
#   'Score:happy:56.99999999999999\r'],
#  ['boxes:[522, 158, 38, 48]', 'name:Cities iSlerid 086', 'Score:happy:54.0\r'],
#  ['boxes:[518, 809, 43, 52]', 'name:Singh Shivam 098', 'Score:neutral:64.0\r'],
#  ['boxes:[1580, 128, 54, 69]',
#   'name:-kanchan kumar erie) th',
#   'Score:angry:43.0\r'],
#  ['boxes:[1792, 660, 42, 50]', 'name:Raja', 'Score:sad:49.0\r'],
#  ['boxes:[1150, 649, 30, 38]',
#   'name:y Velie) Kumar Soni reley.',
#   'Score:fear:36.0\r'],
#  ['Frame No:5\r'],
#  ['boxes:[295, 783, 50, 62]', 'name:4 NiteshwAfahari', 'Score:sad:42.0\r'],
#  ['boxes:[88, 621, 57, 70]', 'name:032 Harch Rai', 'Score:neutral:79.0\r'],
#  ['boxes:[1162, 288, 67, 78]', 'name:HARSH CUIAPMA', 'Score:neutral:72.0\r'],
#  ['boxes:[1791, 143, 38, 49]',
#   'name:Shukis Shvam 10?',
#   'Score:neutral:89.0\r'],
#  ['boxes:[731, 801, 46, 58]',
#   'name:_bikkyl facste-laee- ia adleehry',
#   'Score:neutral:48.0\r'],
#  ['boxes:[726, 135, 58, 74]',
#   'name:rrAVs\\ing-@ KLMARI',
#   'Score:neutral:88.0\r'],
#  ['boxes:[1375, 302, 45, 56]',
#   'name:ola t-34 Kumar 078',
#   'Score:neutral:88.0\r'],
#  ['boxes:[303, 150, 49, 62]', 'name:Pooja Yadav', 'Score:neutral:67.0\r'],
#  ['boxes:[1558, 319, 74, 90]', 'name:Singh 018 ATTK)', 'Score:happy:53.0\r'],
#  ['boxes:[1366, 822, 52, 62]', 'name:Sarkar Amar 012', 'Score:neutral:59.0\r'],
#  ['boxes:[113, 312, 42, 50]',
#   'name:jelaisell elated Mehta Mehta',
#   'Score:angry:37.0\r'],
#  ['boxes:[1772, 477, 57, 71]',
#   'name:Manich 048 alles t-| om',
#   'Score:neutral:83.0\r'],
#  ['boxes:[929, 279, 73, 95]',
#   'name:a 4tlesteial Amit K',
#   'Score:neutral:56.99999999999999\r'],
#  ['boxes:[83, 807, 57, 74]', 'name:Neeraj Fels;', 'Score:neutral:68.0\r'],
#  ['boxes:[1785, 819, 39, 45]',
#   'name:[@istitielscin Sarita foy-.',
#   'Score:neutral:52.0\r'],
#  ['boxes:[116, 98, 63, 78]',
#   'name:st Barnabas st Barnabas',
#   'Score:happy:97.0\r'],
#  ['boxes:[529, 511, 38, 49]',
#   'name:Nitesh kum',
#   'Score:happy:56.99999999999999\r'],
#  ['boxes:[1368, 457, 35, 44]', 'name:', 'Score:neutral:93.0\r'],
#  ['boxes:[503, 642, 74, 89]', 'name:Gupta Sonu | 104', 'Score:fear:36.0\r'],
#  ['boxes:[1138, 785, 77, 99]', 'name:Ruchi Panse', 'Score:happy:33.0\r'],
#  ['boxes:[931, 128, 42, 48]',
#   'name:irao -purushottama r',
#   'Score:angry:37.0\r'],
#  ['boxes:[1372, 983, 45, 52]', 'name:', 'Score:neutral:65.0\r'],
#  ['boxes:[932, 481, 45, 54]',
#   'name:SudhSnshu ) Shrivastova |',
#   'Score:neutral:56.99999999999999\r'],
#  ['boxes:[717, 289, 72, 92]', 'name:1) Garg Simran |', 'Score:neutral:70.0\r'],
#  ['boxes:[1148, 128, 50, 65]', 'name:Kumawat Kainal', 'Score:sad:42.0\r'],
#  ['boxes:[1775, 275, 47, 55]', 'name:', 'Score:happy:27.0\r'],
#  ['boxes:[1578, 470, 50, 61]', 'name:Nan@ani Shz', 'Score:neutral:68.0\r'],
#  ['boxes:[1581, 620, 41, 56]',
#   'name:i Meena  melon ) Neetu |',
#   'Score:neutral:44.0\r'],
#  ['boxes:[784, 962, 50, 63]',
#   'name:@ite Velsltla iva',
#   'Score:happy:56.00000000000001\r'],
#  ['boxes:[522, 158, 38, 48]', 'name:Cities ilerid 086', 'Score:happy:53.0\r'],
#  ['boxes:[518, 809, 43, 52]', 'name:Singh Shivam 098', 'Score:neutral:64.0\r'],
#  ['boxes:[1580, 128, 54, 69]',
#   'name:-kanchan kumar erie) th',
#   'Score:angry:43.0\r'],
#  ['boxes:[1792, 660, 42, 50]', 'name:Raja', 'Score:sad:49.0\r'],
#  ['boxes:[1150, 649, 30, 38]',
#   'name:y Velie) Kumar Soni reley.',
#   'Score:fear:36.0\r'],
#  ['Frame No:6\r'],
#  ['boxes:[932, 278, 72, 97]', 'name:Kumar', 'Score:neutral:61.0\r'],
#  ['boxes:[88, 621, 57, 70]', 'name:032 Harch Rai', 'Score:neutral:79.0\r'],
#  ['boxes:[1162, 288, 67, 78]', 'name:HARSH CUIAPMA', 'Score:neutral:71.0\r'],
#  ['boxes:[295, 783, 50, 63]', 'name:mele Nifeewestshari', 'Score:sad:38.0\r'],
#  ['boxes:[1791, 143, 38, 49]',
#   'name:Shukla Shvam 10?',
#   'Score:neutral:88.0\r'],
#  ['boxes:[1377, 304, 43, 54]',
#   'name:tis = 738 Kumar Kumar',
#   'Score:neutral:79.0\r'],
#  ['boxes:[731, 801, 46, 58]',
#   'name:_bikkyl facste-laee- ia adleehry',
#   'Score:neutral:48.0\r'],
#  ['boxes:[726, 135, 58, 74]',
#   'name:rrAVs\\ing-@ KLMARI',
#   'Score:neutral:89.0\r'],
#  ['boxes:[303, 150, 49, 62]', 'name:Pooja Yadav', 'Score:neutral:67.0\r'],
#  ['boxes:[1366, 822, 52, 61]', 'name:Sarkar Amar 012', 'Score:neutral:90.0\r'],
#  ['boxes:[113, 312, 42, 50]',
#   'name:jelaisell elated Mehta Mehta',
#   'Score:angry:37.0\r'],
#  ['boxes:[1772, 477, 57, 71]',
#   'name:Manich 048 alles t-| om',
#   'Score:neutral:83.0\r'],
#  ['boxes:[83, 807, 57, 74]', 'name:Neeraj Fels;', 'Score:neutral:68.0\r'],
#  ['boxes:[1785, 819, 39, 45]',
#   'name:[@istitielscin Sarita foy-.',
#   'Score:neutral:52.0\r'],
#  ['boxes:[116, 98, 63, 78]',
#   'name:st Barnabas st Barnabas',
#   'Score:happy:97.0\r'],
#  ['boxes:[1557, 318, 74, 92]',
#   'name:o18 mS lalelal AQIKI',
#   'Score:happy:74.0\r'],
#  ['boxes:[529, 511, 38, 49]',
#   'name:Nitesh kum',
#   'Score:happy:56.99999999999999\r'],
#  ['boxes:[1368, 457, 36, 45]', 'name:', 'Score:neutral:88.0\r'],
#  ['boxes:[503, 642, 74, 89]', 'name:Gupta Sonu | 104', 'Score:sad:37.0\r'],
#  ['boxes:[1138, 785, 77, 99]', 'name:Ruchi Panse', 'Score:happy:32.0\r'],
#  ['boxes:[931, 128, 42, 48]',
#   'name:irao -purushottama r',
#   'Score:angry:37.0\r'],
#  ['boxes:[1372, 983, 45, 52]', 'name:', 'Score:neutral:65.0\r'],
#  ['boxes:[932, 481, 45, 54]',
#   'name:SudhSnshu ) Shrivastova |',
#   'Score:neutral:56.99999999999999\r'],
#  ['boxes:[717, 289, 72, 92]', 'name:1) Garg Simran |', 'Score:neutral:69.0\r'],
#  ['boxes:[1148, 128, 50, 65]', 'name:Kumawat Kainal', 'Score:sad:42.0\r'],
#  ['boxes:[1578, 470, 50, 61]', 'name:Nandani Shz', 'Score:neutral:68.0\r'],
#  ['boxes:[1774, 274, 48, 57]', 'name:', 'Score:sad:32.0\r'],
#  ['boxes:[784, 964, 50, 61]',
#   'name:Gite, lelsitia iva',
#   'Score:happy:56.99999999999999\r'],
#  ['boxes:[518, 809, 43, 52]', 'name:Singh Shivam 098', 'Score:neutral:64.0\r'],
#  ['boxes:[1578, 618, 44, 59]',
#   'name:Meena Neetu! mey-0)',
#   'Score:neutral:51.0\r'],
#  ['boxes:[1580, 128, 54, 69]',
#   'name:-kanchan kumar erie) th',
#   'Score:angry:43.0\r'],
#  ['boxes:[522, 157, 38, 48]',
#   'name:[Citiei = Siecle 086',
#   'Score:happy:28.000000000000004\r'],
#  ['boxes:[1792, 660, 42, 50]', 'name:Raja', 'Score:sad:49.0\r'],
#  ['boxes:[1149, 648, 30, 40]',
#   'name:Kumar Soni Seley Aditya',
#   'Score:sad:35.0\r'],
#  ['Frame No:7\r'],
#  ['boxes:[89, 621, 56, 69]', 'name:032 Harsh Rai', 'Score:neutral:79.0\r'],
#  ['boxes:[932, 277, 75, 97]', 'name:Amit Miumar', 'Score:neutral:74.0\r'],
#  ['boxes:[1162, 288, 67, 78]', 'name:HARSH CUIAPMA', 'Score:neutral:71.0\r'],
#  ['boxes:[113, 312, 43, 51]',
#   'name:jer ecisell eilat: Mehta Mehta',
#   'Score:neutral:59.0\r'],
#  ['boxes:[295, 783, 50, 63]', 'name:mele Nifeewestshari', 'Score:sad:40.0\r'],
#  ['boxes:[1377, 304, 43, 55]',
#   'name:Tl t-34 Kumar 078',
#   'Score:neutral:81.0\r'],
#  ['boxes:[1791, 143, 38, 49]',
#   'name:Shukla Shvam 10?',
#   'Score:neutral:88.0\r'],
#  ['boxes:[731, 801, 47, 58]',
#   'name:Be tay leerleesericern',
#   'Score:neutral:59.0\r'],
#  ['boxes:[726, 135, 58, 74]',
#   'name:rrAVs\\ing-@ KLMARI',
#   'Score:neutral:88.0\r'],
#  ['boxes:[303, 150, 49, 62]', 'name:Pooja Yadav', 'Score:neutral:67.0\r'],
#  ['boxes:[83, 807, 57, 74]', 'name:Neeraj Fels;', 'Score:neutral:68.0\r'],
#  ['boxes:[1772, 477, 57, 71]',
#   'name:Manich 048 alles | am',
#   'Score:neutral:82.0\r'],
#  ['boxes:[1785, 819, 39, 45]',
#   'name:[@istitielscin Sarita foy-.',
#   'Score:neutral:52.0\r'],
#  ['boxes:[1367, 822, 51, 62]',
#   'name:Sarkar Amar. 012',
#   'Score:neutral:61.0\r'],
#  ['boxes:[116, 98, 63, 78]',
#   'name:st Barnabas st Barnabas',
#   'Score:happy:97.0\r'],
#  ['boxes:[1557, 318, 74, 92]',
#   'name:o18 om lalelal AQIKI',
#   'Score:happy:74.0\r'],
#  ['boxes:[529, 511, 38, 49]',
#   'name:Nitesh kum',
#   'Score:happy:56.99999999999999\r'],
#  ['boxes:[1368, 457, 36, 45]', 'name:', 'Score:neutral:88.0\r'],
#  ['boxes:[501, 640, 74, 92]', 'name:Gupta Sonu Sey!', 'Score:fear:35.0\r'],
#  ['boxes:[1138, 785, 77, 99]', 'name:Ruchi Panse', 'Score:happy:32.0\r'],
#  ['boxes:[931, 128, 42, 48]',
#   'name:irao -purushottama r',
#   'Score:angry:37.0\r'],
#  ['boxes:[1372, 983, 45, 52]', 'name:', 'Score:neutral:65.0\r'],
#  ['boxes:[1582, 129, 52, 65]',
#   'name:"et ateistelal rey-te) kumar th.',
#   'Score:neutral:37.0\r'],
#  ['boxes:[932, 481, 45, 54]',
#   'name:SudhSnshu ) Shrivastova |',
#   'Score:neutral:56.99999999999999\r'],
#  ['boxes:[717, 289, 72, 92]', 'name:1) Garg Simran |', 'Score:neutral:69.0\r'],
#  ['boxes:[1775, 274, 47, 57]', 'name:', 'Score:sad:32.0\r'],
#  ['boxes:[1148, 128, 50, 65]', 'name:Kumawat Kainal', 'Score:sad:42.0\r'],
#  ['boxes:[1578, 470, 50, 61]', 'name:Nandani Shz', 'Score:neutral:68.0\r'],
#  ['boxes:[784, 964, 50, 61]',
#   'name:Gite, leisitia iva',
#   'Score:happy:57.99999999999999\r'],
#  ['boxes:[518, 809, 43, 52]', 'name:Singh Shivam 098', 'Score:neutral:64.0\r'],
#  ['boxes:[1578, 618, 44, 59]',
#   'name:Meena Neetu! mey-0)',
#   'Score:neutral:51.0\r'],
#  ['boxes:[522, 157, 38, 48]',
#   'name:[Citiei = Siecle 086',
#   'Score:happy:27.0\r'],
#  ['boxes:[1792, 660, 42, 50]', 'name:Raja', 'Score:sad:49.0\r'],
#  ['boxes:[1149, 648, 30, 40]',
#   'name:Kumar Soni Seley Aditya',
#   'Score:sad:35.0\r'],
#  ['Frame No:8\r'],
#  ['boxes:[89, 621, 56, 69]', 'name:032 Harsh Rai', 'Score:neutral:79.0\r'],
#  ['boxes:[932, 277, 75, 97]', 'name:Amit Miumar', 'Score:neutral:74.0\r'],
#  ['boxes:[113, 312, 43, 51]',
#   'name:jer ecisell eilat: Mehta Mehta',
#   'Score:neutral:60.0\r'],
#  ['boxes:[295, 783, 50, 63]', 'name:mele Nifeewestshari', 'Score:sad:40.0\r'],
#  ['boxes:[1377, 304, 43, 55]',
#   'name:Tl t-34 Kumar 078',
#   'Score:neutral:81.0\r'],
#  ['boxes:[731, 801, 47, 58]',
#   'name:Be tay llesllaeseriaerch',
#   'Score:neutral:59.0\r'],
#  ['boxes:[1791, 141, 39, 51]',
#   'name:Shvam Shukis 102',
#   'Score:neutral:92.0\r'],
#  ['boxes:[726, 135, 58, 74]',
#   'name:rrAVs\\ing-@ KLMARI',
#   'Score:neutral:88.0\r'],
#  ['boxes:[303, 150, 49, 62]', 'name:Pooja Yadav', 'Score:neutral:67.0\r'],
#  ['boxes:[1368, 457, 35, 45]', 'name:', 'Score:neutral:88.0\r'],
#  ['boxes:[1786, 819, 38, 45]',
#   'name:Chaudhary "Sarita 044',
#   'Score:neutral:40.0\r'],
#  ['boxes:[83, 807, 57, 74]', 'name:Neeraj Fels;', 'Score:neutral:68.0\r'],
#  ['boxes:[1772, 477, 57, 71]',
#   'name:Manich 048 alles | am',
#   'Score:neutral:82.0\r'],
#  ['boxes:[1367, 822, 51, 62]',
#   'name:Sarkar Amar. 012',
#   'Score:neutral:61.0\r'],
#  ['boxes:[116, 98, 63, 78]',
#   'name:st Barnabas st Barnabas',
#   'Score:happy:97.0\r'],
#  ['boxes:[1167, 291, 63, 76]', 'name:SHARMA LARSL', 'Score:neutral:77.0\r'],
#  ['boxes:[1557, 318, 74, 92]',
#   'name:o18 om lalelal AQIKI',
#   'Score:happy:74.0\r'],
#  ['boxes:[529, 511, 38, 49]',
#   'name:Nitesh kum',
#   'Score:happy:56.99999999999999\r'],
#  ['boxes:[501, 640, 74, 93]', 'name:Sonu Gupta 104', 'Score:sad:39.0\r'],
#  ['boxes:[931, 128, 42, 48]',
#   'name:irao -purushottama r',
#   'Score:angry:37.0\r'],
#  ['boxes:[1372, 983, 45, 52]', 'name:', 'Score:neutral:65.0\r'],
#  ['boxes:[1138, 786, 75, 98]', 'name:Ruchi Panse', 'Score:happy:37.0\r'],
#  ['boxes:[1582, 129, 52, 65]',
#   'name:"et ateistelal rey-te) kumar th.',
#   'Score:neutral:37.0\r'],
#  ['boxes:[523, 157, 37, 47]', 'name:SHleris Che 086', 'Score:happy:32.0\r'],
#  ['boxes:[717, 290, 72, 91]', 'name:Garg Thaales ial', 'Score:neutral:63.0\r'],
#  ['boxes:[1775, 274, 47, 57]', 'name:', 'Score:sad:33.0\r'],
#  ['boxes:[1148, 128, 50, 65]', 'name:Kumawat Kainal', 'Score:sad:42.0\r'],
#  ['boxes:[1578, 470, 50, 61]', 'name:Nandani Shz', 'Score:neutral:68.0\r'],
#  ['boxes:[933, 480, 44, 55]',
#   'name:Sudh4nshu Shrivastava',
#   'Score:neutral:65.0\r'],
#  ['boxes:[784, 964, 50, 61]',
#   'name:Gite, leisitia iva',
#   'Score:happy:57.99999999999999\r'],
#  ['boxes:[1578, 618, 44, 59]',
#   'name:Meena Neetu! mey-0)',
#   'Score:neutral:51.0\r'],
#  ['boxes:[519, 809, 43, 51]',
#   'name:Shrram )Singh 098',
#   'Score:neutral:63.0\r'],
#  ['boxes:[1792, 660, 42, 50]', 'name:Raja', 'Score:sad:49.0\r'],
#  ['boxes:[1149, 648, 30, 40]',
#   'name:Kumar Soni Seley Aditya',
#   'Score:sad:35.0\r'],
#  ['Frame No:9\r'],
#  ['boxes:[90, 622, 55, 68]', 'name:032 Harsh Rai', 'Score:neutral:80.0\r'],
#  ['boxes:[113, 312, 43, 51]',
#   'name:jel aisell elal: Mehta Mehta',
#   'Score:neutral:60.0\r'],
#  ['boxes:[295, 783, 50, 63]', 'name:mele Nifeewestshari', 'Score:sad:40.0\r'],
#  ['boxes:[1377, 304, 43, 55]',
#   'name:Tl t-34 Kumar 078',
#   'Score:neutral:81.0\r'],
#  ['boxes:[932, 277, 75, 100]', 'name:Amit Kumar', 'Score:neutral:69.0\r'],
#  ['boxes:[1791, 144, 38, 48]',
#   'name:Shyam Shukla 102 vo',
#   'Score:neutral:87.0\r'],
#  ['boxes:[731, 801, 47, 58]',
#   'name:Be tay leslaeseriaeerch',
#   'Score:neutral:59.0\r'],
#  ['boxes:[726, 135, 58, 73]',
#   'name:NAVNITA | KIIMARI',
#   'Score:neutral:77.0\r'],
#  ['boxes:[1575, 619, 47, 59]',
#   'name:1 Meena Rey.10) _Neetu',
#   'Score:neutral:55.00000000000001\r'],
#  ['boxes:[1367, 824, 49, 60]', 'name:Amar Sarkan 012', 'Score:neutral:53.0\r'],
#  ['boxes:[303, 150, 49, 62]', 'name:Pooja Yadav', 'Score:neutral:67.0\r'],
#  ['boxes:[1368, 457, 35, 45]', 'name:', 'Score:neutral:88.0\r'],
#  ['boxes:[1786, 819, 38, 45]',
#   'name:Chaudhary "Sarita 044',
#   'Score:neutral:41.0\r'],
#  ['boxes:[83, 807, 57, 74]', 'name:Neeraj Fels;', 'Score:neutral:68.0\r'],
#  ['boxes:[1772, 477, 57, 71]',
#   'name:Manich 048 alles | am',
#   'Score:neutral:82.0\r'],
#  ['boxes:[116, 98, 63, 78]',
#   'name:st Barnabas st Barnabas',
#   'Score:happy:97.0\r'],
#  ['boxes:[1167, 291, 63, 76]', 'name:SHARMA LARSL', 'Score:neutral:77.0\r'],
#  ['boxes:[1557, 318, 74, 92]',
#   'name:o18 om lalelal AQIKI',
#   'Score:happy:74.0\r'],
#  ['boxes:[501, 640, 74, 93]', 'name:Sonu Gupta 104', 'Score:sad:39.0\r'],
#  ['boxes:[529, 511, 39, 49]', 'name:Nitesh kum', 'Score:happy:60.0\r'],
#  ['boxes:[1138, 785, 77, 100]', 'name:Ruchi | Panse', 'Score:happy:45.0\r'],
#  ['boxes:[1372, 983, 45, 52]', 'name:', 'Score:neutral:65.0\r'],
#  ['boxes:[1582, 129, 52, 65]',
#   'name:"et ateistelal rey-te) kumar th.',
#   'Score:neutral:37.0\r'],
#  ['boxes:[930, 128, 43, 49]',
#   'name:oetllaltisteiaetiie ns rao',
#   'Score:angry:32.0\r'],
#  ['boxes:[522, 157, 38, 46]', 'name:Che Sagar 086', 'Score:happy:43.0\r'],
#  ['boxes:[717, 290, 72, 91]', 'name:Garg Thaales ial', 'Score:neutral:63.0\r'],
#  ['boxes:[1775, 276, 47, 56]', 'name:', 'Score:happy:33.0\r'],
#  ['boxes:[1148, 128, 50, 65]', 'name:Kumawat Kainal', 'Score:sad:42.0\r'],
#  ['boxes:[933, 480, 44, 55]',
#   'name:Sudh4nshu_ Shrivastava',
#   'Score:neutral:66.0\r'],
#  ['boxes:[1577, 470, 50, 60]', 'name:Nandsni St hah', 'Score:neutral:70.0\r'],
#  ['boxes:[784, 964, 50, 61]', 'name:Gite, leisitia iva', 'Score:happy:62.0\r'],
#  ['boxes:[1149, 650, 30, 38]',
#   'name:Kumar feley-a Aditya Teta]',
#   'Score:fear:33.0\r'],
#  ['boxes:[519, 809, 43, 51]',
#   'name:Shrram )Singh 098',
#   'Score:neutral:61.0\r'],
#  ['boxes:[1792, 660, 42, 50]', 'name:Raja', 'Score:sad:49.0\r'],
#  ['Frame No:10\r'],
#  ['boxes:[90, 622, 55, 68]', 'name:032 Harsh Rai', 'Score:neutral:80.0\r'],
#  ['boxes:[933, 279, 75, 94]', 'name:Kumar Amit', 'Score:neutral:76.0\r'],
#  ['boxes:[113, 312, 43, 51]',
#   'name:jel aisell elal: Mehta Mehta',
#   'Score:neutral:60.0\r'],
#  ['boxes:[1376, 304, 44, 55]',
#   'name:Tl t-34 Kumar 078',
#   'Score:neutral:80.0\r'],
#  ['boxes:[295, 783, 51, 62]',
#   'name:mely 9 4 NitstwAfahari',
#   'Score:sad:46.0\r'],
#  ['boxes:[731, 801, 47, 58]',
#   'name:Be tay lleslaeseriaerchn',
#   'Score:neutral:59.0\r'],
#  ['boxes:[1791, 141, 39, 51]',
#   'name:Shvam Shukis 102',
#   'Score:neutral:93.0\r'],
#  ['boxes:[726, 135, 58, 73]',
#   'name:NAVNITA | KIIMARI',
#   'Score:neutral:76.0\r'],
#  ['boxes:[1575, 619, 47, 59]',
#   'name:1 Meena Rey.10) _Neetu',
#   'Score:neutral:55.00000000000001\r'],
#  ['boxes:[1367, 824, 49, 60]', 'name:Amar Sarkan 012', 'Score:neutral:54.0\r'],
#  ['boxes:[303, 150, 49, 62]', 'name:Pooja Yadav', 'Score:neutral:67.0\r'],
#  ['boxes:[1368, 457, 35, 45]', 'name:', 'Score:neutral:88.0\r'],
#  ['boxes:[1786, 819, 38, 45]',
#   'name:Chaudhary "Sarita 044',
#   'Score:neutral:41.0\r'],
#  ['boxes:[83, 807, 57, 74]', 'name:Neeraj Fels;', 'Score:neutral:68.0\r'],
#  ['boxes:[1772, 477, 57, 71]',
#   'name:Manich 048 alles | am',
#   'Score:neutral:82.0\r'],
#  ['boxes:[1167, 291, 63, 76]', 'name:SHARMA LARSL', 'Score:neutral:78.0\r'],
#  ['boxes:[116, 98, 63, 78]',
#   'name:st Barnabas st Barnabas',
#   'Score:happy:97.0\r'],
#  ['boxes:[1559, 319, 73, 90]', 'name:otislelal o18 ,', 'Score:happy:61.0\r'],
#  ['boxes:[500, 641, 74, 92]', 'name:Sonu Gupta 104', 'Score:angry:30.0\r'],
#  ['boxes:[529, 511, 39, 49]', 'name:Nitesh kum', 'Score:happy:60.0\r'],
#  ['boxes:[1775, 276, 47, 57]', 'name:', 'Score:sad:28.999999999999996\r'],
#  ['boxes:[1138, 785, 77, 100]', 'name:Ruchi | Panse', 'Score:happy:45.0\r'],
#  ['boxes:[1372, 983, 45, 52]', 'name:', 'Score:neutral:65.0\r'],
#  ['boxes:[1582, 129, 51, 65]',
#   'name:kanchan kumar rer-te th...',
#   'Score:neutral:42.0\r'],
#  ['boxes:[930, 128, 43, 49]',
#   'name:oetllaltisteiaetiie ns rao',
#   'Score:angry:33.0\r'],
#  ['boxes:[1148, 127, 50, 66]', 'name:Kumawat Runal', 'Score:sad:39.0\r'],
#  ['boxes:[717, 290, 72, 91]', 'name:Garg Thaales ial', 'Score:neutral:63.0\r'],
#  ['boxes:[1577, 469, 50, 61]', 'name:Ve 2S oe', 'Score:neutral:70.0\r'],
#  ['boxes:[933, 480, 44, 55]',
#   'name:Sudh4nshu Shrivastava',
#   'Score:neutral:66.0\r'],
#  ['boxes:[1149, 650, 30, 38]',
#   'name:Kumar feley-a Aditya Teta]',
#   'Score:fear:33.0\r'],
#  ['boxes:[784, 964, 50, 61]', 'name:@ite, lelsitia iva', 'Score:happy:67.0\r'],
#  ['boxes:[522, 155, 37, 49]', 'name:Chet Sagar (O}s{.)', 'Score:happy:70.0\r'],
#  ['boxes:[1792, 660, 42, 50]', 'name:Raja', 'Score:sad:49.0\r'],
#  ['boxes:[519, 809, 43, 52]',
#   'name:1 Singh Sham. 098',
#   'Score:neutral:63.0\r'],
#  ['Frame No:11\r'],
#  ['boxes:[90, 622, 55, 68]', 'name:032 Harsh Rai', 'Score:neutral:80.0\r'],
#  ['boxes:[113, 312, 43, 51]',
#   'name:jel aisell elal: Mehta Mehta',
#   'Score:neutral:60.0\r'],
#  ['boxes:[932, 277, 75, 100]', 'name:7 \\eslia Kumar', 'Score:neutral:70.0\r'],
#  ['boxes:[1376, 304, 44, 55]',
#   'name:Tl t-34 Kumar 078',
#   'Score:neutral:79.0\r'],
#  ['boxes:[295, 783, 51, 62]',
#   'name:mely 9 4 NitstwAfahari',
#   'Score:sad:46.0\r'],
#  ['boxes:[731, 801, 47, 58]',
#   'name:Be tay lleslaeseriaerchn',
#   'Score:neutral:59.0\r'],
#  ['boxes:[1791, 141, 39, 51]',
#   'name:Shvam Shukis 102',
#   'Score:neutral:93.0\r'],
#  ['boxes:[726, 135, 58, 73]',
#   'name:NAVNITA | KIIMARI',
#   'Score:neutral:77.0\r'],
#  ['boxes:[1575, 619, 47, 59]',
#   'name:1 Meena Rey.10) _Neetu',
#   'Score:neutral:55.00000000000001\r'],
#  ['boxes:[1367, 824, 49, 60]', 'name:Amar Sarkan 012', 'Score:neutral:53.0\r'],
#  ['boxes:[1368, 457, 35, 45]', 'name:', 'Score:neutral:88.0\r'],
#  ['boxes:[1772, 476, 57, 72]',
#   'name:Manich 048 loirmear',
#   'Score:neutral:73.0\r'],
#  ['boxes:[1786, 819, 38, 45]',
#   'name:Chaudhary "Sarita 044',
#   'Score:neutral:41.0\r'],
#  ['boxes:[83, 807, 57, 74]', 'name:Neeraj Fels;', 'Score:neutral:68.0\r'],
#  ['boxes:[116, 98, 63, 78]',
#   'name:st Barnabas st Barnabas',
#   'Score:happy:97.0\r'],
#  ['boxes:[1559, 319, 73, 90]', 'name:otislelal o18 ,', 'Score:happy:62.0\r'],
#  ['boxes:[500, 641, 74, 92]', 'name:Sonu Gupta 104', 'Score:angry:30.0\r'],
#  ['boxes:[1162, 288, 65, 79]', 'name:HARSH SHARMA', 'Score:neutral:76.0\r'],
#  ['boxes:[529, 511, 39, 49]', 'name:Nitesh kum', 'Score:happy:61.0\r'],
#  ['boxes:[303, 149, 49, 63]', 'name:Pooja Yadav', 'Score:neutral:61.0\r'],
#  ['boxes:[1775, 276, 47, 57]', 'name:', 'Score:happy:28.000000000000004\r'],
#  ['boxes:[933, 482, 44, 54]',
#   'name:Shrivaet  SodhSnchu TV3',
#   'Score:neutral:42.0\r'],
#  ['boxes:[1137, 787, 76, 97]', 'name:-Ruchi Panse', 'Score:happy:38.0\r'],
#  ['boxes:[1372, 983, 45, 52]', 'name:', 'Score:neutral:65.0\r'],
#  ['boxes:[930, 128, 43, 49]',
#   'name:oetllaltisteiaetiie ns rao',
#   'Score:angry:33.0\r'],
#  ['boxes:[1148, 127, 50, 66]', 'name:Kumawat Runal', 'Score:sad:39.0\r'],
#  ['boxes:[717, 290, 72, 91]', 'name:Garg Thaales ial', 'Score:neutral:59.0\r'],
#  ['boxes:[1581, 128, 52, 65]',
#   'name:i "eatelst lat rer-te kumar th.',
#   'Score:neutral:46.0\r'],
#  ['boxes:[1577, 469, 50, 61]', 'name:Ve 2S oe', 'Score:neutral:70.0\r'],
#  ['boxes:[1149, 650, 30, 38]',
#   'name:Kumar feley-a Aditya Teta]',
#   'Score:fear:33.0\r'],
#  ['boxes:[784, 964, 50, 61]', 'name:@ite, lelsitia iva', 'Score:happy:67.0\r'],
#  ['boxes:[522, 155, 37, 49]', 'name:Chet Sagar (O}s{.)', 'Score:happy:72.0\r'],
#  ['boxes:[1792, 660, 42, 50]', 'name:Raja', 'Score:sad:49.0\r'],
#  ['boxes:[519, 809, 43, 52]',
#   'name:1 Singh Sham. 098',
#   'Score:neutral:63.0\r'],
#  ['Frame No:12\r'],
#  ['boxes:[89, 622, 56, 68]', 'name:032 Harsh Rai', 'Score:neutral:84.0\r'],
#  ['boxes:[1376, 304, 44, 55]',
#   'name:Tl t-34 Kumar 078',
#   'Score:neutral:79.0\r'],
#  ['boxes:[932, 277, 77, 100]', 'name:yYestia Kumar', 'Score:neutral:74.0\r'],
#  ['boxes:[295, 783, 51, 62]',
#   'name:mely 9 4 NitstwAfahari',
#   'Score:sad:46.0\r'],
#  ['boxes:[731, 802, 46, 57]',
#   'name:Bel tay sSlieertlc Ser leee ae',
#   'Score:neutral:56.99999999999999\r'],
#  ['boxes:[726, 135, 58, 73]',
#   'name:NAVNITA | KIIMARI',
#   'Score:neutral:77.0\r'],
#  ['boxes:[1367, 824, 49, 60]', 'name:Amar Sarkan 012', 'Score:neutral:53.0\r'],
#  ['boxes:[1790, 141, 40, 51]',
#   'name:Shvam Shukis 102',
#   'Score:neutral:93.0\r'],
#  ['boxes:[1771, 476, 58, 72]',
#   'name:Manish 048 loormar',
#   'Score:neutral:87.0\r'],
#  ['boxes:[1368, 457, 35, 45]', 'name:', 'Score:neutral:88.0\r'],
#  ['boxes:[528, 511, 39, 49]',
#   'name:Nitesh detlestel',
#   'Score:happy:56.00000000000001\r'],
#  ['boxes:[83, 807, 57, 74]', 'name:Neeraj Fels;', 'Score:neutral:68.0\r'],
#  ['boxes:[1786, 819, 39, 46]',
#   'name:Chaudhary Sarita 044',
#   'Score:neutral:43.0\r'],
#  ['boxes:[116, 98, 63, 78]',
#   'name:st Barnabas st Barnabas',
#   'Score:happy:97.0\r'],
#  ['boxes:[1559, 319, 73, 90]', 'name:otislelal o18 ,', 'Score:happy:62.0\r'],
#  ['boxes:[113, 311, 42, 51]',
#   'name:be laisall eilait Mehta Mehta',
#   'Score:neutral:48.0\r'],
#  ['boxes:[1162, 288, 65, 79]', 'name:HARSH SHARMA', 'Score:neutral:77.0\r'],
#  ['boxes:[1137, 786, 76, 98]', 'name:-Ruchi | /Panse', 'Score:sad:40.0\r'],
#  ['boxes:[303, 149, 49, 63]', 'name:Pooja Yadav', 'Score:neutral:61.0\r'],
#  ['boxes:[1372, 983, 45, 52]', 'name:', 'Score:neutral:65.0\r'],
#  ['boxes:[933, 481, 43, 54]',
#   'name:Sudh3nshu Shrivasteyv',
#   'Score:neutral:56.99999999999999\r'],
#  ['boxes:[930, 128, 43, 49]',
#   'name:oetllaltisteiaetiie ns rao',
#   'Score:angry:33.0\r'],
#  ['boxes:[1148, 127, 50, 66]', 'name:Kumawat Runal', 'Score:sad:39.0\r'],
#  ['boxes:[717, 289, 73, 92]', 'name:|Garg Simran', 'Score:neutral:64.0\r'],
#  ['boxes:[1581, 128, 52, 65]',
#   'name:i "eatelst lat rer-te kumar th.',
#   'Score:neutral:46.0\r'],
#  ['boxes:[1577, 469, 50, 61]', 'name:Ve 2S oe', 'Score:neutral:70.0\r'],
#  ['boxes:[521, 154, 38, 50]', 'name:[Cities 086 Sagar', 'Score:happy:80.0\r'],
#  ['boxes:[1580, 620, 42, 55]',
#   'name:iMeena  | Neetu | Neetu',
#   'Score:neutral:49.0\r'],
#  ['boxes:[1774, 274, 48, 58]', 'name:', 'Score:sad:34.0\r'],
#  ['boxes:[784, 964, 50, 61]', 'name:@ite, lelsitia iva', 'Score:happy:67.0\r'],
#  ['boxes:[1149, 650, 30, 39]',
#   'name:Kumar Soni Aditya rele',
#   'Score:fear:39.0\r'],
#  ['boxes:[1792, 660, 42, 50]', 'name:Raja', 'Score:sad:49.0\r'],
#  ['boxes:[519, 809, 43, 52]',
#   'name:1 Singh Sham. 098',
#   'Score:neutral:63.0\r'],
#  ['Frame No:13\r'],
#  ['boxes:[89, 622, 56, 68]', 'name:032 Harsh Rai', 'Score:neutral:85.0\r'],
#  ['boxes:[1377, 303, 43, 56]',
#   'name:tle ==) 4 Kumar 078',
#   'Score:neutral:81.0\r'],
#  ['boxes:[932, 277, 76, 100]',
#   'name:wy \\estia Kumar',
#   'Score:neutral:73.0\r'],
#  ['boxes:[295, 783, 51, 62]',
#   'name:mely 9 4 NitstwAfahari',
#   'Score:sad:46.0\r'],
#  ['boxes:[731, 802, 46, 57]',
#   'name:Bel tay stlieertle Ser icee ae',
#   'Score:neutral:56.99999999999999\r'],
#  ['boxes:[726, 135, 58, 73]',
#   'name:NAVNITA | KIIMARI',
#   'Score:neutral:77.0\r'],
#  ['boxes:[1367, 824, 49, 60]', 'name:Amar Sarkan 012', 'Score:neutral:53.0\r'],
#  ['boxes:[1790, 141, 40, 51]',
#   'name:Shvam Shukis 102',
#   'Score:neutral:93.0\r'],
#  ['boxes:[1771, 476, 58, 72]',
#   'name:Manish 048 loormar',
#   'Score:neutral:87.0\r'],
#  ['boxes:[528, 511, 39, 49]',
#   'name:Nitesh detlestel',
#   'Score:happy:56.99999999999999\r'],
#  ['boxes:[1368, 457, 35, 45]', 'name:', 'Score:neutral:87.0\r'],
#  ['boxes:[83, 807, 57, 74]', 'name:Neeraj Fels;', 'Score:neutral:68.0\r'],
#  ['boxes:[1786, 819, 39, 46]',
#   'name:Chaudhary Sarita 044',
#   'Score:neutral:43.0\r'],
#  ['boxes:[116, 98, 63, 78]',
#   'name:st Barnabas st Barnabas',
#   'Score:happy:97.0\r'],
#  ['boxes:[1559, 319, 73, 90]', 'name:otislelal o18 ,', 'Score:happy:62.0\r'],
#  ['boxes:[113, 311, 42, 51]',
#   'name:be laisall eilait Mehta Mehta',
#   'Score:neutral:48.0\r'],
#  ['boxes:[1162, 288, 65, 79]', 'name:HARSH SHARMA', 'Score:neutral:77.0\r'],
#  ['boxes:[1137, 786, 76, 98]', 'name:-Ruchi | /Panse', 'Score:sad:40.0\r'],
#  ['boxes:[303, 149, 49, 63]', 'name:Pooja Yadav', 'Score:neutral:61.0\r'],
#  ['boxes:[1372, 983, 45, 52]', 'name:', 'Score:neutral:65.0\r'],
#  ['boxes:[1575, 466, 51, 65]', 'name:Nandsani S! hah', 'Score:neutral:48.0\r'],
#  ['boxes:[933, 481, 43, 54]',
#   'name:Sudh3nshu Shrivastoyv',
#   'Score:neutral:56.99999999999999\r'],
#  ['boxes:[930, 128, 43, 49]',
#   'name:oetllaltisteiaetiie ns rao',
#   'Score:angry:33.0\r'],
#  ['boxes:[1148, 127, 50, 66]', 'name:Kumawat Runal', 'Score:sad:39.0\r'],
#  ['boxes:[717, 289, 73, 92]', 'name:|Garg Simran', 'Score:neutral:64.0\r'],
#  ['boxes:[1581, 128, 52, 65]',
#   'name:ie atelst lat rer-te kumar th.',
#   'Score:neutral:47.0\r'],
#  ['boxes:[1580, 620, 42, 55]',
#   'name:i Meena  | Neetu | Neetu',
#   'Score:neutral:49.0\r'],
#  ['boxes:[1775, 275, 47, 57]', 'name:', 'Score:happy:46.0\r'],
#  ['boxes:[784, 964, 50, 61]', 'name:@ite, lelsitia iva', 'Score:happy:67.0\r'],
#  ['boxes:[521, 155, 37, 47]', 'name:Sagar fettie = 086', 'Score:happy:74.0\r'],
#  ['boxes:[1149, 650, 30, 39]',
#   'name:Kumar Soni Aditya rele',
#   'Score:fear:38.0\r'],
#  ['boxes:[519, 809, 43, 51]',
#   'name:Sanam. | Singh 098',
#   'Score:neutral:65.0\r'],
#  ['boxes:[1792, 660, 42, 50]', 'name:Raja', 'Score:sad:49.0\r'],
#  ['Frame No:14\r'],
#  ['boxes:[89, 622, 56, 68]', 'name:032 Harsh Rai', 'Score:neutral:85.0\r'],
#  ['boxes:[1162, 287, 67, 79]', 'name:HARSH SHARMA', 'Score:neutral:71.0\r'],
#  ['boxes:[113, 312, 43, 52]',
#   'name:Ment: tel aisall ilel! tel aisall ilel!',
#   'Score:neutral:62.0\r'],
#  ['boxes:[1377, 303, 43, 56]',
#   'name:tle ==) 4 Kumar 078',
#   'Score:neutral:81.0\r'],
#  ['boxes:[1790, 141, 40, 51]',
#   'name:Shvam Shukis 102',
#   'Score:neutral:94.0\r'],
#  ['boxes:[295, 783, 51, 62]',
#   'name:mely 9 4 NitstwAfahari',
#   'Score:sad:46.0\r'],
#  ['boxes:[731, 802, 46, 57]',
#   'name:Bel tay sSlieerlcg Ser leee ee',
#   'Score:neutral:56.99999999999999\r'],
#  ['boxes:[932, 278, 76, 99]', 'name:Amit. Kumar', 'Score:neutral:62.0\r'],
#  ['boxes:[726, 135, 58, 73]',
#   'name:NAVNITA | KIIMARI',
#   'Score:neutral:77.0\r'],
#  ['boxes:[1771, 476, 58, 72]',
#   'name:Manish 048 loormar',
#   'Score:neutral:87.0\r'],
#  ['boxes:[528, 511, 39, 49]',
#   'name:Nitesh detlestel',
#   'Score:happy:56.99999999999999\r'],
#  ['boxes:[1368, 457, 35, 45]', 'name:', 'Score:neutral:87.0\r'],
#  ['boxes:[303, 149, 49, 63]', 'name:Pooja Yadav', 'Score:neutral:63.0\r'],
#  ['boxes:[83, 807, 57, 74]', 'name:Neeraj Fels;', 'Score:neutral:68.0\r'],
#  ['boxes:[1786, 819, 39, 46]',
#   'name:Chaudhary Sarita 044',
#   'Score:neutral:43.0\r'],
#  ['boxes:[116, 98, 63, 78]',
#   'name:st Barnabas st Barnabas',
#   'Score:happy:97.0\r'],
#  ['boxes:[1775, 275, 47, 57]', 'name:', 'Score:happy:37.0\r'],
#  ['boxes:[1137, 786, 76, 98]', 'name:-Ruchi | /Panse', 'Score:sad:40.0\r'],
#  ['boxes:[1372, 983, 45, 52]', 'name:', 'Score:neutral:65.0\r'],
#  ['boxes:[933, 481, 43, 54]',
#   'name:Sudh3nshu Shrivastoyv',
#   'Score:neutral:56.99999999999999\r'],
#  ['boxes:[930, 128, 43, 49]',
#   'name:oetllaltisteiaetiie ns rao',
#   'Score:angry:33.0\r'],
#  ['boxes:[1575, 467, 51, 63]', 'name:Nan@ani SI hah', 'Score:neutral:46.0\r'],
#  ['boxes:[1148, 127, 50, 66]', 'name:Kumawat Runal', 'Score:sad:39.0\r'],
#  ['boxes:[1555, 318, 76, 96]',
#   'name:elalelal | Ait 018',
#   'Score:angry:35.0\r'],
#  ['boxes:[1368, 823, 49, 61]', 'name:Sarkan Amar 012', 'Score:neutral:50.0\r'],
#  ['boxes:[717, 289, 73, 92]', 'name:|Garg Simran', 'Score:neutral:65.0\r'],
#  ['boxes:[1581, 128, 52, 65]',
#   'name:ie atelst lat rer-te kumar th.',
#   'Score:neutral:48.0\r'],
#  ['boxes:[1580, 620, 42, 55]',
#   'name:i Meena  | Neetu | Neetu',
#   'Score:neutral:49.0\r'],
#  ['boxes:[784, 964, 49, 60]',
#   'name:[Gisele isisitia iva',
#   'Score:happy:57.99999999999999\r'],
#  ['boxes:[1149, 650, 30, 39]',
#   'name:Kumar Soni Aditya rele',
#   'Score:fear:39.0\r'],
#  ['boxes:[521, 155, 37, 48]', 'name:fCitiest Saaar 086', 'Score:happy:64.0\r'],
#  ['boxes:[519, 809, 43, 51]',
#   'name:Sanam | | Singh 098',
#   'Score:neutral:66.0\r'],
#  ['boxes:[1792, 660, 42, 50]', 'name:Raja', 'Score:sad:49.0\r'],
#  ['Frame No:15\r'],
#  ['boxes:[89, 622, 56, 68]', 'name:032 Harsh Rai', 'Score:neutral:85.0\r'],
#  ['boxes:[113, 312, 43, 52]',
#   'name:Ment: tel aisall ilel! tel aisall ilel!',
#   'Score:neutral:62.0\r'],
#  ['boxes:[1162, 288, 67, 78]', 'name:HARSH CUIAPMA', 'Score:neutral:77.0\r'],
#  ['boxes:[1377, 303, 43, 56]',
#   'name:tle ==) 4 Kumar 078',
#   'Score:neutral:81.0\r'],
#  ['boxes:[1790, 141, 40, 51]',
#   'name:Shvam Shukis 102',
#   'Score:neutral:94.0\r'],
#  ['boxes:[295, 783, 51, 62]',
#   'name:mely 9 4 NitstwAfahari',
#   'Score:sad:46.0\r'],
#  ['boxes:[729, 803, 49, 59]',
#   'name:_ bikky mae-\\lgeseren Cua',
#   'Score:neutral:65.0\r'],
#  ['boxes:[1146, 126, 52, 66]', 'name:Kumawat Kunal', 'Score:neutral:45.0\r'],
#  ['boxes:[932, 278, 75, 100]', 'name:Amit Kumar.', 'Score:neutral:75.0\r'],
#  ['boxes:[726, 135, 57, 73]', 'name:KLMARI NAVNITA.', 'Score:neutral:81.0\r'],
#  ['boxes:[1771, 476, 58, 72]',
#   'name:Manish 048 loormar',
#   'Score:neutral:87.0\r'],
#  ['boxes:[528, 511, 39, 49]',
#   'name:Nitesh detlestel',
#   'Score:happy:56.99999999999999\r'],
#  ['boxes:[303, 149, 49, 63]', 'name:Pooja Yadav', 'Score:neutral:63.0\r'],
#  ['boxes:[83, 807, 57, 74]', 'name:Neeraj Fels;', 'Score:neutral:68.0\r'],
#  ['boxes:[1786, 819, 39, 46]',
#   'name:Chaudhary Sarita 044',
#   'Score:neutral:43.0\r'],
#  ['boxes:[1368, 457, 36, 45]', 'name:', 'Score:neutral:87.0\r'],
#  ['boxes:[116, 98, 63, 78]',
#   'name:st Barnabas st Barnabas',
#   'Score:happy:97.0\r'],
#  ['boxes:[1137, 786, 76, 98]', 'name:-Ruchi | /Panse', 'Score:sad:40.0\r'],
#  ['boxes:[1372, 983, 45, 52]', 'name:', 'Score:neutral:65.0\r'],
#  ['boxes:[1557, 318, 74, 96]', 'name:slalelal 018 may', 'Score:angry:31.0\r'],
#  ['boxes:[933, 479, 44, 55]',
#   'name:Shrivast Sudh4nshu sel',
#   'Score:neutral:53.0\r'],
#  ['boxes:[930, 128, 43, 49]',
#   'name:oetllaltisteiaetiie ns rao',
#   'Score:angry:33.0\r'],
#  ['boxes:[1575, 467, 51, 63]', 'name:Nan@ani SI hah', 'Score:neutral:46.0\r'],
#  ['boxes:[1775, 275, 47, 56]', 'name:', 'Score:sad:31.0\r'],
#  ['boxes:[1368, 823, 49, 61]', 'name:Sarkan Amar 012', 'Score:neutral:49.0\r'],
#  ['boxes:[717, 289, 73, 92]', 'name:|Garg Simran', 'Score:neutral:66.0\r'],
#  ['boxes:[1581, 128, 52, 65]',
#   'name:ie atelst lat rer-te kumar th.',
#   'Score:neutral:48.0\r'],
#  ['boxes:[1580, 620, 42, 55]',
#   'name:i Meena  | Neetu | Neetu',
#   'Score:neutral:49.0\r'],
#  ['boxes:[784, 964, 49, 60]',
#   'name:[Gisele isisitia iva',
#   'Score:happy:57.99999999999999\r'],
#  ['boxes:[521, 155, 37, 48]', 'name:fCitiest Saaar 086', 'Score:happy:63.0\r'],
#  ['boxes:[519, 809, 43, 51]',
#   'name:Sanam | | Singh 098',
#   'Score:neutral:66.0\r'],
#  ['boxes:[1792, 660, 42, 50]', 'name:Raja', 'Score:sad:49.0\r'],
#  ['boxes:[1149, 649, 29, 37]',
#   'name:y Velie) Kumar feleyl Son',
#   'Score:fear:40.0\r'],
#  ['Frame No:16\r'],
#  ['boxes:[89, 622, 56, 68]', 'name:032 Harsh Rai', 'Score:neutral:85.0\r'],
#  ['boxes:[113, 312, 43, 52]',
#   'name:Ment: tel aisall ilel! tel aisall ilel!',
#   'Score:neutral:62.0\r'],
#  ['boxes:[1377, 304, 43, 55]',
#   'name:Tl t-34 Kumar 078',
#   'Score:neutral:79.0\r'],
#  ['boxes:[1790, 141, 40, 51]',
#   'name:Shvam Shukla 102',
#   'Score:neutral:95.0\r'],
#  ['boxes:[295, 783, 51, 62]',
#   'name:mely 9 4 NitstwAfahari',
#   'Score:sad:46.0\r'],
#  ['boxes:[932, 278, 76, 100]', 'name:Amit Kumar.', 'Score:neutral:75.0\r'],
#  ['boxes:[729, 803, 49, 59]',
#   'name:_ bikky aae-\\laee lm Cua',
#   'Score:neutral:66.0\r'],
#  ['boxes:[1146, 126, 52, 66]', 'name:Kumawat Kunal', 'Score:neutral:47.0\r'],
#  ['boxes:[726, 135, 57, 73]', 'name:KUMARI NAVNITA.', 'Score:neutral:82.0\r'],
#  ['boxes:[1771, 476, 58, 72]',
#   'name:Manish 048 loormar',
#   'Score:neutral:87.0\r'],
#  ['boxes:[528, 511, 39, 49]',
#   'name:Nitesh detlestel',
#   'Score:happy:56.99999999999999\r'],
#  ['boxes:[303, 149, 49, 63]', 'name:Pooja Yadav', 'Score:neutral:63.0\r'],
#  ['boxes:[83, 807, 57, 74]', 'name:Neeraj Fels;', 'Score:neutral:68.0\r'],
#  ['boxes:[1368, 457, 36, 45]', 'name:', 'Score:neutral:87.0\r'],
#  ['boxes:[116, 98, 63, 78]',
#   'name:st Barnabas st Barnabas',
#   'Score:happy:97.0\r'],
#  ['boxes:[1786, 819, 39, 45]',
#   'name:Chaudhary "Sarita 044',
#   'Score:neutral:46.0\r'],
#  ['boxes:[1137, 786, 76, 98]', 'name:-Ruchi | /Panse', 'Score:sad:40.0\r'],
#  ['boxes:[1162, 288, 64, 78]', 'name:HARSH CLIAPMA .', 'Score:neutral:76.0\r'],
#  ['boxes:[1372, 983, 45, 52]', 'name:', 'Score:neutral:65.0\r'],
#  ['boxes:[1557, 318, 74, 96]', 'name:slalelal 018 may', 'Score:angry:31.0\r'],
#  ['boxes:[933, 479, 44, 55]',
#   'name:Shrivast Sudh4nshu sel',
#   'Score:neutral:53.0\r'],
#  ['boxes:[930, 128, 43, 49]',
#   'name:oetllaltisteiaetiie ns rao',
#   'Score:angry:33.0\r'],
#  ['boxes:[1575, 467, 51, 63]', 'name:Nan@ani SI hah', 'Score:neutral:46.0\r'],
#  ['boxes:[1775, 275, 47, 57]', 'name:', 'Score:happy:46.0\r'],
#  ['boxes:[1581, 128, 52, 65]',
#   'name:i "eatelst lat rer-te kumar th.',
#   'Score:neutral:46.0\r'],
#  ['boxes:[1368, 823, 49, 61]', 'name:Sarkan Amar 012', 'Score:neutral:49.0\r'],
#  ['boxes:[717, 289, 73, 92]', 'name:|Garg Simran', 'Score:neutral:65.0\r'],
#  ['boxes:[520, 154, 37, 48]', 'name:BS ler\\s Cue 086', 'Score:happy:47.0\r'],
#  ['boxes:[1580, 620, 42, 55]',
#   'name:i Meena  | Neetu | Neetu',
#   'Score:neutral:49.0\r'],
#  ['boxes:[784, 964, 49, 60]',
#   'name:[Gisele isisitia iva',
#   'Score:happy:57.99999999999999\r'],
#  ['boxes:[519, 809, 43, 51]',
#   'name:Sanam | | Singh 098',
#   'Score:neutral:66.0\r'],
#  ['boxes:[1792, 659, 44, 52]', 'name:Sangam ele)', 'Score:sad:53.0\r'],
#  ['boxes:[1149, 649, 29, 37]',
#   'name:y Velie) Kumar feleyl Son',
#   'Score:fear:40.0\r'],
#  ['Frame No:17\r'],
#  ['boxes:[88, 620, 56, 70]', 'name:032 Harsh Rai', 'Score:neutral:88.0\r'],
#  ['boxes:[113, 312, 43, 52]',
#   'name:Ment: tel aisall ilel! tel aisall ilel!',
#   'Score:neutral:62.0\r'],
#  ['boxes:[1377, 304, 43, 55]',
#   'name:Tl t-34 Kumar 078',
#   'Score:neutral:79.0\r'],
#  ['boxes:[1790, 141, 40, 51]',
#   'name:Shvam Shukla 102',
#   'Score:neutral:95.0\r'],
#  ['boxes:[295, 783, 51, 62]',
#   'name:mely 9 4 NitstwAfahari',
#   'Score:sad:47.0\r'],
#  ['boxes:[932, 278, 76, 100]', 'name:Amit Kumar.', 'Score:neutral:75.0\r'],
#  ['boxes:[729, 803, 49, 59]',
#   'name:_ bikky aae-\\laee lm cular',
#   'Score:neutral:66.0\r'],
#  ['boxes:[726, 135, 58, 74]', 'name:rrAVibe-@ KLMARI', 'Score:neutral:88.0\r'],
#  ['boxes:[1146, 126, 52, 66]', 'name:Kumawat Kunal', 'Score:neutral:48.0\r'],
#  ['boxes:[83, 807, 57, 74]', 'name:Neeraj Fels;', 'Score:neutral:68.0\r'],
#  ['boxes:[1162, 288, 64, 77]',
#   'name:TWIARPCL CLIAPMA',
#   'Score:neutral:82.0\r'],
#  ['boxes:[1786, 819, 39, 45]',
#   'name:Chaudhary "Sarita O44',
#   'Score:neutral:45.0\r'],
#  ['boxes:[1368, 457, 36, 45]', 'name:', 'Score:neutral:87.0\r'],
#  ['boxes:[116, 98, 63, 78]',
#   'name:st Barnabas st Barnabas',
#   'Score:happy:97.0\r'],
#  ['boxes:[529, 510, 39, 50]', 'name:Nitesh kum', 'Score:happy:65.0\r'],
#  ['boxes:[1138, 785, 77, 99]', 'name:Ruchi Panse', 'Score:neutral:33.0\r'],
#  ['boxes:[1775, 275, 47, 58]', 'name:', 'Score:happy:40.0\r'],
#  ['boxes:[302, 149, 50, 63]', 'name:Pooja Yadav', 'Score:neutral:65.0\r'],
#  ['boxes:[1372, 983, 45, 52]', 'name:', 'Score:neutral:65.0\r'],
#  ['boxes:[1557, 318, 74, 96]', 'name:welatelal 018 may', 'Score:angry:31.0\r'],
#  ['boxes:[933, 479, 44, 55]',
#   'name:Shrivast Sudh4nshu sel',
#   'Score:neutral:53.0\r'],
#  ['boxes:[930, 128, 43, 49]',
#   'name:oetllaltisteiaetiie ns rao',
#   'Score:angry:32.0\r'],
#  ['boxes:[1581, 128, 52, 65]',
#   'name:i "eatelst lat rer-te kumar th.',
#   'Score:neutral:46.0\r'],
#  ['boxes:[1368, 823, 49, 61]', 'name:Sarkan Amar 012', 'Score:neutral:48.0\r'],
#  ['boxes:[717, 289, 73, 92]', 'name:|Garg Simran', 'Score:neutral:66.0\r'],
#  ['boxes:[1576, 468, 50, 63]', 'name:Ne ea oe', 'Score:neutral:61.0\r'],
#  ['boxes:[520, 154, 37, 48]', 'name:BSler\\s Cue 086', 'Score:happy:47.0\r'],
#  ['boxes:[1580, 620, 42, 55]',
#   'name:i Meena  | Neetu | Neetu',
#   'Score:neutral:49.0\r'],
#  ['boxes:[1770, 479, 59, 70]',
#   'name:ey-t:} Vi etattte kumar',
#   'Score:neutral:85.0\r'],
#  ['boxes:[784, 964, 49, 60]',
#   'name:[Gisele isisitia iva',
#   'Score:happy:67.0\r'],
#  ['boxes:[1792, 659, 44, 52]', 'name:Sangam ele)', 'Score:sad:53.0\r'],
#  ['boxes:[1149, 649, 29, 37]',
#   'name:y Velie) Kumar feleyl Son',
#   'Score:fear:40.0\r'],
#  ['boxes:[518, 811, 42, 50]',
#   'name:Shivam 1 Singh 098',
#   'Score:neutral:68.0\r'],
#  ['Frame No:18\r'],
#  ['boxes:[88, 620, 56, 70]', 'name:032 Harsh Rai', 'Score:neutral:88.0\r'],
#  ['boxes:[113, 312, 43, 52]',
#   'name:Ment: tel aisall ilel! tel aisall ilel!',
#   'Score:neutral:62.0\r'],
#  ['boxes:[1377, 304, 43, 55]',
#   'name:Tl t-34 Kumar 078',
#   'Score:neutral:79.0\r'],
#  ['boxes:[932, 280, 75, 98]', 'name:Amit. ilar', 'Score:neutral:77.0\r'],
#  ['boxes:[1791, 141, 39, 52]',
#   'name:Shvam his Flare 102 Yo',
# ...
#   'Score:sad:47.0\r'],
#  ['boxes:[1376, 304, 43, 54]',
#   'name:Tat-t-34 Kumar O78',
#   'Score:neutral:82.0\r'],
#  ['boxes:[113, 311, 43, 53]',
#   'name:Mehta i latsell clei i latsell clei',
#   'Score:neutral:45.0\r'],
#  ['boxes:[1575, 618, 47, 60]',
#   'name:u Meena mm ey.10) _Neetu',
#   'Score:neutral:57.99999999999999\r'],
#  ['boxes:[1550, 320, 79, 96]',
#   'name:Siatelal el abe 018',
#   'Score:angry:28.000000000000004\r'],
#  ['boxes:[726, 134, 57, 75]', 'name:KUMARI NAVNITA.', 'Score:neutral:85.0\r'],
#  ['boxes:[731, 802, 49, 60]',
#   'name:iar. _bikkyl Sharh',
#   'Score:neutral:56.99999999999999\r'],
#  ['boxes:[1367, 457, 36, 45]', 'name:', 'Score:neutral:87.0\r'],
#  ['boxes:[529, 511, 39, 49]', 'name:Nitesh kum', 'Score:happy:70.0\r'],
#  ['boxes:[83, 807, 57, 74]', 'name:Neeraj Fels;', 'Score:neutral:68.0\r'],
#  ['boxes:[500, 641, 74, 91]', 'name:Gupta Sonu 104', 'Score:angry:35.0\r'],
#  ['boxes:[116, 98, 63, 78]',
#   'name:st Barnabas st Barnabas',
#   'Score:happy:97.0\r'],
#  ['boxes:[1771, 476, 58, 72]',
#   'name:Manish 048 loormar',
#   'Score:neutral:88.0\r'],
#  ['boxes:[1786, 819, 39, 45]',
#   'name:Chaudhary "Sarita 044',
#   'Score:neutral:50.0\r'],
#  ['boxes:[934, 479, 44, 55]',
#   'name:Shrivacr Sudh4Snshu . TVa',
#   'Score:neutral:64.0\r'],
#  ['boxes:[1147, 127, 50, 65]',
#   'name:Mlsrivc ls Raunal',
#   'Score:neutral:62.0\r'],
#  ['boxes:[1137, 786, 76, 98]', 'name:-Ruchi | Panse', 'Score:sad:53.0\r'],
#  ['boxes:[931, 129, 42, 48]',
#   'name:-purushottama r rao',
#   'Score:happy:41.0\r'],
#  ['boxes:[930, 277, 75, 99]', 'name:Amit Kumar', 'Score:neutral:68.0\r'],
#  ['boxes:[302, 149, 50, 64]', 'name:Pooja Yadav', 'Score:neutral:50.0\r'],
#  ['boxes:[521, 154, 38, 48]', 'name:fCitieis Sagar 086', 'Score:happy:75.0\r'],
#  ['boxes:[1372, 983, 45, 52]', 'name:', 'Score:neutral:65.0\r'],
#  ['boxes:[1581, 128, 52, 66]',
#   'name:kanchan: rey-te) kumar th..',
#   'Score:neutral:45.0\r'],
#  ['boxes:[717, 289, 73, 92]', 'name:|Garg Simran', 'Score:neutral:60.0\r'],
#  ['boxes:[1774, 275, 49, 58]', 'name:', 'Score:happy:42.0\r'],
#  ['boxes:[1574, 467, 50, 62]',
#   'name:Nan@ani SI seial',
#   'Score:neutral:38.0\r'],
#  ['boxes:[1367, 822, 51, 62]', 'name:Sark> Amar. 012', 'Score:neutral:48.0\r'],
#  ['boxes:[783, 964, 50, 60]',
#   'name:@ sles ielsltia iva',
#   'Score:happy:62.0\r'],
#  ['boxes:[520, 804, 52, 64]',
#   'name:)Singh 098 |. Saar',
#   'Score:neutral:63.0\r'],
#  ['boxes:[1792, 659, 44, 52]', 'name:Sangam ele)', 'Score:sad:53.0\r'],
#  ['boxes:[1148, 649, 29, 36]',
#   'name:Aditya releya dase Son',
#   'Score:fear:44.0\r'],
#  ['Frame No:25\r'],
#  ['boxes:[89, 622, 56, 68]', 'name:032 Harsh Rai', 'Score:neutral:84.0\r'],
#  ['boxes:[1163, 287, 66, 78]', "name:HARSH 'CLIADMA", 'Score:neutral:70.0\r'],
#  ['boxes:[1790, 143, 40, 49]',
#   'name:Shukla Shvam 102 Yoo',
#   'Score:neutral:92.0\r'],
#  ['boxes:[296, 783, 50, 62]',
#   'name:mel 9 4 NifstwAfahari',
#   'Score:sad:47.0\r'],
#  ['boxes:[1377, 303, 43, 56]',
#   'name:tls ==) 4 Kumar 078',
#   'Score:neutral:80.0\r'],
#  ['boxes:[113, 311, 43, 53]',
#   'name:Mehta i latsell clei i latsell clei',
#   'Score:neutral:45.0\r'],
#  ['boxes:[1575, 618, 47, 60]',
#   'name:i Meena mm ey.10) Neetu',
#   'Score:neutral:59.0\r'],
#  ['boxes:[1550, 320, 79, 96]',
#   'name:Siatelal el abe 018',
#   'Score:angry:28.000000000000004\r'],
#  ['boxes:[726, 134, 57, 74]', 'name:NAVNITA. KLIMARI', 'Score:neutral:75.0\r'],
#  ['boxes:[731, 802, 49, 60]',
#   'name:iar. _bikkyl Sharh',
#   'Score:neutral:56.99999999999999\r'],
#  ['boxes:[1367, 457, 36, 45]', 'name:', 'Score:neutral:87.0\r'],
#  ['boxes:[529, 511, 39, 49]', 'name:Nitesh kum', 'Score:happy:70.0\r'],
#  ['boxes:[83, 807, 57, 74]', 'name:Neeraj Fels;', 'Score:neutral:68.0\r'],
#  ['boxes:[1786, 819, 39, 46]',
#   'name:Chaudhary Sarita 044',
#   'Score:neutral:42.0\r'],
#  ['boxes:[116, 98, 63, 78]',
#   'name:st Barnabas st Barnabas',
#   'Score:happy:97.0\r'],
#  ['boxes:[1777, 278, 46, 55]', 'name:', 'Score:happy:67.0\r'],
#  ['boxes:[934, 479, 44, 55]',
#   'name:Shrivacr Sudh4Snshu . TVa',
#   'Score:neutral:64.0\r'],
#  ['boxes:[1137, 786, 76, 98]', 'name:-Ruchi | Panse', 'Score:sad:53.0\r'],
#  ['boxes:[302, 149, 50, 64]', 'name:Pooja Yadav', 'Score:neutral:50.0\r'],
#  ['boxes:[930, 277, 75, 99]', 'name:Amit Kumar', 'Score:neutral:67.0\r'],
#  ['boxes:[1147, 127, 50, 65]',
#   'name:Mlsrivc ls Raunal',
#   'Score:neutral:67.0\r'],
#  ['boxes:[1372, 983, 45, 52]', 'name:', 'Score:neutral:65.0\r'],
#  ['boxes:[500, 642, 73, 88]', 'name:Sonu |Gupta ey.', 'Score:surprise:38.0\r'],
#  ['boxes:[520, 154, 38, 49]', 'name:Sagar [Ciiet 086', 'Score:happy:66.0\r'],
#  ['boxes:[717, 289, 73, 92]', 'name:|Garg Simran', 'Score:neutral:59.0\r'],
#  ['boxes:[1367, 822, 51, 62]', 'name:Sark> Amar. 012', 'Score:neutral:48.0\r'],
#  ['boxes:[1581, 128, 52, 65]',
#   'name:kanchan rer-te kumar th.',
#   'Score:neutral:47.0\r'],
#  ['boxes:[1575, 468, 51, 63]', 'name:Nandsani St', 'Score:neutral:53.0\r'],
#  ['boxes:[930, 128, 43, 50]', 'name:purushottama | rao', 'Score:angry:32.0\r'],
#  ['boxes:[1771, 478, 58, 72]',
#   'name:rey: Manish kumar',
#   'Score:neutral:82.0\r'],
#  ['boxes:[783, 964, 50, 60]',
#   'name:@ sles ielsltia iva',
#   'Score:happy:62.0\r'],
#  ['boxes:[520, 804, 52, 64]',
#   'name:)Singh 098 |. Saar',
#   'Score:neutral:63.0\r'],
#  ['boxes:[1792, 659, 44, 52]', 'name:Sangam ele)', 'Score:sad:53.0\r'],
#  ['boxes:[1148, 649, 29, 35]',
#   'name:Kumar Sor Aditya foley',
#   'Score:fear:47.0\r'],
#  ['Frame No:26\r'],
#  ['boxes:[89, 622, 56, 68]', 'name:032 Harsh Rai', 'Score:neutral:84.0\r'],
#  ['boxes:[1163, 287, 66, 78]', "name:HARSH 'CLIADMA", 'Score:neutral:70.0\r'],
#  ['boxes:[1790, 141, 40, 51]',
#   'name:Shvam Shukis 102 Yc',
#   'Score:neutral:94.0\r'],
#  ['boxes:[296, 783, 50, 62]',
#   'name:mel 9 4 NifstwAfahari',
#   'Score:sad:47.0\r'],
#  ['boxes:[1377, 303, 43, 56]',
#   'name:tls ==) 4 Kumar 078',
#   'Score:neutral:80.0\r'],
#  ['boxes:[113, 311, 43, 53]',
#   'name:Mehta i latsell clei i latsell clei',
#   'Score:neutral:45.0\r'],
#  ['boxes:[726, 134, 57, 74]', 'name:NAVNITA. KLIMARI', 'Score:neutral:75.0\r'],
#  ['boxes:[731, 802, 49, 60]',
#   'name:iar. _bikkyl Sharh',
#   'Score:neutral:56.99999999999999\r'],
#  ['boxes:[1367, 457, 36, 45]', 'name:', 'Score:neutral:87.0\r'],
#  ['boxes:[529, 511, 39, 49]', 'name:Nitesh kum', 'Score:happy:70.0\r'],
#  ['boxes:[83, 807, 57, 74]', 'name:Neeraj Fels;', 'Score:neutral:68.0\r'],
#  ['boxes:[1786, 819, 39, 46]',
#   'name:Chaudhary Sarita 044',
#   'Score:neutral:42.0\r'],
#  ['boxes:[116, 98, 63, 78]',
#   'name:st Barnabas st Barnabas',
#   'Score:happy:97.0\r'],
#  ['boxes:[1777, 278, 46, 54]', 'name:', 'Score:happy:59.0\r'],
#  ['boxes:[1137, 786, 76, 98]', 'name:Ruchi | Panse', 'Score:sad:38.0\r'],
#  ['boxes:[934, 479, 44, 55]',
#   'name:Shrivacr Sudh4Snshu . TVa',
#   'Score:neutral:64.0\r'],
#  ['boxes:[930, 277, 74, 99]', 'name:Amit i allestle', 'Score:neutral:65.0\r'],
#  ['boxes:[302, 149, 50, 64]', 'name:Pooja Yadav', 'Score:neutral:50.0\r'],
#  ['boxes:[1147, 127, 50, 65]',
#   'name:Mlsrivc ls Raunal',
#   'Score:neutral:68.0\r'],
#  ['boxes:[1372, 983, 45, 52]', 'name:', 'Score:neutral:65.0\r'],
#  ['boxes:[500, 642, 73, 88]', 'name:Sonu |Gupta ey.', 'Score:surprise:38.0\r'],
#  ['boxes:[717, 289, 73, 92]', 'name:|Garg Simran', 'Score:neutral:59.0\r'],
#  ['boxes:[930, 129, 42, 49]', 'name:puruchottama | rao', 'Score:happy:53.0\r'],
#  ['boxes:[1368, 823, 49, 61]', 'name:Amar Sarkan 012', 'Score:neutral:48.0\r'],
#  ['boxes:[1581, 128, 52, 65]',
#   'name:kanchan rer-te kumar th.',
#   'Score:neutral:47.0\r'],
#  ['boxes:[1575, 468, 51, 63]', 'name:Ne aS:', 'Score:neutral:53.0\r'],
#  ['boxes:[1580, 619, 42, 56]',
#   'name:iMveena  ) Neetu. ) Neetu.',
#   'Score:neutral:45.0\r'],
#  ['boxes:[1771, 478, 58, 72]',
#   'name:rey: Manish kumar',
#   'Score:neutral:82.0\r'],
#  ['boxes:[1554, 321, 73, 89]', 'name:Singh o18 Skit', 'Score:sad:30.0\r'],
#  ['boxes:[783, 962, 51, 63]',
#   'name:@isle, Velaltia. riva',
#   'Score:happy:62.0\r'],
#  ['boxes:[521, 153, 38, 49]', 'name:Sagar Che 086', 'Score:happy:76.0\r'],
#  ['boxes:[519, 803, 53, 66]',
#   'name:Singh 098 | Saver',
#   'Score:neutral:47.0\r'],
#  ['boxes:[1792, 659, 44, 52]', 'name:Sangam ele)', 'Score:sad:53.0\r'],
#  ['boxes:[1148, 649, 29, 35]',
#   'name:Kumar Sor Aditya foley',
#   'Score:fear:47.0\r'],
#  ['Frame No:27\r'],
#  ['boxes:[88, 621, 56, 69]', 'name:032 Harsh Rai', 'Score:neutral:85.0\r'],
#  ['boxes:[732, 802, 49, 62]',
#   'name:charryma cis bikkyl y Kun',
#   'Score:neutral:49.0\r'],
#  ['boxes:[1790, 141, 40, 51]',
#   'name:Shvam Shukis 102 > <',
#   'Score:neutral:94.0\r'],
#  ['boxes:[296, 783, 50, 62]',
#   'name:mel 9 4 Nif@stwAfahari',
#   'Score:sad:47.0\r'],
#  ['boxes:[1377, 303, 43, 56]',
#   'name:tls ==) 4 Kumar 078',
#   'Score:neutral:80.0\r'],
#  ['boxes:[113, 311, 43, 53]',
#   'name:Mehta i latsell clei i latsell clei',
#   'Score:neutral:46.0\r'],
#  ['boxes:[726, 134, 57, 74]', 'name:NAVNITA. KLIMARI', 'Score:neutral:75.0\r'],
#  ['boxes:[1367, 457, 36, 45]', 'name:', 'Score:neutral:87.0\r'],
#  ['boxes:[1163, 287, 65, 78]', "name:HARSH 'CLIADMAA", 'Score:neutral:70.0\r'],
#  ['boxes:[529, 511, 39, 49]', 'name:Nitesh kum', 'Score:happy:70.0\r'],
#  ['boxes:[83, 807, 57, 74]', 'name:Neeraj Fels;', 'Score:neutral:68.0\r'],
#  ['boxes:[1786, 819, 39, 46]',
#   'name:Chaudhary Sarita 044',
#   'Score:neutral:42.0\r'],
#  ['boxes:[116, 98, 63, 78]',
#   'name:st Barnabas st Barnabas',
#   'Score:happy:97.0\r'],
#  ['boxes:[302, 148, 50, 65]', 'name:Pooja Vaday', 'Score:neutral:59.0\r'],
#  ['boxes:[1137, 786, 76, 98]', 'name:Ruchi | Panse', 'Score:sad:38.0\r'],
#  ['boxes:[934, 479, 44, 55]',
#   'name:Shrivacr Sudh4Snshu . TVa',
#   'Score:neutral:64.0\r'],
#  ['boxes:[930, 277, 74, 99]', 'name:Amit i ablestle', 'Score:neutral:64.0\r'],
#  ['boxes:[1147, 127, 50, 65]',
#   'name:Mlsrivc ls Raunal',
#   'Score:neutral:68.0\r'],
#  ['boxes:[1372, 983, 45, 52]', 'name:', 'Score:neutral:65.0\r'],
#  ['boxes:[717, 289, 73, 92]', 'name:|Garg Simran', 'Score:neutral:60.0\r'],
#  ['boxes:[1775, 275, 48, 58]', 'name:', 'Score:happy:38.0\r'],
#  ['boxes:[499, 641, 74, 92]', 'name:|Gupta Sonu 104', 'Score:angry:41.0\r'],
#  ['boxes:[1368, 823, 49, 61]', 'name:Amar Sarkan 012', 'Score:neutral:48.0\r'],
#  ['boxes:[930, 129, 42, 48]', 'name:-purushottamar rao', 'Score:happy:42.0\r'],
#  ['boxes:[1581, 128, 52, 65]',
#   'name:kanchan rer-te kumar th.',
#   'Score:neutral:47.0\r'],
#  ['boxes:[1575, 468, 51, 63]', 'name:Nandsani St', 'Score:neutral:53.0\r'],
#  ['boxes:[1580, 619, 42, 56]',
#   'name:iMvMeena  ) Neetu. ) Neetu.',
#   'Score:neutral:46.0\r'],
#  ['boxes:[522, 154, 37, 48]', 'name:Sagar [Cities 086', 'Score:happy:77.0\r'],
#  ['boxes:[1771, 478, 58, 72]',
#   'name:rey: Manish kumar',
#   'Score:neutral:82.0\r'],
#  ['boxes:[1554, 321, 73, 89]', 'name:Singh o18 kit', 'Score:sad:30.0\r'],
#  ['boxes:[783, 962, 51, 63]',
#   'name:@isle, Velaltia. riva',
#   'Score:happy:62.0\r'],
#  ['boxes:[1792, 659, 44, 52]', 'name:Sangam ele)', 'Score:sad:53.0\r'],
#  ['boxes:[518, 812, 43, 49]',
#   'name:+ Shawvam | Singh 098',
#   'Score:neutral:59.0\r'],
#  ['boxes:[1148, 648, 28, 37]',
#   'name:Aditya foley Kumar Son',
#   'Score:fear:39.0\r'],
#  ['Frame No:28\r'],
#  ['boxes:[88, 621, 56, 69]', 'name:032 Harsh Rai', 'Score:neutral:85.0\r'],
#  ['boxes:[731, 802, 50, 62]',
#   'name:charms _bikky#l yar',
#   'Score:neutral:53.0\r'],
#  ['boxes:[1790, 141, 40, 51]',
#   'name:Shvam Shukla 102 a &',
#   'Score:neutral:93.0\r'],
#  ['boxes:[1377, 303, 43, 56]',
#   'name:tls ==) 4 Kumar 078',
#   'Score:neutral:80.0\r'],
#  ['boxes:[296, 783, 50, 62]',
#   'name:mel 9 4 Nif@stwAfahari',
#   'Score:sad:47.0\r'],
#  ['boxes:[113, 311, 43, 53]',
#   'name:Mehta elatsallelatt elatsallelatt',
#   'Score:neutral:45.0\r'],
#  ['boxes:[726, 134, 57, 74]', 'name:NAVNITA. KLIMARI', 'Score:neutral:75.0\r'],
#  ['boxes:[1367, 457, 36, 45]', 'name:', 'Score:neutral:87.0\r'],
#  ['boxes:[1163, 287, 65, 78]', "name:HARSH 'CLIADMAA", 'Score:neutral:70.0\r'],
#  ['boxes:[529, 510, 39, 50]', 'name:Nitesh kum', 'Score:happy:69.0\r'],
#  ['boxes:[936, 479, 43, 54]',
#   'name:Boiss ce. Birelst le taltl ava',
#   'Score:neutral:56.00000000000001\r'],
#  ['boxes:[83, 807, 57, 74]', 'name:Neeraj Fels;', 'Score:neutral:68.0\r'],
#  ['boxes:[1138, 785, 77, 99]', 'name:Ruchi Panse', 'Score:happy:39.0\r'],
#  ['boxes:[1786, 819, 39, 45]',
#   'name:Chaudhary "Sarita 044',
#   'Score:neutral:50.0\r'],
#  ['boxes:[116, 98, 63, 78]',
#   'name:st Barnabas st Barnabas',
#   'Score:happy:97.0\r'],
#  ['boxes:[302, 148, 50, 65]', 'name:Pooja Vaday', 'Score:neutral:59.0\r'],
#  ['boxes:[930, 277, 74, 99]', 'name:Amit i ablestle', 'Score:neutral:64.0\r'],
#  ['boxes:[499, 642, 74, 90]',
#   'name:| Gupta Sonu 104',
#   'Score:surprise:30.0\r'],
#  ['boxes:[1147, 127, 50, 65]',
#   'name:Mlsrivc ls Raunal',
#   'Score:neutral:68.0\r'],
#  ['boxes:[1372, 983, 45, 52]', 'name:', 'Score:neutral:65.0\r'],
#  ['boxes:[717, 289, 73, 92]', 'name:|Garg Simran', 'Score:neutral:60.0\r'],
#  ['boxes:[1775, 275, 48, 58]', 'name:', 'Score:happy:42.0\r'],
#  ['boxes:[1581, 128, 52, 65]',
#   'name:kanchan rer-te kumar th.',
#   'Score:neutral:44.0\r'],
#  ['boxes:[1368, 823, 49, 61]', 'name:Amar Sarkan 012', 'Score:neutral:48.0\r'],
#  ['boxes:[930, 128, 42, 50]',
#   'name:eitalisteiaetiiee rao',
#   'Score:angry:42.0\r'],
#  ['boxes:[1575, 468, 51, 63]', 'name:Nandsani St', 'Score:neutral:53.0\r'],
#  ['boxes:[1580, 618, 42, 57]',
#   'name:iMeena _ ) Neetu. ) Neetu.',
#   'Score:neutral:44.0\r'],
#  ['boxes:[1771, 478, 58, 72]',
#   'name:rey: Manish kumar',
#   'Score:neutral:82.0\r'],
#  ['boxes:[1554, 321, 73, 89]', 'name:Singh o18 Skit', 'Score:sad:30.0\r'],
#  ['boxes:[783, 962, 51, 63]',
#   'name:@isle, Velaltia. riva',
#   'Score:happy:62.0\r'],
#  ['boxes:[521, 154, 37, 47]',
#   'name:ote BSler|, 086',
#   'Score:happy:57.99999999999999\r'],
#  ['boxes:[1792, 659, 44, 52]', 'name:Sangam ele)', 'Score:sad:53.0\r'],
#  ['boxes:[518, 811, 43, 50]',
#   'name:Shrram Beis 098',
#   'Score:neutral:56.00000000000001\r'],
#  ['boxes:[1148, 649, 28, 35]',
#   'name:Kumar Sor Aditya foley',
#   'Score:fear:45.0\r'],
#  ['Frame No:29\r'],
#  ['boxes:[88, 621, 56, 69]', 'name:032 Harsh Rai', 'Score:neutral:85.0\r'],
#  ['boxes:[731, 802, 50, 62]',
#   'name:charms _bikky#l yar',
#   'Score:neutral:53.0\r'],
#  ['boxes:[1377, 303, 43, 56]',
#   'name:tls ==) 4 Kumar 078',
#   'Score:neutral:80.0\r'],
#  ['boxes:[1790, 141, 40, 51]',
#   'name:Shvam Shukla 102 a &',
#   'Score:neutral:93.0\r'],
#  ['boxes:[296, 783, 50, 62]',
#   'name:mel 9 4 Nif@stwAfahari',
#   'Score:sad:47.0\r'],
#  ['boxes:[113, 311, 43, 53]',
#   'name:Mehta iS latsell eile! iS latsell eile!',
#   'Score:neutral:45.0\r'],
#  ['boxes:[1366, 821, 52, 62]', 'name:Amar Sarkar 012', 'Score:neutral:83.0\r'],
#  ['boxes:[1367, 457, 36, 45]', 'name:', 'Score:neutral:89.0\r'],
#  ['boxes:[725, 134, 58, 74]', 'name:NAVNITA KLIMARI,', 'Score:neutral:78.0\r'],
#  ['boxes:[1163, 287, 65, 78]', "name:HARSH 'CLIADMAA", 'Score:neutral:70.0\r'],
#  ['boxes:[529, 510, 39, 50]', 'name:Nitesh kum', 'Score:happy:68.0\r'],
#  ['boxes:[936, 479, 43, 54]',
#   'name:Boisigi ce. BS Trelste le taltl Tava',
#   'Score:neutral:56.00000000000001\r'],
#  ['boxes:[83, 807, 57, 74]', 'name:Neeraj Fels;', 'Score:neutral:68.0\r'],
#  ['boxes:[116, 98, 63, 78]',
#   'name:st Barnabas st Barnabas',
#   'Score:happy:97.0\r'],
#  ['boxes:[1786, 819, 39, 45]',
#   'name:Chaudhary "Sarita 044',
#   'Score:neutral:49.0\r'],
#  ['boxes:[1137, 786, 76, 98]', 'name:Ruchi | /Panse', 'Score:sad:45.0\r'],
#  ['boxes:[302, 148, 50, 65]', 'name:Pooja Vaday', 'Score:neutral:59.0\r'],
#  ['boxes:[499, 642, 74, 90]',
#   'name:| Gupta Sonu 104',
#   'Score:surprise:31.0\r'],
#  ['boxes:[929, 278, 77, 100]', 'name:Amit Kumar', 'Score:neutral:84.0\r'],
#  ['boxes:[1147, 127, 50, 65]',
#   'name:Mlsrivc ls Raunal',
#   'Score:neutral:68.0\r'],
#  ['boxes:[930, 129, 43, 48]',
#   'name:weltatitsleiaeliie ns rao',
#   'Score:happy:36.0\r'],
#  ['boxes:[1372, 983, 45, 52]', 'name:', 'Score:neutral:65.0\r'],
#  ['boxes:[717, 289, 73, 92]', 'name:|Garg Simran', 'Score:neutral:60.0\r'],
#  ['boxes:[1575, 468, 50, 61]', 'name:Nanton i SI shah', 'Score:angry:39.0\r'],
#  ['boxes:[1775, 275, 48, 58]', 'name:', 'Score:happy:40.0\r'],
#  ['boxes:[1580, 128, 53, 65]',
#   'name:etatelselal kumar certo th.',
#   'Score:neutral:46.0\r'],
#  ['boxes:[783, 964, 51, 60]',
#   'name:Girls isisitias iva',
#   'Score:happy:62.0\r'],
#  ...]

# %%
s1 = []
for i in range(len(d)):
  for j in range(len(d[i])):
    s1.append(d[i][j].split('\t'))

# %%
s1
# Out:
# [['Frame No:1\r'],
#  ['boxes:[730, 803, 47, 57]'],
#  ['name:eset iceerl _bikkyl \\leskle-'],
#  ['Score:neutral:69.0\r'],
#  ['boxes:[295, 783, 50, 62]'],
#  ['name:4 NiteshAfahari'],
#  ['Score:sad:43.0\r'],
#  ['boxes:[1146, 127, 52, 63]'],
#  ['name:aseivris eanal'],
#  ['Score:sad:43.0\r'],
#  ['boxes:[1161, 288, 68, 79]'],
#  ['name:HARSH SHARMA'],
#  ['Score:neutral:80.0\r'],
#  ['boxes:[88, 621, 57, 70]'],
#  ['name:032 Harsch Rai'],
#  ['Score:neutral:79.0\r'],
#  ['boxes:[1791, 142, 39, 50]'],
#  ['name:Shyam is Flare 102 >'],
#  ['Score:neutral:92.0\r'],
#  ['boxes:[932, 480, 44, 53]'],
#  ['name:Shrivast BStrelst ls alll TVa'],
#  ['Score:neutral:65.0\r'],
#  ['boxes:[303, 150, 49, 62]'],
#  ['name:Pooja Yadav'],
#  ['Score:neutral:66.0\r'],
#  ['boxes:[1376, 303, 44, 55]'],
#  ['name:Tat-t-34 Kumar 078'],
#  ['Score:neutral:81.0\r'],
#  ['boxes:[928, 274, 77, 99]'],
#  ['name:Kumar Amit |'],
#  ['Score:neutral:76.0\r'],
#  ['boxes:[725, 134, 58, 74]'],
#  ['name:NAVNITA KLIMARI,'],
#  ['Score:neutral:78.0\r'],
#  ['boxes:[506, 644, 71, 86]'],
#  ['name:Gupta Sonu | 104'],
#  ['Score:sad:42.0\r'],
#  ['boxes:[1576, 618, 46, 59]'],
#  ['name:Meena mey.i0) Neetu.'],
#  ['Score:neutral:46.0\r'],
#  ['boxes:[529, 511, 38, 49]'],
#  ['name:Nitesh kum'],
#  ['Score:happy:57.99999999999999\r'],
#  ['boxes:[929, 129, 44, 50]'],
#  ['name:Oeihalisteiaetiiee rao'],
#  ['Score:angry:45.0\r'],
#  ['boxes:[114, 312, 41, 51]'],
#  ['name:jel eisell elat: Mehta Mehta'],
#  ['Score:neutral:49.0\r'],
#  ['boxes:[83, 807, 57, 74]'],
#  ['name:Neeraj Fels;'],
#  ['Score:neutral:68.0\r'],
#  ['boxes:[1785, 819, 39, 45]'],
#  ['name:[@istitielscin Sarita foy-.'],
#  ['Score:neutral:52.0\r'],
#  ['boxes:[1771, 477, 58, 71]'],
#  ['name:Manich alles t-| om ney-tc'],
#  ['Score:neutral:82.0\r'],
#  ['boxes:[1557, 318, 73, 92]'],
#  ['name:lalelal o18 AMKI'],
#  ['Score:happy:59.0\r'],
#  ['boxes:[116, 98, 63, 78]'],
#  ['name:st Barnabas st Barnabas'],
#  ['Score:happy:97.0\r'],
#  ['boxes:[1366, 822, 52, 63]'],
#  ['name:Amar 012 Sarkan'],
#  ['Score:neutral:53.0\r'],
#  ['boxes:[1368, 457, 35, 44]'],
#  ['name:'],
#  ['Score:neutral:93.0\r'],
#  ['boxes:[1138, 786, 75, 98]'],
#  ['name:Ruchi Panse'],
#  ['Score:happy:36.0\r'],
#  ['boxes:[1372, 983, 45, 52]'],
#  ['name:'],
#  ['Score:neutral:65.0\r'],
#  ['boxes:[1577, 468, 50, 62]'],
#  ['name:Nandsani SF cele'],
#  ['Score:neutral:53.0\r'],
#  ['boxes:[1581, 129, 53, 64]'],
#  ["name:a'e-tateistelal rey-te) kumar th"],
#  ['Score:neutral:53.0\r'],
#  ['boxes:[1775, 275, 46, 54]'],
#  ['name:'],
#  ['Score:sad:28.000000000000004\r'],
#  ['boxes:[717, 289, 72, 92]'],
#  ['name:1) Garg Simran |'],
#  ['Score:neutral:69.0\r'],
#  ['boxes:[783, 963, 51, 62]'],
#  ['name:@ite ieisitia iva'],
#  ['Score:happy:55.00000000000001\r'],
#  ['boxes:[521, 159, 39, 48]'],
#  ['name:[Sie Sagar 086'],
#  ['Score:happy:48.0\r'],
#  ['boxes:[518, 809, 42, 51]'],
#  ['name:1 Singh Sharam. 098'],
#  ['Score:neutral:70.0\r'],
#  ['boxes:[1792, 660, 42, 50]'],
#  ['name:Raja'],
#  ['Score:sad:49.0\r'],
#  ['boxes:[1150, 650, 30, 37]'],
#  ['name:"laste ween Aditya foley'],
#  ['Score:fear:35.0\r'],
#  ['Frame No:2\r'],
#  ['boxes:[730, 803, 47, 57]'],
#  ['name:eset iceerl _bikkyl \\leskle-'],
#  ['Score:neutral:69.0\r'],
#  ['boxes:[295, 783, 50, 62]'],
#  ['name:4 NiteshwAfahari'],
#  ['Score:sad:43.0\r'],
#  ['boxes:[1146, 127, 52, 63]'],
#  ['name:aseivris eanal'],
#  ['Score:sad:42.0\r'],
#  ['boxes:[1161, 288, 68, 79]'],
#  ['name:HARSH SHARMA'],
#  ['Score:neutral:80.0\r'],
#  ['boxes:[88, 621, 57, 70]'],
#  ['name:032 Harch Rai'],
#  ['Score:neutral:79.0\r'],
#  ['boxes:[1791, 143, 39, 49]'],
#  ['name:Shukis Shvam 10?'],
#  ['Score:neutral:89.0\r'],
#  ['boxes:[303, 150, 49, 62]'],
#  ['name:Pooja Yadav'],
#  ['Score:neutral:67.0\r'],
#  ['boxes:[1376, 303, 44, 55]'],
#  ['name:Tat-t-34 Kumar 078'],
#  ['Score:neutral:81.0\r'],
#  ['boxes:[928, 274, 77, 99]'],
#  ['name:Kumar Amit |'],
#  ['Score:neutral:76.0\r'],
#  ['boxes:[725, 134, 58, 74]'],
#  ['name:NAVNITA KLIMARI,'],
#  ['Score:neutral:78.0\r'],
#  ['boxes:[1576, 618, 46, 59]'],
#  ['name:Meena mey.i0) Neetu.'],
#  ['Score:neutral:46.0\r'],
#  ['boxes:[529, 511, 38, 49]'],
#  ['name:Nitesh kum'],
#  ['Score:happy:59.0\r'],
#  ['boxes:[505, 643, 72, 88]'],
#  ['name:|Gupta Sonu 104'],
#  ['Score:fear:48.0\r'],
#  ['boxes:[114, 312, 41, 51]'],
#  ['name:jel eisell elat: Mehta Mehta'],
#  ['Score:neutral:49.0\r'],
#  ['boxes:[83, 807, 57, 74]'],
#  ['name:Neeraj Fels;'],
#  ['Score:neutral:68.0\r'],
#  ['boxes:[1771, 477, 58, 71]'],
#  ['name:Manich ney-t: alles t-| om'],
#  ['Score:neutral:82.0\r'],
#  ['boxes:[1785, 819, 39, 45]'],
#  ['name:[@istitielscin Sarita foy-.'],
#  ['Score:neutral:52.0\r'],
#  ['boxes:[116, 98, 63, 78]'],
#  ['name:st Barnabas st Barnabas'],
#  ['Score:happy:97.0\r'],
#  ['boxes:[1366, 822, 52, 63]'],
#  ['name:Amar 012 Sarkan'],
#  ['Score:neutral:53.0\r'],
#  ['boxes:[1368, 457, 35, 44]'],
#  ['name:'],
#  ['Score:neutral:93.0\r'],
#  ['boxes:[1557, 317, 74, 91]'],
#  ['name:Telelal 018 AKI'],
#  ['Score:happy:45.0\r'],
#  ['boxes:[931, 128, 42, 49]'],
#  ['name:eltattsseiseliiee rao'],
#  ['Score:angry:33.0\r'],
#  ['boxes:[1138, 786, 75, 98]'],
#  ['name:Ruchi Panse'],
#  ['Score:happy:39.0\r'],
#  ['boxes:[1372, 983, 45, 52]'],
#  ['name:'],
#  ['Score:neutral:65.0\r'],
#  ['boxes:[1577, 468, 50, 62]'],
#  ['name:NanGsani St cele'],
#  ['Score:neutral:53.0\r'],
#  ['boxes:[932, 481, 45, 54]'],
#  ['name:SudhSnshu ) Shrivastova |'],
#  ['Score:neutral:56.99999999999999\r'],
#  ['boxes:[1581, 129, 53, 64]'],
#  ["name:a'e-tateistelal rey-te) kumar th."],
#  ['Score:neutral:53.0\r'],
#  ['boxes:[717, 289, 72, 92]'],
#  ['name:1) Garg Simran |'],
#  ['Score:neutral:71.0\r'],
#  ['boxes:[1775, 275, 46, 54]'],
#  ['name:'],
#  ['Score:sad:28.000000000000004\r'],
#  ['boxes:[784, 962, 49, 63]'],
#  ['name:Gite, lelisitia riva'],
#  ['Score:happy:57.99999999999999\r'],
#  ['boxes:[522, 158, 38, 50]'],
#  ['name:Sagar [Chie 086'],
#  ['Score:happy:59.0\r'],
#  ['boxes:[518, 809, 42, 51]'],
#  ['name:1 Singh Sharam. 098'],
#  ['Score:neutral:70.0\r'],
#  ['boxes:[1792, 660, 42, 50]'],
#  ['name:Raja'],
#  ['Score:sad:49.0\r'],
#  ['boxes:[1150, 650, 30, 37]'],
#  ['name:"laste ween Aditya foley'],
#  ['Score:fear:34.0\r'],
#  ['Frame No:3\r'],
#  ['boxes:[295, 783, 50, 62]'],
#  ['name:4 NiteshwAfahari'],
#  ['Score:sad:42.0\r'],
#  ['boxes:[1146, 127, 52, 63]'],
#  ['name:aseivris eanal'],
#  ['Score:sad:42.0\r'],
#  ['boxes:[88, 621, 57, 70]'],
#  ['name:032 Harch Rai'],
#  ['Score:neutral:79.0\r'],
#  ['boxes:[731, 801, 46, 58]'],
#  ['name:_ bikkyl Yoaser-ines- a bvedleerl:'],
#  ['Score:neutral:47.0\r'],
#  ['boxes:[1791, 141, 39, 51]'],
#  ['name:Shvam Shukla 102 Yo'],
#  ['Score:neutral:91.0\r'],
#  ['boxes:[1375, 302, 45, 56]'],
#  ['name:ola t-34 Kumar 078'],
#  ['Score:neutral:88.0\r'],
#  ['boxes:[303, 150, 49, 62]'],
#  ['name:Pooja Yadav'],
#  ['Score:neutral:67.0\r'],
#  ['boxes:[1557, 318, 75, 92]'],
#  ['name:018 Singh AMKI'],
#  ['Score:happy:51.0\r'],
#  ['boxes:[725, 135, 59, 73]'],
#  ['name:KLMARI NAVNITA.'],
#  ['Score:neutral:81.0\r'],
#  ['boxes:[1366, 822, 52, 62]'],
#  ['name:Sarkar Amar 012'],
#  ['Score:neutral:59.0\r'],
#  ['boxes:[929, 276, 74, 97]'],
#  ['name:Kumar Amit'],
#  ['Score:neutral:72.0\r'],
#  ['boxes:[529, 511, 38, 49]'],
#  ['name:Nitesh kum'],
#  ['Score:happy:59.0\r'],
#  ['boxes:[505, 643, 72, 88]'],
#  ['name:| Gupta Sonu 104'],
#  ['Score:fear:48.0\r'],
#  ['boxes:[1166, 291, 64, 78]'],
#  ['name:SHARMA HARSH'],
#  ['Score:neutral:76.0\r'],
#  ['boxes:[114, 312, 41, 51]'],
#  ['name:jel eisell elat: Mehta Mehta'],
#  ['Score:neutral:49.0\r'],
#  ['boxes:[83, 807, 57, 74]'],
#  ['name:Neeraj Fels;'],
#  ['Score:neutral:68.0\r'],
#  ['boxes:[1771, 477, 58, 71]'],
#  ['name:Manich 048 alles t-| om'],
#  ['Score:neutral:82.0\r'],
#  ['boxes:[1785, 819, 39, 45]'],
#  ['name:[@istitielscin Sarita foy-.'],
#  ['Score:neutral:52.0\r'],
#  ['boxes:[116, 98, 63, 78]'],
#  ['name:st Barnabas st Barnabas'],
#  ['Score:happy:97.0\r'],
#  ['boxes:[1368, 457, 36, 45]'],
#  ['name:'],
#  ['Score:neutral:89.0\r'],
#  ['boxes:[931, 128, 42, 48]'],
#  ['name:irao -purushottama r'],
#  ['Score:angry:37.0\r'],
#  ['boxes:[1138, 786, 75, 98]'],
#  ['name:Ruchi Panse'],
#  ['Score:happy:39.0\r'],
#  ['boxes:[1372, 983, 45, 52]'],
#  ['name:'],
#  ['Score:neutral:65.0\r'],
#  ['boxes:[1577, 468, 50, 62]'],
#  ['name:NanGsani St cele'],
#  ['Score:neutral:53.0\r'],
#  ['boxes:[932, 481, 45, 54]'],
#  ['name:SudhSnshu ) Shrivastova |'],
#  ['Score:neutral:56.99999999999999\r'],
#  ['boxes:[717, 289, 72, 92]'],
#  ['name:1) Garg Simran |'],
#  ['Score:neutral:69.0\r'],
#  ['boxes:[1775, 275, 47, 55]'],
#  ['name:'],
#  ['Score:happy:28.999999999999996\r'],
#  ['boxes:[1581, 620, 41, 56]'],
#  ['name:i Meena  melon ) Neetu |'],
#  ['Score:neutral:44.0\r'],
#  ['boxes:[784, 962, 50, 63]'],
#  ['name:@ite Velsltla iva'],
#  ['Score:happy:56.99999999999999\r'],
#  ['boxes:[521, 159, 40, 49]'],
#  ['name:Sagar [Cltleir: 086'],
#  ['Score:happy:61.0\r'],
#  ['boxes:[1580, 128, 54, 69]'],
#  ['name:-kanchan kumar erie) th'],
#  ['Score:angry:42.0\r'],
#  ['boxes:[518, 809, 42, 51]'],
#  ['name:1 Singh Sharam. 098'],
#  ['Score:neutral:70.0\r'],
#  ['boxes:[1792, 660, 42, 50]'],
#  ['name:Raja'],
#  ['Score:sad:49.0\r'],
#  ['boxes:[1150, 649, 30, 38]'],
#  ['name:y Velie) Kumar Soni reley.'],
#  ['Score:fear:36.0\r'],
#  ['Frame No:4\r'],
#  ['boxes:[295, 783, 50, 62]'],
#  ['name:4 NiteshwAfahari'],
#  ['Score:sad:42.0\r'],
#  ['boxes:[1146, 127, 52, 63]'],
#  ['name:aseivris eanal'],
#  ['Score:sad:42.0\r'],
#  ['boxes:[88, 621, 57, 70]'],
#  ['name:032 Harch Rai'],
#  ['Score:neutral:79.0\r'],
#  ['boxes:[1791, 143, 38, 49]'],
#  ['name:Shukis Shvam 10?'],
#  ['Score:neutral:89.0\r'],
#  ['boxes:[731, 801, 46, 58]'],
#  ['name:_bikkyl lace laee a atleehy'],
#  ['Score:neutral:48.0\r'],
#  ['boxes:[1375, 302, 45, 56]'],
#  ['name:ola t-34 Kumar 078'],
#  ['Score:neutral:88.0\r'],
#  ['boxes:[1557, 318, 75, 92]'],
#  ['name:018 Singh AMKI'],
#  ['Score:happy:52.0\r'],
#  ['boxes:[303, 150, 49, 62]'],
#  ['name:Pooja Yadav'],
#  ['Score:neutral:67.0\r'],
#  ['boxes:[725, 135, 59, 73]'],
#  ['name:KLMARI NAVNITA.'],
#  ['Score:neutral:81.0\r'],
#  ['boxes:[1366, 822, 52, 62]'],
#  ['name:Sarkar Amar 012'],
#  ['Score:neutral:59.0\r'],
#  ['boxes:[113, 312, 42, 50]'],
#  ['name:jelaisell elated Mehta Mehta'],
#  ['Score:angry:37.0\r'],
#  ['boxes:[1772, 477, 57, 71]'],
#  ['name:Manich 048 alles t-| om'],
#  ['Score:neutral:83.0\r'],
#  ['boxes:[929, 279, 73, 95]'],
#  ['name:m40lesteial Amit K'],
#  ['Score:neutral:56.99999999999999\r'],
#  ['boxes:[505, 643, 72, 88]'],
#  ['name:| Gupta Sonu 104'],
#  ['Score:fear:48.0\r'],
#  ['boxes:[1166, 291, 64, 78]'],
#  ['name:SHARMA HARSH'],
#  ['Score:neutral:75.0\r'],
#  ['boxes:[83, 807, 57, 74]'],
#  ['name:Neeraj Fels;'],
#  ['Score:neutral:68.0\r'],
#  ['boxes:[1785, 819, 39, 45]'],
#  ['name:[@istitielscin Sarita foy-.'],
#  ['Score:neutral:52.0\r'],
#  ['boxes:[116, 98, 63, 78]'],
#  ['name:st Barnabas st Barnabas'],
#  ['Score:happy:97.0\r'],
#  ['boxes:[529, 511, 38, 49]'],
#  ['name:Nitesh kum'],
#  ['Score:happy:56.99999999999999\r'],
#  ['boxes:[1368, 457, 36, 45]'],
#  ['name:'],
#  ['Score:neutral:89.0\r'],
#  ['boxes:[931, 128, 42, 48]'],
#  ['name:irao -purushottama r'],
#  ['Score:angry:37.0\r'],
#  ['boxes:[1138, 786, 75, 98]'],
#  ['name:Ruchi Panse'],
#  ['Score:happy:39.0\r'],
#  ['boxes:[1372, 983, 45, 52]'],
#  ['name:'],
#  ['Score:neutral:65.0\r'],
#  ['boxes:[1577, 468, 50, 62]'],
#  ['name:NanGsani St cele'],
#  ['Score:neutral:53.0\r'],
#  ['boxes:[932, 481, 45, 54]'],
#  ['name:SudhSnshu ) Shrivastova |'],
#  ['Score:neutral:56.99999999999999\r'],
#  ['boxes:[717, 289, 72, 92]'],
#  ['name:1) Garg Simran |'],
#  ['Score:neutral:70.0\r'],
#  ['boxes:[1775, 275, 47, 55]'],
#  ['name:'],
#  ['Score:happy:28.999999999999996\r'],
#  ['boxes:[1581, 620, 41, 56]'],
#  ['name:i Meena  melon ) Neetu |'],
#  ['Score:neutral:44.0\r'],
#  ['boxes:[784, 962, 50, 63]'],
#  ['name:@ite Velsltla iva'],
#  ['Score:happy:56.99999999999999\r'],
#  ['boxes:[522, 158, 38, 48]'],
#  ['name:Cities iSlerid 086'],
#  ['Score:happy:54.0\r'],
#  ['boxes:[518, 809, 43, 52]'],
#  ['name:Singh Shivam 098'],
#  ['Score:neutral:64.0\r'],
#  ['boxes:[1580, 128, 54, 69]'],
#  ['name:-kanchan kumar erie) th'],
#  ['Score:angry:43.0\r'],
#  ['boxes:[1792, 660, 42, 50]'],
#  ['name:Raja'],
#  ['Score:sad:49.0\r'],
#  ['boxes:[1150, 649, 30, 38]'],
#  ['name:y Velie) Kumar Soni reley.'],
#  ['Score:fear:36.0\r'],
#  ['Frame No:5\r'],
#  ['boxes:[295, 783, 50, 62]'],
#  ['name:4 NiteshwAfahari'],
#  ['Score:sad:42.0\r'],
#  ['boxes:[88, 621, 57, 70]'],
#  ['name:032 Harch Rai'],
#  ['Score:neutral:79.0\r'],
#  ['boxes:[1162, 288, 67, 78]'],
#  ['name:HARSH CUIAPMA'],
#  ['Score:neutral:72.0\r'],
#  ['boxes:[1791, 143, 38, 49]'],
#  ['name:Shukis Shvam 10?'],
#  ['Score:neutral:89.0\r'],
#  ['boxes:[731, 801, 46, 58]'],
#  ['name:_bikkyl facste-laee- ia adleehry'],
#  ['Score:neutral:48.0\r'],
#  ['boxes:[726, 135, 58, 74]'],
#  ['name:rrAVs\\ing-@ KLMARI'],
#  ['Score:neutral:88.0\r'],
#  ['boxes:[1375, 302, 45, 56]'],
#  ['name:ola t-34 Kumar 078'],
#  ['Score:neutral:88.0\r'],
#  ['boxes:[303, 150, 49, 62]'],
#  ['name:Pooja Yadav'],
#  ['Score:neutral:67.0\r'],
#  ['boxes:[1558, 319, 74, 90]'],
#  ['name:Singh 018 ATTK)'],
#  ['Score:happy:53.0\r'],
#  ['boxes:[1366, 822, 52, 62]'],
#  ['name:Sarkar Amar 012'],
#  ['Score:neutral:59.0\r'],
#  ['boxes:[113, 312, 42, 50]'],
#  ['name:jelaisell elated Mehta Mehta'],
#  ['Score:angry:37.0\r'],
#  ['boxes:[1772, 477, 57, 71]'],
#  ['name:Manich 048 alles t-| om'],
#  ['Score:neutral:83.0\r'],
#  ['boxes:[929, 279, 73, 95]'],
#  ['name:a 4tlesteial Amit K'],
#  ['Score:neutral:56.99999999999999\r'],
#  ['boxes:[83, 807, 57, 74]'],
#  ['name:Neeraj Fels;'],
#  ['Score:neutral:68.0\r'],
#  ['boxes:[1785, 819, 39, 45]'],
#  ['name:[@istitielscin Sarita foy-.'],
#  ['Score:neutral:52.0\r'],
#  ['boxes:[116, 98, 63, 78]'],
#  ['name:st Barnabas st Barnabas'],
#  ['Score:happy:97.0\r'],
#  ['boxes:[529, 511, 38, 49]'],
#  ['name:Nitesh kum'],
#  ['Score:happy:56.99999999999999\r'],
#  ['boxes:[1368, 457, 35, 44]'],
#  ['name:'],
#  ['Score:neutral:93.0\r'],
#  ['boxes:[503, 642, 74, 89]'],
#  ['name:Gupta Sonu | 104'],
#  ['Score:fear:36.0\r'],
#  ['boxes:[1138, 785, 77, 99]'],
#  ['name:Ruchi Panse'],
#  ['Score:happy:33.0\r'],
#  ['boxes:[931, 128, 42, 48]'],
#  ['name:irao -purushottama r'],
#  ['Score:angry:37.0\r'],
#  ['boxes:[1372, 983, 45, 52]'],
#  ['name:'],
#  ['Score:neutral:65.0\r'],
#  ['boxes:[932, 481, 45, 54]'],
#  ['name:SudhSnshu ) Shrivastova |'],
#  ['Score:neutral:56.99999999999999\r'],
#  ['boxes:[717, 289, 72, 92]'],
#  ['name:1) Garg Simran |'],
#  ['Score:neutral:70.0\r'],
#  ['boxes:[1148, 128, 50, 65]'],
#  ['name:Kumawat Kainal'],
#  ['Score:sad:42.0\r'],
#  ['boxes:[1775, 275, 47, 55]'],
#  ['name:'],
#  ['Score:happy:27.0\r'],
#  ['boxes:[1578, 470, 50, 61]'],
#  ['name:Nan@ani Shz'],
#  ['Score:neutral:68.0\r'],
#  ['boxes:[1581, 620, 41, 56]'],
#  ['name:i Meena  melon ) Neetu |'],
#  ['Score:neutral:44.0\r'],
#  ['boxes:[784, 962, 50, 63]'],
#  ['name:@ite Velsltla iva'],
#  ['Score:happy:56.00000000000001\r'],
#  ['boxes:[522, 158, 38, 48]'],
#  ['name:Cities ilerid 086'],
#  ['Score:happy:53.0\r'],
#  ['boxes:[518, 809, 43, 52]'],
#  ['name:Singh Shivam 098'],
#  ['Score:neutral:64.0\r'],
#  ['boxes:[1580, 128, 54, 69]'],
#  ['name:-kanchan kumar erie) th'],
#  ['Score:angry:43.0\r'],
#  ['boxes:[1792, 660, 42, 50]'],
#  ['name:Raja'],
#  ['Score:sad:49.0\r'],
#  ['boxes:[1150, 649, 30, 38]'],
#  ['name:y Velie) Kumar Soni reley.'],
#  ['Score:fear:36.0\r'],
#  ['Frame No:6\r'],
#  ['boxes:[932, 278, 72, 97]'],
#  ['name:Kumar'],
#  ['Score:neutral:61.0\r'],
#  ['boxes:[88, 621, 57, 70]'],
#  ['name:032 Harch Rai'],
#  ['Score:neutral:79.0\r'],
#  ['boxes:[1162, 288, 67, 78]'],
#  ['name:HARSH CUIAPMA'],
#  ['Score:neutral:71.0\r'],
#  ['boxes:[295, 783, 50, 63]'],
#  ['name:mele Nifeewestshari'],
#  ['Score:sad:38.0\r'],
#  ['boxes:[1791, 143, 38, 49]'],
#  ['name:Shukla Shvam 10?'],
#  ['Score:neutral:88.0\r'],
#  ['boxes:[1377, 304, 43, 54]'],
#  ['name:tis = 738 Kumar Kumar'],
#  ['Score:neutral:79.0\r'],
#  ['boxes:[731, 801, 46, 58]'],
#  ['name:_bikkyl facste-laee- ia adleehry'],
#  ['Score:neutral:48.0\r'],
#  ['boxes:[726, 135, 58, 74]'],
#  ['name:rrAVs\\ing-@ KLMARI'],
#  ['Score:neutral:89.0\r'],
#  ['boxes:[303, 150, 49, 62]'],
#  ['name:Pooja Yadav'],
#  ['Score:neutral:67.0\r'],
#  ['boxes:[1366, 822, 52, 61]'],
#  ['name:Sarkar Amar 012'],
#  ['Score:neutral:90.0\r'],
#  ['boxes:[113, 312, 42, 50]'],
#  ['name:jelaisell elated Mehta Mehta'],
#  ['Score:angry:37.0\r'],
#  ['boxes:[1772, 477, 57, 71]'],
#  ['name:Manich 048 alles t-| om'],
#  ['Score:neutral:83.0\r'],
#  ['boxes:[83, 807, 57, 74]'],
#  ['name:Neeraj Fels;'],
#  ['Score:neutral:68.0\r'],
#  ['boxes:[1785, 819, 39, 45]'],
#  ['name:[@istitielscin Sarita foy-.'],
#  ['Score:neutral:52.0\r'],
#  ['boxes:[116, 98, 63, 78]'],
#  ['name:st Barnabas st Barnabas'],
#  ['Score:happy:97.0\r'],
#  ['boxes:[1557, 318, 74, 92]'],
#  ['name:o18 mS lalelal AQIKI'],
#  ['Score:happy:74.0\r'],
#  ['boxes:[529, 511, 38, 49]'],
#  ['name:Nitesh kum'],
#  ['Score:happy:56.99999999999999\r'],
#  ['boxes:[1368, 457, 36, 45]'],
#  ['name:'],
#  ['Score:neutral:88.0\r'],
#  ['boxes:[503, 642, 74, 89]'],
#  ['name:Gupta Sonu | 104'],
#  ['Score:sad:37.0\r'],
#  ['boxes:[1138, 785, 77, 99]'],
#  ['name:Ruchi Panse'],
#  ['Score:happy:32.0\r'],
#  ['boxes:[931, 128, 42, 48]'],
#  ['name:irao -purushottama r'],
#  ['Score:angry:37.0\r'],
#  ['boxes:[1372, 983, 45, 52]'],
#  ['name:'],
#  ['Score:neutral:65.0\r'],
#  ['boxes:[932, 481, 45, 54]'],
#  ['name:SudhSnshu ) Shrivastova |'],
#  ['Score:neutral:56.99999999999999\r'],
#  ['boxes:[717, 289, 72, 92]'],
#  ['name:1) Garg Simran |'],
#  ['Score:neutral:69.0\r'],
#  ['boxes:[1148, 128, 50, 65]'],
#  ['name:Kumawat Kainal'],
#  ['Score:sad:42.0\r'],
#  ['boxes:[1578, 470, 50, 61]'],
#  ['name:Nandani Shz'],
#  ['Score:neutral:68.0\r'],
#  ['boxes:[1774, 274, 48, 57]'],
#  ['name:'],
#  ['Score:sad:32.0\r'],
#  ['boxes:[784, 964, 50, 61]'],
#  ['name:Gite, lelsitia iva'],
#  ['Score:happy:56.99999999999999\r'],
#  ['boxes:[518, 809, 43, 52]'],
#  ['name:Singh Shivam 098'],
#  ['Score:neutral:64.0\r'],
#  ['boxes:[1578, 618, 44, 59]'],
#  ['name:Meena Neetu! mey-0)'],
#  ['Score:neutral:51.0\r'],
#  ['boxes:[1580, 128, 54, 69]'],
#  ['name:-kanchan kumar erie) th'],
#  ['Score:angry:43.0\r'],
#  ['boxes:[522, 157, 38, 48]'],
#  ['name:[Citiei = Siecle 086'],
#  ['Score:happy:28.000000000000004\r'],
#  ['boxes:[1792, 660, 42, 50]'],
#  ['name:Raja'],
#  ['Score:sad:49.0\r'],
#  ['boxes:[1149, 648, 30, 40]'],
#  ['name:Kumar Soni Seley Aditya'],
#  ['Score:sad:35.0\r'],
#  ['Frame No:7\r'],
#  ['boxes:[89, 621, 56, 69]'],
#  ['name:032 Harsh Rai'],
#  ['Score:neutral:79.0\r'],
#  ['boxes:[932, 277, 75, 97]'],
#  ['name:Amit Miumar'],
#  ['Score:neutral:74.0\r'],
#  ['boxes:[1162, 288, 67, 78]'],
#  ['name:HARSH CUIAPMA'],
#  ['Score:neutral:71.0\r'],
#  ['boxes:[113, 312, 43, 51]'],
#  ['name:jer ecisell eilat: Mehta Mehta'],
#  ['Score:neutral:59.0\r'],
#  ['boxes:[295, 783, 50, 63]'],
#  ['name:mele Nifeewestshari'],
#  ['Score:sad:40.0\r'],
#  ['boxes:[1377, 304, 43, 55]'],
#  ['name:Tl t-34 Kumar 078'],
#  ['Score:neutral:81.0\r'],
#  ['boxes:[1791, 143, 38, 49]'],
#  ['name:Shukla Shvam 10?'],
#  ['Score:neutral:88.0\r'],
#  ['boxes:[731, 801, 47, 58]'],
#  ['name:Be tay leerleesericern'],
#  ['Score:neutral:59.0\r'],
#  ['boxes:[726, 135, 58, 74]'],
#  ['name:rrAVs\\ing-@ KLMARI'],
#  ['Score:neutral:88.0\r'],
#  ['boxes:[303, 150, 49, 62]'],
#  ['name:Pooja Yadav'],
#  ['Score:neutral:67.0\r'],
#  ['boxes:[83, 807, 57, 74]'],
#  ['name:Neeraj Fels;'],
#  ['Score:neutral:68.0\r'],
#  ['boxes:[1772, 477, 57, 71]'],
#  ['name:Manich 048 alles | am'],
#  ['Score:neutral:82.0\r'],
#  ['boxes:[1785, 819, 39, 45]'],
#  ['name:[@istitielscin Sarita foy-.'],
#  ['Score:neutral:52.0\r'],
#  ['boxes:[1367, 822, 51, 62]'],
#  ['name:Sarkar Amar. 012'],
#  ['Score:neutral:61.0\r'],
#  ['boxes:[116, 98, 63, 78]'],
#  ['name:st Barnabas st Barnabas'],
#  ['Score:happy:97.0\r'],
#  ['boxes:[1557, 318, 74, 92]'],
#  ['name:o18 om lalelal AQIKI'],
#  ['Score:happy:74.0\r'],
#  ['boxes:[529, 511, 38, 49]'],
#  ['name:Nitesh kum'],
#  ['Score:happy:56.99999999999999\r'],
#  ['boxes:[1368, 457, 36, 45]'],
#  ['name:'],
#  ['Score:neutral:88.0\r'],
#  ['boxes:[501, 640, 74, 92]'],
#  ['name:Gupta Sonu Sey!'],
#  ['Score:fear:35.0\r'],
#  ['boxes:[1138, 785, 77, 99]'],
#  ['name:Ruchi Panse'],
#  ['Score:happy:32.0\r'],
#  ['boxes:[931, 128, 42, 48]'],
#  ['name:irao -purushottama r'],
#  ['Score:angry:37.0\r'],
#  ['boxes:[1372, 983, 45, 52]'],
#  ['name:'],
#  ['Score:neutral:65.0\r'],
#  ['boxes:[1582, 129, 52, 65]'],
#  ['name:"et ateistelal rey-te) kumar th.'],
#  ['Score:neutral:37.0\r'],
#  ['boxes:[932, 481, 45, 54]'],
#  ['name:SudhSnshu ) Shrivastova |'],
#  ['Score:neutral:56.99999999999999\r'],
#  ['boxes:[717, 289, 72, 92]'],
#  ['name:1) Garg Simran |'],
#  ['Score:neutral:69.0\r'],
#  ['boxes:[1775, 274, 47, 57]'],
#  ['name:'],
#  ['Score:sad:32.0\r'],
#  ['boxes:[1148, 128, 50, 65]'],
#  ['name:Kumawat Kainal'],
#  ['Score:sad:42.0\r'],
#  ['boxes:[1578, 470, 50, 61]'],
#  ['name:Nandani Shz'],
#  ['Score:neutral:68.0\r'],
#  ['boxes:[784, 964, 50, 61]'],
#  ['name:Gite, leisitia iva'],
#  ['Score:happy:57.99999999999999\r'],
#  ['boxes:[518, 809, 43, 52]'],
#  ['name:Singh Shivam 098'],
#  ['Score:neutral:64.0\r'],
#  ['boxes:[1578, 618, 44, 59]'],
#  ['name:Meena Neetu! mey-0)'],
#  ['Score:neutral:51.0\r'],
#  ['boxes:[522, 157, 38, 48]'],
#  ['name:[Citiei = Siecle 086'],
#  ['Score:happy:27.0\r'],
#  ['boxes:[1792, 660, 42, 50]'],
#  ['name:Raja'],
#  ['Score:sad:49.0\r'],
#  ['boxes:[1149, 648, 30, 40]'],
#  ['name:Kumar Soni Seley Aditya'],
#  ['Score:sad:35.0\r'],
#  ['Frame No:8\r'],
#  ['boxes:[89, 621, 56, 69]'],
#  ['name:032 Harsh Rai'],
#  ['Score:neutral:79.0\r'],
#  ['boxes:[932, 277, 75, 97]'],
#  ['name:Amit Miumar'],
#  ['Score:neutral:74.0\r'],
#  ['boxes:[113, 312, 43, 51]'],
#  ['name:jer ecisell eilat: Mehta Mehta'],
#  ['Score:neutral:60.0\r'],
#  ['boxes:[295, 783, 50, 63]'],
#  ['name:mele Nifeewestshari'],
#  ['Score:sad:40.0\r'],
#  ['boxes:[1377, 304, 43, 55]'],
#  ['name:Tl t-34 Kumar 078'],
#  ['Score:neutral:81.0\r'],
#  ['boxes:[731, 801, 47, 58]'],
#  ['name:Be tay llesllaeseriaerch'],
#  ['Score:neutral:59.0\r'],
#  ['boxes:[1791, 141, 39, 51]'],
#  ['name:Shvam Shukis 102'],
#  ['Score:neutral:92.0\r'],
#  ['boxes:[726, 135, 58, 74]'],
#  ['name:rrAVs\\ing-@ KLMARI'],
#  ['Score:neutral:88.0\r'],
#  ['boxes:[303, 150, 49, 62]'],
#  ['name:Pooja Yadav'],
#  ['Score:neutral:67.0\r'],
#  ['boxes:[1368, 457, 35, 45]'],
#  ['name:'],
#  ['Score:neutral:88.0\r'],
#  ['boxes:[1786, 819, 38, 45]'],
#  ['name:Chaudhary "Sarita 044'],
#  ['Score:neutral:40.0\r'],
#  ['boxes:[83, 807, 57, 74]'],
#  ['name:Neeraj Fels;'],
#  ['Score:neutral:68.0\r'],
#  ['boxes:[1772, 477, 57, 71]'],
#  ['name:Manich 048 alles | am'],
#  ['Score:neutral:82.0\r'],
#  ['boxes:[1367, 822, 51, 62]'],
#  ['name:Sarkar Amar. 012'],
#  ['Score:neutral:61.0\r'],
#  ['boxes:[116, 98, 63, 78]'],
#  ['name:st Barnabas st Barnabas'],
#  ['Score:happy:97.0\r'],
#  ['boxes:[1167, 291, 63, 76]'],
#  ['name:SHARMA LARSL'],
#  ['Score:neutral:77.0\r'],
#  ['boxes:[1557, 318, 74, 92]'],
#  ['name:o18 om lalelal AQIKI'],
#  ['Score:happy:74.0\r'],
#  ['boxes:[529, 511, 38, 49]'],
#  ['name:Nitesh kum'],
#  ['Score:happy:56.99999999999999\r'],
#  ['boxes:[501, 640, 74, 93]'],
#  ['name:Sonu Gupta 104'],
#  ['Score:sad:39.0\r'],
#  ['boxes:[931, 128, 42, 48]'],
#  ['name:irao -purushottama r'],
#  ['Score:angry:37.0\r'],
#  ['boxes:[1372, 983, 45, 52]'],
#  ['name:'],
#  ['Score:neutral:65.0\r'],
#  ['boxes:[1138, 786, 75, 98]'],
#  ['name:Ruchi Panse'],
#  ['Score:happy:37.0\r'],
#  ['boxes:[1582, 129, 52, 65]'],
#  ['name:"et ateistelal rey-te) kumar th.'],
#  ['Score:neutral:37.0\r'],
#  ['boxes:[523, 157, 37, 47]'],
#  ['name:SHleris Che 086'],
#  ['Score:happy:32.0\r'],
#  ['boxes:[717, 290, 72, 91]'],
#  ['name:Garg Thaales ial'],
#  ['Score:neutral:63.0\r'],
#  ['boxes:[1775, 274, 47, 57]'],
#  ['name:'],
#  ['Score:sad:33.0\r'],
#  ['boxes:[1148, 128, 50, 65]'],
#  ['name:Kumawat Kainal'],
#  ['Score:sad:42.0\r'],
#  ['boxes:[1578, 470, 50, 61]'],
#  ['name:Nandani Shz'],
#  ['Score:neutral:68.0\r'],
#  ['boxes:[933, 480, 44, 55]'],
#  ['name:Sudh4nshu Shrivastava'],
#  ['Score:neutral:65.0\r'],
#  ['boxes:[784, 964, 50, 61]'],
#  ['name:Gite, leisitia iva'],
#  ['Score:happy:57.99999999999999\r'],
#  ['boxes:[1578, 618, 44, 59]'],
#  ['name:Meena Neetu! mey-0)'],
#  ['Score:neutral:51.0\r'],
#  ['boxes:[519, 809, 43, 51]'],
#  ['name:Shrram )Singh 098'],
#  ['Score:neutral:63.0\r'],
#  ['boxes:[1792, 660, 42, 50]'],
#  ['name:Raja'],
#  ['Score:sad:49.0\r'],
#  ['boxes:[1149, 648, 30, 40]'],
#  ['name:Kumar Soni Seley Aditya'],
#  ['Score:sad:35.0\r'],
#  ['Frame No:9\r'],
#  ['boxes:[90, 622, 55, 68]'],
#  ['name:032 Harsh Rai'],
#  ['Score:neutral:80.0\r'],
#  ['boxes:[113, 312, 43, 51]'],
#  ['name:jel aisell elal: Mehta Mehta'],
#  ['Score:neutral:60.0\r'],
#  ['boxes:[295, 783, 50, 63]'],
#  ['name:mele Nifeewestshari'],
#  ['Score:sad:40.0\r'],
#  ['boxes:[1377, 304, 43, 55]'],
#  ['name:Tl t-34 Kumar 078'],
#  ['Score:neutral:81.0\r'],
#  ['boxes:[932, 277, 75, 100]'],
#  ['name:Amit Kumar'],
#  ['Score:neutral:69.0\r'],
#  ['boxes:[1791, 144, 38, 48]'],
#  ['name:Shyam Shukla 102 vo'],
#  ['Score:neutral:87.0\r'],
#  ['boxes:[731, 801, 47, 58]'],
#  ['name:Be tay leslaeseriaeerch'],
#  ['Score:neutral:59.0\r'],
#  ['boxes:[726, 135, 58, 73]'],
#  ['name:NAVNITA | KIIMARI'],
#  ['Score:neutral:77.0\r'],
#  ['boxes:[1575, 619, 47, 59]'],
#  ['name:1 Meena Rey.10) _Neetu'],
#  ['Score:neutral:55.00000000000001\r'],
#  ['boxes:[1367, 824, 49, 60]'],
#  ['name:Amar Sarkan 012'],
#  ['Score:neutral:53.0\r'],
#  ['boxes:[303, 150, 49, 62]'],
#  ['name:Pooja Yadav'],
#  ['Score:neutral:67.0\r'],
#  ['boxes:[1368, 457, 35, 45]'],
#  ['name:'],
#  ['Score:neutral:88.0\r'],
#  ['boxes:[1786, 819, 38, 45]'],
#  ['name:Chaudhary "Sarita 044'],
#  ['Score:neutral:41.0\r'],
#  ['boxes:[83, 807, 57, 74]'],
#  ['name:Neeraj Fels;'],
#  ['Score:neutral:68.0\r'],
#  ['boxes:[1772, 477, 57, 71]'],
#  ['name:Manich 048 alles | am'],
#  ['Score:neutral:82.0\r'],
#  ['boxes:[116, 98, 63, 78]'],
#  ['name:st Barnabas st Barnabas'],
#  ['Score:happy:97.0\r'],
#  ['boxes:[1167, 291, 63, 76]'],
#  ['name:SHARMA LARSL'],
#  ['Score:neutral:77.0\r'],
#  ['boxes:[1557, 318, 74, 92]'],
#  ['name:o18 om lalelal AQIKI'],
#  ['Score:happy:74.0\r'],
#  ['boxes:[501, 640, 74, 93]'],
#  ['name:Sonu Gupta 104'],
#  ['Score:sad:39.0\r'],
#  ['boxes:[529, 511, 39, 49]'],
#  ['name:Nitesh kum'],
#  ['Score:happy:60.0\r'],
#  ['boxes:[1138, 785, 77, 100]'],
#  ['name:Ruchi | Panse'],
#  ['Score:happy:45.0\r'],
#  ['boxes:[1372, 983, 45, 52]'],
#  ['name:'],
#  ['Score:neutral:65.0\r'],
#  ['boxes:[1582, 129, 52, 65]'],
#  ['name:"et ateistelal rey-te) kumar th.'],
#  ['Score:neutral:37.0\r'],
#  ['boxes:[930, 128, 43, 49]'],
#  ['name:oetllaltisteiaetiie ns rao'],
#  ['Score:angry:32.0\r'],
#  ['boxes:[522, 157, 38, 46]'],
#  ['name:Che Sagar 086'],
#  ['Score:happy:43.0\r'],
#  ['boxes:[717, 290, 72, 91]'],
#  ['name:Garg Thaales ial'],
#  ['Score:neutral:63.0\r'],
#  ['boxes:[1775, 276, 47, 56]'],
#  ['name:'],
#  ['Score:happy:33.0\r'],
#  ['boxes:[1148, 128, 50, 65]'],
#  ['name:Kumawat Kainal'],
#  ['Score:sad:42.0\r'],
#  ['boxes:[933, 480, 44, 55]'],
#  ['name:Sudh4nshu_ Shrivastava'],
#  ['Score:neutral:66.0\r'],
#  ['boxes:[1577, 470, 50, 60]'],
#  ['name:Nandsni St hah'],
#  ['Score:neutral:70.0\r'],
#  ['boxes:[784, 964, 50, 61]'],
#  ['name:Gite, leisitia iva'],
#  ['Score:happy:62.0\r'],
#  ['boxes:[1149, 650, 30, 38]'],
#  ['name:Kumar feley-a Aditya Teta]'],
#  ['Score:fear:33.0\r'],
#  ['boxes:[519, 809, 43, 51]'],
#  ['name:Shrram )Singh 098'],
#  ['Score:neutral:61.0\r'],
#  ['boxes:[1792, 660, 42, 50]'],
#  ['name:Raja'],
#  ['Score:sad:49.0\r'],
#  ['Frame No:10\r'],
#  ['boxes:[90, 622, 55, 68]'],
#  ['name:032 Harsh Rai'],
#  ['Score:neutral:80.0\r'],
#  ['boxes:[933, 279, 75, 94]'],
#  ['name:Kumar Amit'],
#  ['Score:neutral:76.0\r'],
#  ['boxes:[113, 312, 43, 51]'],
#  ['name:jel aisell elal: Mehta Mehta'],
#  ['Score:neutral:60.0\r'],
#  ['boxes:[1376, 304, 44, 55]'],
#  ['name:Tl t-34 Kumar 078'],
#  ['Score:neutral:80.0\r'],
#  ['boxes:[295, 783, 51, 62]'],
#  ['name:mely 9 4 NitstwAfahari'],
#  ['Score:sad:46.0\r'],
#  ['boxes:[731, 801, 47, 58]'],
#  ['name:Be tay lleslaeseriaerchn'],
#  ['Score:neutral:59.0\r'],
#  ['boxes:[1791, 141, 39, 51]'],
#  ['name:Shvam Shukis 102'],
#  ['Score:neutral:93.0\r'],
#  ['boxes:[726, 135, 58, 73]'],
#  ['name:NAVNITA | KIIMARI'],
#  ['Score:neutral:76.0\r'],
#  ['boxes:[1575, 619, 47, 59]'],
#  ['name:1 Meena Rey.10) _Neetu'],
#  ['Score:neutral:55.00000000000001\r'],
#  ['boxes:[1367, 824, 49, 60]'],
#  ['name:Amar Sarkan 012'],
#  ['Score:neutral:54.0\r'],
#  ['boxes:[303, 150, 49, 62]'],
#  ['name:Pooja Yadav'],
#  ['Score:neutral:67.0\r'],
#  ['boxes:[1368, 457, 35, 45]'],
#  ['name:'],
#  ['Score:neutral:88.0\r'],
#  ['boxes:[1786, 819, 38, 45]'],
#  ['name:Chaudhary "Sarita 044'],
#  ['Score:neutral:41.0\r'],
#  ['boxes:[83, 807, 57, 74]'],
#  ['name:Neeraj Fels;'],
#  ['Score:neutral:68.0\r'],
#  ['boxes:[1772, 477, 57, 71]'],
#  ['name:Manich 048 alles | am'],
#  ['Score:neutral:82.0\r'],
#  ['boxes:[1167, 291, 63, 76]'],
#  ['name:SHARMA LARSL'],
#  ['Score:neutral:78.0\r'],
#  ['boxes:[116, 98, 63, 78]'],
#  ['name:st Barnabas st Barnabas'],
#  ['Score:happy:97.0\r'],
#  ['boxes:[1559, 319, 73, 90]'],
#  ['name:otislelal o18 ,'],
#  ['Score:happy:61.0\r'],
#  ['boxes:[500, 641, 74, 92]'],
#  ['name:Sonu Gupta 104'],
#  ['Score:angry:30.0\r'],
#  ['boxes:[529, 511, 39, 49]'],
#  ['name:Nitesh kum'],
#  ['Score:happy:60.0\r'],
#  ['boxes:[1775, 276, 47, 57]'],
#  ['name:'],
#  ['Score:sad:28.999999999999996\r'],
#  ['boxes:[1138, 785, 77, 100]'],
#  ['name:Ruchi | Panse'],
#  ['Score:happy:45.0\r'],
#  ['boxes:[1372, 983, 45, 52]'],
#  ['name:'],
#  ['Score:neutral:65.0\r'],
#  ['boxes:[1582, 129, 51, 65]'],
#  ['name:kanchan kumar rer-te th...'],
#  ['Score:neutral:42.0\r'],
#  ...]

# %%
# s1
names = []
emotions = []
for i in range(len(s1)):
  for j in range(len(s1[i])):
      try:
        if s1[i][0][0]=='n':
          names.append(s1[i][j].split(':')[1])
        if s1[i][0][0]=='S':
          emotions.append(s1[i][j].split(':')[1])
      except:
        continue

# %%
names
# Out:
# ['eset iceerl _bikkyl \\leskle-',
#  '4 NiteshAfahari',
#  'aseivris eanal',
#  'HARSH SHARMA',
#  '032 Harsch Rai',
#  'Shyam is Flare 102 >',
#  'Shrivast BStrelst ls alll TVa',
#  'Pooja Yadav',
#  'Tat-t-34 Kumar 078',
#  'Kumar Amit |',
#  'NAVNITA KLIMARI,',
#  'Gupta Sonu | 104',
#  'Meena mey.i0) Neetu.',
#  'Nitesh kum',
#  'Oeihalisteiaetiiee rao',
#  'jel eisell elat',
#  'Neeraj Fels;',
#  '[@istitielscin Sarita foy-.',
#  'Manich alles t-| om ney-tc',
#  'lalelal o18 AMKI',
#  'st Barnabas st Barnabas',
#  'Amar 012 Sarkan',
#  '',
#  'Ruchi Panse',
#  '',
#  'Nandsani SF cele',
#  "a'e-tateistelal rey-te) kumar th",
#  '',
#  '1) Garg Simran |',
#  '@ite ieisitia iva',
#  '[Sie Sagar 086',
#  '1 Singh Sharam. 098',
#  'Raja',
#  '"laste ween Aditya foley',
#  'eset iceerl _bikkyl \\leskle-',
#  '4 NiteshwAfahari',
#  'aseivris eanal',
#  'HARSH SHARMA',
#  '032 Harch Rai',
#  'Shukis Shvam 10?',
#  'Pooja Yadav',
#  'Tat-t-34 Kumar 078',
#  'Kumar Amit |',
#  'NAVNITA KLIMARI,',
#  'Meena mey.i0) Neetu.',
#  'Nitesh kum',
#  '|Gupta Sonu 104',
#  'jel eisell elat',
#  'Neeraj Fels;',
#  'Manich ney-t',
#  '[@istitielscin Sarita foy-.',
#  'st Barnabas st Barnabas',
#  'Amar 012 Sarkan',
#  '',
#  'Telelal 018 AKI',
#  'eltattsseiseliiee rao',
#  'Ruchi Panse',
#  '',
#  'NanGsani St cele',
#  'SudhSnshu ) Shrivastova |',
#  "a'e-tateistelal rey-te) kumar th.",
#  '1) Garg Simran |',
#  '',
#  'Gite, lelisitia riva',
#  'Sagar [Chie 086',
#  '1 Singh Sharam. 098',
#  'Raja',
#  '"laste ween Aditya foley',
#  '4 NiteshwAfahari',
#  'aseivris eanal',
#  '032 Harch Rai',
#  '_ bikkyl Yoaser-ines- a bvedleerl',
#  'Shvam Shukla 102 Yo',
#  'ola t-34 Kumar 078',
#  'Pooja Yadav',
#  '018 Singh AMKI',
#  'KLMARI NAVNITA.',
#  'Sarkar Amar 012',
#  'Kumar Amit',
#  'Nitesh kum',
#  '| Gupta Sonu 104',
#  'SHARMA HARSH',
#  'jel eisell elat',
#  'Neeraj Fels;',
#  'Manich 048 alles t-| om',
#  '[@istitielscin Sarita foy-.',
#  'st Barnabas st Barnabas',
#  '',
#  'irao -purushottama r',
#  'Ruchi Panse',
#  '',
#  'NanGsani St cele',
#  'SudhSnshu ) Shrivastova |',
#  '1) Garg Simran |',
#  '',
#  'i Meena  melon ) Neetu |',
#  '@ite Velsltla iva',
#  'Sagar [Cltleir',
#  '-kanchan kumar erie) th',
#  '1 Singh Sharam. 098',
#  'Raja',
#  'y Velie) Kumar Soni reley.',
#  '4 NiteshwAfahari',
#  'aseivris eanal',
#  '032 Harch Rai',
#  'Shukis Shvam 10?',
#  '_bikkyl lace laee a atleehy',
#  'ola t-34 Kumar 078',
#  '018 Singh AMKI',
#  'Pooja Yadav',
#  'KLMARI NAVNITA.',
#  'Sarkar Amar 012',
#  'jelaisell elated Mehta Mehta',
#  'Manich 048 alles t-| om',
#  'm40lesteial Amit K',
#  '| Gupta Sonu 104',
#  'SHARMA HARSH',
#  'Neeraj Fels;',
#  '[@istitielscin Sarita foy-.',
#  'st Barnabas st Barnabas',
#  'Nitesh kum',
#  '',
#  'irao -purushottama r',
#  'Ruchi Panse',
#  '',
#  'NanGsani St cele',
#  'SudhSnshu ) Shrivastova |',
#  '1) Garg Simran |',
#  '',
#  'i Meena  melon ) Neetu |',
#  '@ite Velsltla iva',
#  'Cities iSlerid 086',
#  'Singh Shivam 098',
#  '-kanchan kumar erie) th',
#  'Raja',
#  'y Velie) Kumar Soni reley.',
#  '4 NiteshwAfahari',
#  '032 Harch Rai',
#  'HARSH CUIAPMA',
#  'Shukis Shvam 10?',
#  '_bikkyl facste-laee- ia adleehry',
#  'rrAVs\\ing-@ KLMARI',
#  'ola t-34 Kumar 078',
#  'Pooja Yadav',
#  'Singh 018 ATTK)',
#  'Sarkar Amar 012',
#  'jelaisell elated Mehta Mehta',
#  'Manich 048 alles t-| om',
#  'a 4tlesteial Amit K',
#  'Neeraj Fels;',
#  '[@istitielscin Sarita foy-.',
#  'st Barnabas st Barnabas',
#  'Nitesh kum',
#  '',
#  'Gupta Sonu | 104',
#  'Ruchi Panse',
#  'irao -purushottama r',
#  '',
#  'SudhSnshu ) Shrivastova |',
#  '1) Garg Simran |',
#  'Kumawat Kainal',
#  '',
#  'Nan@ani Shz',
#  'i Meena  melon ) Neetu |',
#  '@ite Velsltla iva',
#  'Cities ilerid 086',
#  'Singh Shivam 098',
#  '-kanchan kumar erie) th',
#  'Raja',
#  'y Velie) Kumar Soni reley.',
#  'Kumar',
#  '032 Harch Rai',
#  'HARSH CUIAPMA',
#  'mele Nifeewestshari',
#  'Shukla Shvam 10?',
#  'tis = 738 Kumar Kumar',
#  '_bikkyl facste-laee- ia adleehry',
#  'rrAVs\\ing-@ KLMARI',
#  'Pooja Yadav',
#  'Sarkar Amar 012',
#  'jelaisell elated Mehta Mehta',
#  'Manich 048 alles t-| om',
#  'Neeraj Fels;',
#  '[@istitielscin Sarita foy-.',
#  'st Barnabas st Barnabas',
#  'o18 mS lalelal AQIKI',
#  'Nitesh kum',
#  '',
#  'Gupta Sonu | 104',
#  'Ruchi Panse',
#  'irao -purushottama r',
#  '',
#  'SudhSnshu ) Shrivastova |',
#  '1) Garg Simran |',
#  'Kumawat Kainal',
#  'Nandani Shz',
#  '',
#  'Gite, lelsitia iva',
#  'Singh Shivam 098',
#  'Meena Neetu! mey-0)',
#  '-kanchan kumar erie) th',
#  '[Citiei = Siecle 086',
#  'Raja',
#  'Kumar Soni Seley Aditya',
#  '032 Harsh Rai',
#  'Amit Miumar',
#  'HARSH CUIAPMA',
#  'jer ecisell eilat',
#  'mele Nifeewestshari',
#  'Tl t-34 Kumar 078',
#  'Shukla Shvam 10?',
#  'Be tay leerleesericern',
#  'rrAVs\\ing-@ KLMARI',
#  'Pooja Yadav',
#  'Neeraj Fels;',
#  'Manich 048 alles | am',
#  '[@istitielscin Sarita foy-.',
#  'Sarkar Amar. 012',
#  'st Barnabas st Barnabas',
#  'o18 om lalelal AQIKI',
#  'Nitesh kum',
#  '',
#  'Gupta Sonu Sey!',
#  'Ruchi Panse',
#  'irao -purushottama r',
#  '',
#  '"et ateistelal rey-te) kumar th.',
#  'SudhSnshu ) Shrivastova |',
#  '1) Garg Simran |',
#  '',
#  'Kumawat Kainal',
#  'Nandani Shz',
#  'Gite, leisitia iva',
#  'Singh Shivam 098',
#  'Meena Neetu! mey-0)',
#  '[Citiei = Siecle 086',
#  'Raja',
#  'Kumar Soni Seley Aditya',
#  '032 Harsh Rai',
#  'Amit Miumar',
#  'jer ecisell eilat',
#  'mele Nifeewestshari',
#  'Tl t-34 Kumar 078',
#  'Be tay llesllaeseriaerch',
#  'Shvam Shukis 102',
#  'rrAVs\\ing-@ KLMARI',
#  'Pooja Yadav',
#  '',
#  'Chaudhary "Sarita 044',
#  'Neeraj Fels;',
#  'Manich 048 alles | am',
#  'Sarkar Amar. 012',
#  'st Barnabas st Barnabas',
#  'SHARMA LARSL',
#  'o18 om lalelal AQIKI',
#  'Nitesh kum',
#  'Sonu Gupta 104',
#  'irao -purushottama r',
#  '',
#  'Ruchi Panse',
#  '"et ateistelal rey-te) kumar th.',
#  'SHleris Che 086',
#  'Garg Thaales ial',
#  '',
#  'Kumawat Kainal',
#  'Nandani Shz',
#  'Sudh4nshu Shrivastava',
#  'Gite, leisitia iva',
#  'Meena Neetu! mey-0)',
#  'Shrram )Singh 098',
#  'Raja',
#  'Kumar Soni Seley Aditya',
#  '032 Harsh Rai',
#  'jel aisell elal',
#  'mele Nifeewestshari',
#  'Tl t-34 Kumar 078',
#  'Amit Kumar',
#  'Shyam Shukla 102 vo',
#  'Be tay leslaeseriaeerch',
#  'NAVNITA | KIIMARI',
#  '1 Meena Rey.10) _Neetu',
#  'Amar Sarkan 012',
#  'Pooja Yadav',
#  '',
#  'Chaudhary "Sarita 044',
#  'Neeraj Fels;',
#  'Manich 048 alles | am',
#  'st Barnabas st Barnabas',
#  'SHARMA LARSL',
#  'o18 om lalelal AQIKI',
#  'Sonu Gupta 104',
#  'Nitesh kum',
#  'Ruchi | Panse',
#  '',
#  '"et ateistelal rey-te) kumar th.',
#  'oetllaltisteiaetiie ns rao',
#  'Che Sagar 086',
#  'Garg Thaales ial',
#  '',
#  'Kumawat Kainal',
#  'Sudh4nshu_ Shrivastava',
#  'Nandsni St hah',
#  'Gite, leisitia iva',
#  'Kumar feley-a Aditya Teta]',
#  'Shrram )Singh 098',
#  'Raja',
#  '032 Harsh Rai',
#  'Kumar Amit',
#  'jel aisell elal',
#  'Tl t-34 Kumar 078',
#  'mely 9 4 NitstwAfahari',
#  'Be tay lleslaeseriaerchn',
#  'Shvam Shukis 102',
#  'NAVNITA | KIIMARI',
#  '1 Meena Rey.10) _Neetu',
#  'Amar Sarkan 012',
#  'Pooja Yadav',
#  '',
#  'Chaudhary "Sarita 044',
#  'Neeraj Fels;',
#  'Manich 048 alles | am',
#  'SHARMA LARSL',
#  'st Barnabas st Barnabas',
#  'otislelal o18 ,',
#  'Sonu Gupta 104',
#  'Nitesh kum',
#  '',
#  'Ruchi | Panse',
#  '',
#  'kanchan kumar rer-te th...',
#  'oetllaltisteiaetiie ns rao',
#  'Kumawat Runal',
#  'Garg Thaales ial',
#  'Ve 2S oe',
#  'Sudh4nshu Shrivastava',
#  'Kumar feley-a Aditya Teta]',
#  '@ite, lelsitia iva',
#  'Chet Sagar (O}s{.)',
#  'Raja',
#  '1 Singh Sham. 098',
#  '032 Harsh Rai',
#  'jel aisell elal',
#  '7 \\eslia Kumar',
#  'Tl t-34 Kumar 078',
#  'mely 9 4 NitstwAfahari',
#  'Be tay lleslaeseriaerchn',
#  'Shvam Shukis 102',
#  'NAVNITA | KIIMARI',
#  '1 Meena Rey.10) _Neetu',
#  'Amar Sarkan 012',
#  '',
#  'Manich 048 loirmear',
#  'Chaudhary "Sarita 044',
#  'Neeraj Fels;',
#  'st Barnabas st Barnabas',
#  'otislelal o18 ,',
#  'Sonu Gupta 104',
#  'HARSH SHARMA',
#  'Nitesh kum',
#  'Pooja Yadav',
#  '',
#  'Shrivaet  SodhSnchu TV3',
#  '-Ruchi Panse',
#  '',
#  'oetllaltisteiaetiie ns rao',
#  'Kumawat Runal',
#  'Garg Thaales ial',
#  'i "eatelst lat rer-te kumar th.',
#  'Ve 2S oe',
#  'Kumar feley-a Aditya Teta]',
#  '@ite, lelsitia iva',
#  'Chet Sagar (O}s{.)',
#  'Raja',
#  '1 Singh Sham. 098',
#  '032 Harsh Rai',
#  'Tl t-34 Kumar 078',
#  'yYestia Kumar',
#  'mely 9 4 NitstwAfahari',
#  'Bel tay sSlieertlc Ser leee ae',
#  'NAVNITA | KIIMARI',
#  'Amar Sarkan 012',
#  'Shvam Shukis 102',
#  'Manish 048 loormar',
#  '',
#  'Nitesh detlestel',
#  'Neeraj Fels;',
#  'Chaudhary Sarita 044',
#  'st Barnabas st Barnabas',
#  'otislelal o18 ,',
#  'be laisall eilait Mehta Mehta',
#  'HARSH SHARMA',
#  '-Ruchi | /Panse',
#  'Pooja Yadav',
#  '',
#  'Sudh3nshu Shrivasteyv',
#  'oetllaltisteiaetiie ns rao',
#  'Kumawat Runal',
#  '|Garg Simran',
#  'i "eatelst lat rer-te kumar th.',
#  'Ve 2S oe',
#  '[Cities 086 Sagar',
#  'iMeena  | Neetu | Neetu',
#  '',
#  '@ite, lelsitia iva',
#  'Kumar Soni Aditya rele',
#  'Raja',
#  '1 Singh Sham. 098',
#  '032 Harsh Rai',
#  'tle ==) 4 Kumar 078',
#  'wy \\estia Kumar',
#  'mely 9 4 NitstwAfahari',
#  'Bel tay stlieertle Ser icee ae',
#  'NAVNITA | KIIMARI',
#  'Amar Sarkan 012',
#  'Shvam Shukis 102',
#  'Manish 048 loormar',
#  'Nitesh detlestel',
#  '',
#  'Neeraj Fels;',
#  'Chaudhary Sarita 044',
#  'st Barnabas st Barnabas',
#  'otislelal o18 ,',
#  'be laisall eilait Mehta Mehta',
#  'HARSH SHARMA',
#  '-Ruchi | /Panse',
#  'Pooja Yadav',
#  '',
#  'Nandsani S! hah',
#  'Sudh3nshu Shrivastoyv',
#  'oetllaltisteiaetiie ns rao',
#  'Kumawat Runal',
#  '|Garg Simran',
#  'ie atelst lat rer-te kumar th.',
#  'i Meena  | Neetu | Neetu',
#  '',
#  '@ite, lelsitia iva',
#  'Sagar fettie = 086',
#  'Kumar Soni Aditya rele',
#  'Sanam. | Singh 098',
#  'Raja',
#  '032 Harsh Rai',
#  'HARSH SHARMA',
#  'Ment',
#  'tle ==) 4 Kumar 078',
#  'Shvam Shukis 102',
#  'mely 9 4 NitstwAfahari',
#  'Bel tay sSlieerlcg Ser leee ee',
#  'Amit. Kumar',
#  'NAVNITA | KIIMARI',
#  'Manish 048 loormar',
#  'Nitesh detlestel',
#  '',
#  'Pooja Yadav',
#  'Neeraj Fels;',
#  'Chaudhary Sarita 044',
#  'st Barnabas st Barnabas',
#  '',
#  '-Ruchi | /Panse',
#  '',
#  'Sudh3nshu Shrivastoyv',
#  'oetllaltisteiaetiie ns rao',
#  'Nan@ani SI hah',
#  'Kumawat Runal',
#  'elalelal | Ait 018',
#  'Sarkan Amar 012',
#  '|Garg Simran',
#  'ie atelst lat rer-te kumar th.',
#  'i Meena  | Neetu | Neetu',
#  '[Gisele isisitia iva',
#  'Kumar Soni Aditya rele',
#  'fCitiest Saaar 086',
#  'Sanam | | Singh 098',
#  'Raja',
#  '032 Harsh Rai',
#  'Ment',
#  'HARSH CUIAPMA',
#  'tle ==) 4 Kumar 078',
#  'Shvam Shukis 102',
#  'mely 9 4 NitstwAfahari',
#  '_ bikky mae-\\lgeseren Cua',
#  'Kumawat Kunal',
#  'Amit Kumar.',
#  'KLMARI NAVNITA.',
#  'Manish 048 loormar',
#  'Nitesh detlestel',
#  'Pooja Yadav',
#  'Neeraj Fels;',
#  'Chaudhary Sarita 044',
#  '',
#  'st Barnabas st Barnabas',
#  '-Ruchi | /Panse',
#  '',
#  'slalelal 018 may',
#  'Shrivast Sudh4nshu sel',
#  'oetllaltisteiaetiie ns rao',
#  'Nan@ani SI hah',
#  '',
#  'Sarkan Amar 012',
#  '|Garg Simran',
#  'ie atelst lat rer-te kumar th.',
#  'i Meena  | Neetu | Neetu',
#  '[Gisele isisitia iva',
#  'fCitiest Saaar 086',
#  'Sanam | | Singh 098',
#  'Raja',
#  'y Velie) Kumar feleyl Son',
#  '032 Harsh Rai',
#  'Ment',
#  'Tl t-34 Kumar 078',
#  'Shvam Shukla 102',
#  'mely 9 4 NitstwAfahari',
#  'Amit Kumar.',
#  '_ bikky aae-\\laee lm Cua',
#  'Kumawat Kunal',
#  'KUMARI NAVNITA.',
#  'Manish 048 loormar',
#  'Nitesh detlestel',
#  'Pooja Yadav',
#  'Neeraj Fels;',
#  '',
#  'st Barnabas st Barnabas',
#  'Chaudhary "Sarita 044',
#  '-Ruchi | /Panse',
#  'HARSH CLIAPMA .',
#  '',
#  'slalelal 018 may',
#  'Shrivast Sudh4nshu sel',
#  'oetllaltisteiaetiie ns rao',
#  'Nan@ani SI hah',
#  '',
#  'i "eatelst lat rer-te kumar th.',
#  'Sarkan Amar 012',
#  '|Garg Simran',
#  'BS ler\\s Cue 086',
#  'i Meena  | Neetu | Neetu',
#  '[Gisele isisitia iva',
#  'Sanam | | Singh 098',
#  'Sangam ele)',
#  'y Velie) Kumar feleyl Son',
#  '032 Harsh Rai',
#  'Ment',
#  'Tl t-34 Kumar 078',
#  'Shvam Shukla 102',
#  'mely 9 4 NitstwAfahari',
#  'Amit Kumar.',
#  '_ bikky aae-\\laee lm cular',
#  'rrAVibe-@ KLMARI',
#  'Kumawat Kunal',
#  'Neeraj Fels;',
#  'TWIARPCL CLIAPMA',
#  'Chaudhary "Sarita O44',
#  '',
#  'st Barnabas st Barnabas',
#  'Nitesh kum',
#  'Ruchi Panse',
#  '',
#  'Pooja Yadav',
#  '',
#  'welatelal 018 may',
#  'Shrivast Sudh4nshu sel',
#  'oetllaltisteiaetiie ns rao',
#  'i "eatelst lat rer-te kumar th.',
#  'Sarkan Amar 012',
#  '|Garg Simran',
#  'Ne ea oe',
#  'BSler\\s Cue 086',
#  'i Meena  | Neetu | Neetu',
#  'ey-t',
#  '[Gisele isisitia iva',
#  'Sangam ele)',
#  'y Velie) Kumar feleyl Son',
#  'Shivam 1 Singh 098',
#  '032 Harsh Rai',
#  'Ment',
#  'Tl t-34 Kumar 078',
#  'Amit. ilar',
#  'Shvam his Flare 102 Yo',
#  'mely 9 4 NitstwAfahari',
#  'rrAVibe-@ KLMARI',
#  '_ bikky aae-\\laee lm cular',
#  'Kumawat Kunal',
#  'Neeraj Fels;',
#  'TWIARPCL CLIAPMA',
#  'Chaudhary "Sarita O44',
#  'Nitesh kum',
#  'st Barnabas st Barnabas',
#  'Ruchi Panse',
#  '',
#  'ela lal 018 | Aki',
#  'Pooja Yadav',
#  '',
#  '',
#  'Shrivast Sudh4nshu sel',
#  'oetllaltisteiaetiie ns rao',
#  'i "eatelst lat rer-te kumar th.',
#  'Sarkan Amar 012',
#  '|Garg Simran',
#  'Nanton; Sha!',
#  'BSler\\s Cue 086',
#  'iMeena  | Neetu | Neetu',
#  'ey-t',
#  'Gales ielsltia iva',
#  'Sangam ele)',
#  'y Velie) Kumar feleyl Son',
#  'Shriram. 098 1 Singh',
#  '032 Harsh Rai',
#  '_bikkyl jeselecoes',
#  'Amit. ilar',
#  'Shvam Shukla 102',
#  'mely 9 4 NifstwAfahari',
#  'Tat-t-34 Kumar O78',
#  'Mehta jel aisall eilat',
#  'Kumawat Kunal',
#  'KUMARI NAVNITA.',
#  'HARSH SHARMA',
#  'Malahcincle ase Ss .lU',
#  'Neeraj Fels;',
#  'Chaudhary "Sarita O44',
#  'Nitesh kum',
#  'st Barnabas st Barnabas',
#  'Ruchi Panse',
#  '',
#  'ela lal 018 | Aki',
#  '',
#  'Pooja Yadav',
#  '',
#  'oetllaltisteiaetiie ns rao',
#  'i "eatelst lat rer-te kumar th.',
#  '|Garg Simran',
#  'Amar 012 Sarkan',
#  'Nantian; Sha!',
#  'Sagar Cue 086',
#  'iMeena  | Neetu | Neetu',
#  'ey-t',
#  'Gales ielsltia iva',
#  'Sangam ele)',
#  'y Velie) Kumar feleyl Son',
#  'Shriram. 098 1 Singh',
#  '032 Harsh Rai',
#  '_bikkyl Seselesoe',
#  'Amit. ilar',
#  'Shvam Shukla 102',
#  'mely 9 4 NifstwAfahari',
#  'Tat-t-34 Kumar O78',
#  'Mehta jel aisall eilat',
#  'Meena Neetu! mey10)',
#  'KUMARI NAVNITA.',
#  'aseiris Runa!',
#  'HARSH SHARMA',
#  '',
#  'Nitesh kum',
#  '1) Shrivastava se oS lU',
#  'Neeraj Fels;',
#  'Chaudhary Sarita O44',
#  'st Barnabas st Barnabas',
#  'Ruchi Panse',
#  'Sonu |Gupta ey.',
#  'PSingh 018 | Aki',
#  'Pooja Yadav',
#  '',
#  'weltatitsleiaeliie hs rao',
#  'i "eatelst lat rer-te kumar th.',
#  '|Garg Simran',
#  '',
#  'Amar 012 Sarkan',
#  'Nantian; Sha!',
#  'Sagar Cue 086',
#  'ey-t',
#  'Gales ielsltia iva',
#  ')Singh 098 | Shaver',
#  'Sangam ele)',
#  'y Velie) Kumar feleyl Son',
#  '032 Harsh Rai',
#  '_bikkyl jeselecoe es',
#  'Shvam Shukla 102',
#  'mely 9 4 Nif@stwAfahari',
#  'Tat-t-34 Kumar O78',
#  'Mehta is latsell eiel! is latsell eiel!',
#  'Meena Neetu! mey10)',
#  'KUMARI NAVNITA.',
#  'aseiris Runa!',
#  '',
#  'Nitesh kum',
#  '1) Shrivastava se oS lU',
#  'Ruchi Panse',
#  'Neeraj Fels;',
#  'Chaudhary Sarita O44',
#  'HARSH -CLIADMAA',
#  'st Barnabas st Barnabas',
#  'Manish 048 loomar',
#  'Sonu |Gupta ey.',
#  'PSingh 018 | Aki',
#  'Pooja Yadav',
#  '',
#  'puruchottama | rao',
#  '',
#  'Amit Kumar',
#  '|Garg Simran',
#  'i "eatelst lat rer-te kumar th.',
#  'Sarkar Amar. 012',
#  'Ve aa',
#  'Sagar Che 086',
#  '@ sles ielsltia iva',
#  'Sangam ele)',
#  '1 Singh sti iaal 098',
#  'Aditya releya Kumar Son',
#  '032 Harsch Rai',
#  '_bikkyl Seselesoe se',
#  'Shvam Shikia 102 Yr <',
#  'mely 9 4 Nif@stwAfahari',
#  'Mehta is latsell eiel! is latsell eiel!',
#  'Tat-t-34 Kumar O78',
#  'late lal o18 lata',
#  'Meena Neetu! mey10)',
#  'KLMARI NAVNITA.',
#  'aseiris Runa!',
#  '',
#  'Nitesh kum',
#  'Ruchi Panse',
#  'Neeraj Fels;',
#  'Chaudhary Sarita O44',
#  'HARSH -CLIADMAA',
#  'st Barnabas st Barnabas',
#  'Manish 048 lomar',
#  'Shrivacr ~Sudh4Snshu. Vel',
#  'Sonu |Gupta ey.',
#  'Pooja Yadav',
#  '',
#  'puruchottama | rao',
#  'Amit Kumar',
#  'kanchan',
#  '',
#  '| Garg Simran',
#  'Nan@ani SI seial',
#  'Sarkar Amar. 012',
#  'Sagar Che 086',
#  '@ sles ielsltia iva',
#  'Sangam ele)',
#  '1 Singh sti iaal 098',
#  'Aditya releya Kumar Son',
#  '032 Harsh Rai',
#  'Shvam Shikia 102 Yr',
#  'mely 9 4 NifstwAfahari',
#  'Tat-t-34 Kumar O78',
#  'Mehta be laisall lal! be laisall lal!',
#  'iste lal el abe 018',
#  'Meena Neetu | mey10)',
#  'KUMARI NAVNITA.',
#  'oscil _bikkyl Sharh',
#  '',
#  'Nitesh kum',
#  'Neeraj Fels;',
#  'Chaudhary Sarita 044',
#  'HARSH -CLIADMAA',
#  '',
#  'st Barnabas st Barnabas',
#  'Manish 048 loormar',
#  'Sonu Gupta 104',
#  'Shrivacr Sudh4Snshu . TVa',
#  '-Ruchi Panse',
#  'Pooja Yadav',
#  '',
#  'puruchottama | rao',
#  'Amit Kumar',
#  'Mlsrivc ls Raunal',
#  '[Cities Sagar 086',
#  'kanchan',
#  '|Garg Simran',
#  'Nan@ani SI seial',
#  'Sarkar Amar. 012',
#  '@ sles ielsltia iva',
#  ')Singh 098 |. Saar',
#  'Sangam ele)',
#  'Aditya releya Kumar Son',
#  '032 Harsh Rai',
#  "HARSH 'CLIADMA",
#  'Shvam Shukla 10?',
#  'mely 9 4 NifstwAfahari',
#  'Tat-t-34 Kumar O78',
#  'Mehta i latsell clei i latsell clei',
#  'u Meena mm ey.10) _Neetu',
#  'Siatelal el abe 018',
#  'KUMARI NAVNITA.',
#  'iar. _bikkyl Sharh',
#  '',
#  'Nitesh kum',
#  'Neeraj Fels;',
#  'Gupta Sonu 104',
#  'st Barnabas st Barnabas',
#  'Manish 048 loormar',
#  'Chaudhary "Sarita 044',
#  'Shrivacr Sudh4Snshu . TVa',
#  'Mlsrivc ls Raunal',
#  '-Ruchi | Panse',
#  '-purushottama r rao',
#  'Amit Kumar',
#  'Pooja Yadav',
#  'fCitieis Sagar 086',
#  '',
#  'kanchan',
#  '|Garg Simran',
#  '',
#  'Nan@ani SI seial',
#  'Sark> Amar. 012',
#  '@ sles ielsltia iva',
#  ')Singh 098 |. Saar',
#  'Sangam ele)',
#  'Aditya releya dase Son',
#  '032 Harsh Rai',
#  "HARSH 'CLIADMA",
#  'Shukla Shvam 102 Yoo',
#  'mel 9 4 NifstwAfahari',
#  'tls ==) 4 Kumar 078',
#  'Mehta i latsell clei i latsell clei',
#  'i Meena mm ey.10) Neetu',
#  'Siatelal el abe 018',
#  'NAVNITA. KLIMARI',
#  'iar. _bikkyl Sharh',
#  '',
#  'Nitesh kum',
#  'Neeraj Fels;',
#  'Chaudhary Sarita 044',
#  'st Barnabas st Barnabas',
#  '',
#  'Shrivacr Sudh4Snshu . TVa',
#  '-Ruchi | Panse',
#  'Pooja Yadav',
#  'Amit Kumar',
#  'Mlsrivc ls Raunal',
#  '',
#  'Sonu |Gupta ey.',
#  'Sagar [Ciiet 086',
#  '|Garg Simran',
#  'Sark> Amar. 012',
#  'kanchan rer-te kumar th.',
#  'Nandsani St',
#  'purushottama | rao',
#  'rey',
#  '@ sles ielsltia iva',
#  ')Singh 098 |. Saar',
#  'Sangam ele)',
#  'Kumar Sor Aditya foley',
#  '032 Harsh Rai',
#  "HARSH 'CLIADMA",
#  'Shvam Shukis 102 Yc',
#  'mel 9 4 NifstwAfahari',
#  'tls ==) 4 Kumar 078',
#  'Mehta i latsell clei i latsell clei',
#  'NAVNITA. KLIMARI',
#  'iar. _bikkyl Sharh',
#  '',
#  'Nitesh kum',
#  'Neeraj Fels;',
#  'Chaudhary Sarita 044',
#  'st Barnabas st Barnabas',
#  '',
#  'Ruchi | Panse',
#  'Shrivacr Sudh4Snshu . TVa',
#  'Amit i allestle',
#  'Pooja Yadav',
#  'Mlsrivc ls Raunal',
#  '',
#  'Sonu |Gupta ey.',
#  '|Garg Simran',
#  'puruchottama | rao',
#  'Amar Sarkan 012',
#  'kanchan rer-te kumar th.',
#  'Ne aS',
#  'iMveena  ) Neetu. ) Neetu.',
#  'rey',
#  'Singh o18 Skit',
#  '@isle, Velaltia. riva',
#  'Sagar Che 086',
#  'Singh 098 | Saver',
#  'Sangam ele)',
#  'Kumar Sor Aditya foley',
#  '032 Harsh Rai',
#  'charryma cis bikkyl y Kun',
#  'Shvam Shukis 102 > <',
#  'mel 9 4 Nif@stwAfahari',
#  'tls ==) 4 Kumar 078',
#  'Mehta i latsell clei i latsell clei',
#  'NAVNITA. KLIMARI',
#  '',
#  "HARSH 'CLIADMAA",
#  'Nitesh kum',
#  'Neeraj Fels;',
#  'Chaudhary Sarita 044',
#  'st Barnabas st Barnabas',
#  'Pooja Vaday',
#  'Ruchi | Panse',
#  'Shrivacr Sudh4Snshu . TVa',
#  'Amit i ablestle',
#  'Mlsrivc ls Raunal',
#  '',
#  '|Garg Simran',
#  '',
#  '|Gupta Sonu 104',
#  'Amar Sarkan 012',
#  '-purushottamar rao',
#  'kanchan rer-te kumar th.',
#  'Nandsani St',
#  'iMvMeena  ) Neetu. ) Neetu.',
#  'Sagar [Cities 086',
#  'rey',
#  'Singh o18 kit',
#  '@isle, Velaltia. riva',
#  'Sangam ele)',
#  '+ Shawvam | Singh 098',
#  'Aditya foley Kumar Son',
#  '032 Harsh Rai',
#  'charms _bikky#l yar',
#  'Shvam Shukla 102 a &',
#  'tls ==) 4 Kumar 078',
#  'mel 9 4 Nif@stwAfahari',
#  'Mehta elatsallelatt elatsallelatt',
#  'NAVNITA. KLIMARI',
#  '',
#  "HARSH 'CLIADMAA",
#  'Nitesh kum',
#  'Boiss ce. Birelst le taltl ava',
#  'Neeraj Fels;',
#  'Ruchi Panse',
#  'Chaudhary "Sarita 044',
#  'st Barnabas st Barnabas',
#  'Pooja Vaday',
#  'Amit i ablestle',
#  '| Gupta Sonu 104',
#  'Mlsrivc ls Raunal',
#  '',
#  '|Garg Simran',
#  '',
#  'kanchan rer-te kumar th.',
#  'Amar Sarkan 012',
#  'eitalisteiaetiiee rao',
#  'Nandsani St',
#  'iMeena _ ) Neetu. ) Neetu.',
#  'rey',
#  'Singh o18 Skit',
#  '@isle, Velaltia. riva',
#  'ote BSler|, 086',
#  'Sangam ele)',
#  'Shrram Beis 098',
#  'Kumar Sor Aditya foley',
#  '032 Harsh Rai',
#  'charms _bikky#l yar',
#  'tls ==) 4 Kumar 078',
#  'Shvam Shukla 102 a &',
#  'mel 9 4 Nif@stwAfahari',
#  'Mehta iS latsell eile! iS latsell eile!',
#  'Amar Sarkar 012',
#  '',
#  'NAVNITA KLIMARI,',
#  "HARSH 'CLIADMAA",
#  'Nitesh kum',
#  'Boisigi ce. BS Trelste le taltl Tava',
#  'Neeraj Fels;',
#  'st Barnabas st Barnabas',
#  'Chaudhary "Sarita 044',
#  'Ruchi | /Panse',
#  'Pooja Vaday',
#  '| Gupta Sonu 104',
#  'Amit Kumar',
#  'Mlsrivc ls Raunal',
#  'weltatitsleiaeliie ns rao',
#  '',
#  '|Garg Simran',
#  'Nanton i SI shah',
#  '',
#  'etatelselal kumar certo th.',
#  'Girls isisitias iva',
#  'iMeena  ) Neetu. ) Neetu.',
#  'ote BStler|, 086',
#  'Singh o18 Skit',
#  'rey',
#  'Sangam ele)',
#  'SaArwam | 1 Singh 098',
#  'Kumar Sor Aditya foley',
#  '032 Harsh Rai',
#  'charms _bikky#l moar',
#  'Shvam bs Flare 102',
#  'tls ==) 4 Kumar 078',
#  'mel 9 4 Nif@stwAfahari',
#  'Amar Sarkar 012',
#  '',
#  'NAVNITA KLIMARI,',
#  'Ment Il aisall lel! Il aisall lel!',
#  "HARSH 'CLIADMAA",
#  'Nitesh kum',
#  'Ruchi Panse',
#  '| Shrivast BS Trelste le taltl Tava',
#  'Neeraj Fels;',
#  'st Barnabas st Barnabas',
#  'Chaudhary "Sarita 044',
#  'o18 eotistelal Aarkit',
#  'Pooja Vaday',
#  'Kumar Amit',
#  'Mlsrivc ls Raunal',
#  '',
#  '',
#  ...]

# %%
emotions
# Out:
# ['neutral',
#  'sad',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'neutral',
#  'happy',
#  'angry',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'happy',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'neutral',
#  'happy',
#  'happy',
#  'neutral',
#  'sad',
#  'fear',
#  'neutral',
#  'sad',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'fear',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'happy',
#  'angry',
#  'happy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'happy',
#  'happy',
#  'neutral',
#  'sad',
#  'fear',
#  'sad',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'fear',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'angry',
#  'happy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'happy',
#  'happy',
#  'angry',
#  'neutral',
#  'sad',
#  'fear',
#  'sad',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'angry',
#  'neutral',
#  'neutral',
#  'fear',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'happy',
#  'neutral',
#  'angry',
#  'happy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'happy',
#  'happy',
#  'neutral',
#  'angry',
#  'sad',
#  'fear',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'angry',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'happy',
#  'neutral',
#  'fear',
#  'happy',
#  'angry',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'happy',
#  'neutral',
#  'neutral',
#  'happy',
#  'happy',
#  'neutral',
#  'angry',
#  'sad',
#  'fear',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'angry',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'happy',
#  'happy',
#  'neutral',
#  'sad',
#  'happy',
#  'angry',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'neutral',
#  'sad',
#  'happy',
#  'neutral',
#  'neutral',
#  'angry',
#  'happy',
#  'sad',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'happy',
#  'happy',
#  'neutral',
#  'fear',
#  'happy',
#  'angry',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'sad',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'happy',
#  'sad',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'happy',
#  'happy',
#  'sad',
#  'angry',
#  'neutral',
#  'happy',
#  'neutral',
#  'happy',
#  'neutral',
#  'sad',
#  'sad',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'sad',
#  'sad',
#  'neutral',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'happy',
#  'sad',
#  'happy',
#  'happy',
#  'neutral',
#  'neutral',
#  'angry',
#  'happy',
#  'neutral',
#  'happy',
#  'sad',
#  'neutral',
#  'neutral',
#  'happy',
#  'fear',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'happy',
#  'angry',
#  'happy',
#  'sad',
#  'happy',
#  'neutral',
#  'neutral',
#  'angry',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'fear',
#  'happy',
#  'happy',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'happy',
#  'angry',
#  'neutral',
#  'happy',
#  'neutral',
#  'happy',
#  'neutral',
#  'happy',
#  'neutral',
#  'angry',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'fear',
#  'happy',
#  'happy',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'happy',
#  'happy',
#  'neutral',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'angry',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'sad',
#  'happy',
#  'fear',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'happy',
#  'neutral',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'angry',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'happy',
#  'happy',
#  'fear',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'happy',
#  'sad',
#  'neutral',
#  'neutral',
#  'angry',
#  'neutral',
#  'sad',
#  'angry',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'fear',
#  'happy',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'sad',
#  'neutral',
#  'angry',
#  'neutral',
#  'angry',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'happy',
#  'neutral',
#  'sad',
#  'fear',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'angry',
#  'neutral',
#  'angry',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'happy',
#  'neutral',
#  'sad',
#  'fear',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'happy',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'angry',
#  'neutral',
#  'angry',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'happy',
#  'sad',
#  'fear',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'happy',
#  'happy',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'angry',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'happy',
#  'sad',
#  'fear',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'happy',
#  'neutral',
#  'neutral',
#  'happy',
#  'happy',
#  'neutral',
#  'neutral',
#  'angry',
#  'neutral',
#  'neutral',
#  'angry',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'happy',
#  'sad',
#  'fear',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'happy',
#  'fear',
#  'happy',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'happy',
#  'angry',
#  'neutral',
#  'happy',
#  'neutral',
#  'happy',
#  'neutral',
#  'sad',
#  'fear',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'fear',
#  'happy',
#  'neutral',
#  'neutral',
#  'happy',
#  'happy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'happy',
#  'sad',
#  'neutral',
#  'fear',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'angry',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'happy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'fear',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'happy',
#  'sad',
#  'neutral',
#  'fear',
#  'neutral',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'angry',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'happy',
#  'neutral',
#  'angry',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'sad',
#  'fear',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'angry',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'angry',
#  'happy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'happy',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'sad',
#  'fear',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'angry',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'happy',
#  'happy',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'surprise',
#  'happy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'angry',
#  'neutral',
#  'happy',
#  'neutral',
#  'sad',
#  'fear',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'happy',
#  'happy',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'surprise',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'happy',
#  'happy',
#  'neutral',
#  'sad',
#  'fear',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'angry',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'sad',
#  'happy',
#  'sad',
#  'neutral',
#  'fear',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'surprise',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'angry',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'happy',
#  'happy',
#  'sad',
#  'neutral',
#  'fear',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'sad',
#  'neutral',
#  'surprise',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'angry',
#  'happy',
#  'neutral',
#  'happy',
#  'neutral',
#  'happy',
#  'sad',
#  'neutral',
#  'sad',
#  'neutral',
#  'fear',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sad',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  'sad',
#  'neutral',
#  'neutral',
#  'happy',
#  'neutral',
#  'happy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'happy',
#  ...]

# %%
import re
for i in range(len(names)):
  names[i] = re.sub(r"[^a-zA-Z' ']","",names[i])
  names[i] = names[i].lstrip()
  names[i] = names[i].rstrip()

# %%
unique_names = set(names)

# %%
unique_names
# Out:
# ['Shrivast BStrelst ls alll TVa',
#  '',
#  'BC lee Simran',
#  'Shrivast Sudhnshu sel',
#  'Gales ielsltia iva',
#  'Sanam   Singh',
#  'Nandsani St',
#  'ote BStler',
#  'Kumar feleya Aditya Teta',
#  'HARSH CLIAPMA',
#  'purushottama r rao',
#  'BSlers Cue',
#  'isle Velaltia riva',
#  'Ve S oe',
#  'y Velie Kumar feleyl Son',
#  'charryma cis bikkyl y Kun',
#  'Sarkar Amar',
#  'SHleris Che',
#  'a tlesteial Amit K',
#  'welatelal  may',
#  'Boiss ce Birelst le taltl ava',
#  'Gisele isisitia iva',
#  'weltatitsleiaeliie ns rao',
#  'istitielscin Sarita foy',
#  'Nanani SI hah',
#  'sles ielsltia iva',
#  'Sagar Che',
#  'Be tay lleslaeseriaerchn',
#  'KUMARI NAVNITA',
#  'Shvam Shukla  a',
#  'Singh   Saar',
#  'Shriram   Singh',
#  'Sark Amar',
#  'Singh o kit',
#  'Harsch Rai',
#  'Kumawat Kainal',
#  'fCitieis Sagar',
#  'NAVNITA KLIMARI',
#  'HARSH CUIAPMA',
#  'yYestia Kumar',
#  'Shyam is Flare',
#  'et ateistelal reyte kumar th',
#  'Sudhnshu Shrivastava',
#  'Shrivastava se oS lU',
#  'Sonu Gupta',
#  'SHARMA HARSH',
#  'tle   Kumar',
#  'Aditya foley Kumar Son',
#  'Harsh Rai',
#  'SaArwam   Singh',
#  'Manich  alles t om',
#  'Siatelal el abe',
#  'Sagar Cltleir',
#  'wy estia Kumar',
#  'Nandsani S hah',
#  'Shvam Shikia  Yr',
#  'mely   NitstwAfahari',
#  'Manich  alles  am',
#  'Chet Sagar Os',
#  'kanchan kumar erie th',
#  'Cities Sagar',
#  'mely   NifstwAfahari',
#  'Oeihalisteiaetiiee rao',
#  'eslia Kumar',
#  'Kumar Soni Aditya rele',
#  'Singh o Skit',
#  'ite lelsitia iva',
#  'Ruchi  Panse',
#  'Raja',
#  'Sudhnshu Shrivastoyv',
#  'o mS lalelal AQIKI',
#  'ela lal   Aki',
#  'Singh   Shaver',
#  'purushottamar rao',
#  'Nanani SI seial',
#  'SHARMA LARSL',
#  'Girls isisitias iva',
#  'i Meena   Neetu  Neetu',
#  'charms bikkyl yar',
#  'Nanton SI shah',
#  'mlesteial Amit K',
#  'Gupta Sonu Sey',
#  'Shvam Shukla',
#  'late lal o lata',
#  'Amar Sarkan',
#  "HARSH 'CLIADMAA",
#  'bikky maelgeseren Cua',
#  'Sarkan Amar',
#  'aseivris eanal',
#  'Nantian Sha',
#  'Be tay leerleesericern',
#  'Nandsni St hah',
#  'Singh AMKI',
#  'BS lers Cue',
#  'Amit i ablestle',
#  'Che Sagar',
#  'puruchottama  rao',
#  'bikkyl Seselesoe se',
#  'bikky aaelaee lm cular',
#  'Ment Il aisall lel Il aisall lel',
#  'Mehta i latsell clei i latsell clei',
#  'Nanton Sha',
#  'Amar Sarkar',
#  'Cities iSlerid',
#  'kanchan reyte kumar th',
#  'Manish  lomar',
#  'oetllaltisteiaetiie ns rao',
#  'mele Nifeewestshari',
#  'Meena Rey Neetu',
#  'Shvam Shukis  Yc',
#  'TWIARPCL CLIAPMA',
#  'Shrram Singh',
#  'Bel tay stlieertle Ser icee ae',
#  'Mehta be laisall lal be laisall lal',
#  'Kumar',
#  'Kumawat Kunal',
#  'Shvam his Flare  Yo',
#  'Aditya releya dase Son',
#  'Sonu Gupta ey',
#  'eset iceerl bikkyl leskle',
#  'lalelal o AMKI',
#  'y Velie Kumar Soni reley',
#  'Sagar Ciiet',
#  'Nanton i SI shah',
#  'Citiei  Siecle',
#  'Meena Neetu mey',
#  'Singh   Saver',
#  'Singh  ATTK',
#  'iMveena   Neetu  Neetu',
#  'Aditya releya Kumar Son',
#  'Shawvam  Singh',
#  'Manich neyt',
#  'i Meena  melon  Neetu',
#  'otislelal o',
#  'Kumar Amit',
#  'ite ieisitia iva',
#  'Kumar Soni Seley Aditya',
#  'Shvam Shukis',
#  'Shrivaet  SodhSnchu TV',
#  'rrAVibe KLMARI',
#  'Shrivacr SudhSnshu Vel',
#  "HARSH 'CLIADMA",
#  'bikkyl lace laee a atleehy',
#  'Amit ilar',
#  'KLMARI NAVNITA',
#  'bikkyl Seselesoe',
#  'NAVNITA  KIIMARI',
#  'weltatitsleiaeliie hs rao',
#  'Boisigi ce BS Trelste le taltl Tava',
#  'eitalisteiaetiiee rao',
#  'Shukla Shvam',
#  'ola t Kumar',
#  'Shrivacr SudhSnshu  TVa',
#  'iar bikkyl Sharh',
#  'Singh Sham',
#  'Shrram Beis',
#  'rey',
#  'Pooja Yadav',
#  'Singh Shivam',
#  'bikkyl jeselecoe es',
#  'Neeraj Fels',
#  'Meena meyi Neetu',
#  'Amar  Sarkan',
#  'kanchan rerte kumar th',
#  'bikkyl jeselecoes',
#  'Shvam Shukla  Yo',
#  'ote BSler',
#  'st Barnabas st Barnabas',
#  'Nitesh detlestel',
#  'tis   Kumar Kumar',
#  'Mehta jel aisall eilat',
#  'Kumar Sor Aditya foley',
#  'Malahcincle ase Ss lU',
#  'NanGsani St cele',
#  'Tatt Kumar',
#  'NiteshwAfahari',
#  'Sanam  Singh',
#  'iMvMeena   Neetu  Neetu',
#  'Amit Kumar',
#  'Harch Rai',
#  'Mlsrivc ls Raunal',
#  'Shvam bs Flare',
#  'rrAVsing KLMARI',
#  'HARSH SHARMA',
#  'etatelselal kumar certo th',
#  'Be tay leslaeseriaeerch',
#  'Ment',
#  'Pooja Vaday',
#  'i llast',
#  'Chaudhary Sarita',
#  'Sangam ele',
#  'Mehta elatsallelatt elatsallelatt',
#  'Manish  loomar',
#  'aseiris Runa',
#  'Nandani Shz',
#  'slalelal  may',
#  'Gite lelisitia riva',
#  'NiteshAfahari',
#  'bikkyl Yoaserines a bvedleerl',
#  'Garg Thaales ial',
#  'Manich  loirmear',
#  'be laisall eilait Mehta Mehta',
#  'Bel tay sSlieerlcg Ser leee ee',
#  'Shivam  Singh',
#  'eyt',
#  'Amit i allestle',
#  'oscil bikkyl Sharh',
#  'Cities  Sagar',
#  'Nitesh kum',
#  'tls   Kumar',
#  'Garg Simran',
#  'Ne aS',
#  'jelaisell elated Mehta Mehta',
#  'Gite leisitia iva',
#  'Ne ea oe',
#  'ie atelst lat rerte kumar th',
#  'Shukla Shvam  Yoo',
#  'mel   NifstwAfahari',
#  'jel eisell elat',
#  'Nanani Shz',
#  'jer ecisell eilat',
#  'Telelal  AKI',
#  'Sagar Cue',
#  'Ruchi Panse',
#  'Tatt Kumar O',
#  'o om lalelal AQIKI',
#  'iste lal el abe',
#  'i eatelst lat rerte kumar th',
#  'Tl t Kumar',
#  'u Meena mm ey Neetu',
#  'o eotistelal Aarkit',
#  'Meena Neetu  mey',
#  'irao purushottama r',
#  'Manish  loormar',
#  'Manich alles t om neytc',
#  'Shyam Shukla  vo',
#  'Mehta iS latsell eile iS latsell eile',
#  'Shrivast BS Trelste le taltl Tava',
#  'Sagar cies',
#  'Singh sti iaal',
#  'Singh Sharam',
#  'Sagar fettie',
#  'Mehta is latsell eiel is latsell eiel',
#  'kanchan kumar rerte th',
#  'bikky aaelaee lm Cua',
#  'iMeena   Neetu  Neetu',
#  'Sudhnshu Shrivasteyv',
#  'Kumawat Runal',
#  "a'etateistelal reyte kumar th",
#  'Shukis Shvam',
#  'Nandsani SF cele',
#  'PSingh   Aki',
#  'Sie Sagar',
#  'SudhSnshu  Shrivastova',
#  'Amit Miumar',
#  'purushottama  rao',
#  'Bel tay sSlieertlc Ser leee ae',
#  'HARSH CLIADMAA',
#  'bikkyl facstelaee ia adleehry',
#  'kanchan',
#  'Gupta Sonu',
#  'laste ween Aditya foley',
#  'elalelal  Ait',
#  'Chaudhary Sarita O',
#  'jel aisell elal',
#  'Sagar Chie',
#  'charms bikkyl moar',
#  'fCitiest Saaar',
#  'ite Velsltla iva',
#  'Cities ilerid',
#  'Be tay llesllaeseriaerch',
#  'i Meena mm ey Neetu',
#  'Ve aa',
#  'eltattsseiseliiee rao',
#  'Sagar Cities',
#  'Gite lelsitia iva']

# %%
merge=[]
for i in range(len(names)):
  temp=[]
  temp.append(names[i])
  temp.append(emotions[i])
  merge.append(temp)

# %%
merge
# Out:
# [['eset iceerl bikkyl leskle', 'neutral'],
#  ['NiteshAfahari', 'sad'],
#  ['aseivris eanal', 'sad'],
#  ['HARSH SHARMA', 'neutral'],
#  ['Harsch Rai', 'neutral'],
#  ['Shyam is Flare', 'neutral'],
#  ['Shrivast BStrelst ls alll TVa', 'neutral'],
#  ['Pooja Yadav', 'neutral'],
#  ['Tatt Kumar', 'neutral'],
#  ['Kumar Amit', 'neutral'],
#  ['NAVNITA KLIMARI', 'neutral'],
#  ['Gupta Sonu', 'sad'],
#  ['Meena meyi Neetu', 'neutral'],
#  ['Nitesh kum', 'happy'],
#  ['Oeihalisteiaetiiee rao', 'angry'],
#  ['jel eisell elat', 'neutral'],
#  ['Neeraj Fels', 'neutral'],
#  ['istitielscin Sarita foy', 'neutral'],
#  ['Manich alles t om neytc', 'neutral'],
#  ['lalelal o AMKI', 'happy'],
#  ['st Barnabas st Barnabas', 'happy'],
#  ['Amar  Sarkan', 'neutral'],
#  ['', 'neutral'],
#  ['Ruchi Panse', 'happy'],
#  ['', 'neutral'],
#  ['Nandsani SF cele', 'neutral'],
#  ["a'etateistelal reyte kumar th", 'neutral'],
#  ['', 'sad'],
#  ['Garg Simran', 'neutral'],
#  ['ite ieisitia iva', 'happy'],
#  ['Sie Sagar', 'happy'],
#  ['Singh Sharam', 'neutral'],
#  ['Raja', 'sad'],
#  ['laste ween Aditya foley', 'fear'],
#  ['eset iceerl bikkyl leskle', 'neutral'],
#  ['NiteshwAfahari', 'sad'],
#  ['aseivris eanal', 'sad'],
#  ['HARSH SHARMA', 'neutral'],
#  ['Harch Rai', 'neutral'],
#  ['Shukis Shvam', 'neutral'],
#  ['Pooja Yadav', 'neutral'],
#  ['Tatt Kumar', 'neutral'],
#  ['Kumar Amit', 'neutral'],
#  ['NAVNITA KLIMARI', 'neutral'],
#  ['Meena meyi Neetu', 'neutral'],
#  ['Nitesh kum', 'happy'],
#  ['Gupta Sonu', 'fear'],
#  ['jel eisell elat', 'neutral'],
#  ['Neeraj Fels', 'neutral'],
#  ['Manich neyt', 'neutral'],
#  ['istitielscin Sarita foy', 'neutral'],
#  ['st Barnabas st Barnabas', 'happy'],
#  ['Amar  Sarkan', 'neutral'],
#  ['', 'neutral'],
#  ['Telelal  AKI', 'happy'],
#  ['eltattsseiseliiee rao', 'angry'],
#  ['Ruchi Panse', 'happy'],
#  ['', 'neutral'],
#  ['NanGsani St cele', 'neutral'],
#  ['SudhSnshu  Shrivastova', 'neutral'],
#  ["a'etateistelal reyte kumar th", 'neutral'],
#  ['Garg Simran', 'neutral'],
#  ['', 'sad'],
#  ['Gite lelisitia riva', 'happy'],
#  ['Sagar Chie', 'happy'],
#  ['Singh Sharam', 'neutral'],
#  ['Raja', 'sad'],
#  ['laste ween Aditya foley', 'fear'],
#  ['NiteshwAfahari', 'sad'],
#  ['aseivris eanal', 'sad'],
#  ['Harch Rai', 'neutral'],
#  ['bikkyl Yoaserines a bvedleerl', 'neutral'],
#  ['Shvam Shukla  Yo', 'neutral'],
#  ['ola t Kumar', 'neutral'],
#  ['Pooja Yadav', 'neutral'],
#  ['Singh AMKI', 'happy'],
#  ['KLMARI NAVNITA', 'neutral'],
#  ['Sarkar Amar', 'neutral'],
#  ['Kumar Amit', 'neutral'],
#  ['Nitesh kum', 'happy'],
#  ['Gupta Sonu', 'fear'],
#  ['SHARMA HARSH', 'neutral'],
#  ['jel eisell elat', 'neutral'],
#  ['Neeraj Fels', 'neutral'],
#  ['Manich  alles t om', 'neutral'],
#  ['istitielscin Sarita foy', 'neutral'],
#  ['st Barnabas st Barnabas', 'happy'],
#  ['', 'neutral'],
#  ['irao purushottama r', 'angry'],
#  ['Ruchi Panse', 'happy'],
#  ['', 'neutral'],
#  ['NanGsani St cele', 'neutral'],
#  ['SudhSnshu  Shrivastova', 'neutral'],
#  ['Garg Simran', 'neutral'],
#  ['', 'happy'],
#  ['i Meena  melon  Neetu', 'neutral'],
#  ['ite Velsltla iva', 'happy'],
#  ['Sagar Cltleir', 'happy'],
#  ['kanchan kumar erie th', 'angry'],
#  ['Singh Sharam', 'neutral'],
#  ['Raja', 'sad'],
#  ['y Velie Kumar Soni reley', 'fear'],
#  ['NiteshwAfahari', 'sad'],
#  ['aseivris eanal', 'sad'],
#  ['Harch Rai', 'neutral'],
#  ['Shukis Shvam', 'neutral'],
#  ['bikkyl lace laee a atleehy', 'neutral'],
#  ['ola t Kumar', 'neutral'],
#  ['Singh AMKI', 'happy'],
#  ['Pooja Yadav', 'neutral'],
#  ['KLMARI NAVNITA', 'neutral'],
#  ['Sarkar Amar', 'neutral'],
#  ['jelaisell elated Mehta Mehta', 'angry'],
#  ['Manich  alles t om', 'neutral'],
#  ['mlesteial Amit K', 'neutral'],
#  ['Gupta Sonu', 'fear'],
#  ['SHARMA HARSH', 'neutral'],
#  ['Neeraj Fels', 'neutral'],
#  ['istitielscin Sarita foy', 'neutral'],
#  ['st Barnabas st Barnabas', 'happy'],
#  ['Nitesh kum', 'happy'],
#  ['', 'neutral'],
#  ['irao purushottama r', 'angry'],
#  ['Ruchi Panse', 'happy'],
#  ['', 'neutral'],
#  ['NanGsani St cele', 'neutral'],
#  ['SudhSnshu  Shrivastova', 'neutral'],
#  ['Garg Simran', 'neutral'],
#  ['', 'happy'],
#  ['i Meena  melon  Neetu', 'neutral'],
#  ['ite Velsltla iva', 'happy'],
#  ['Cities iSlerid', 'happy'],
#  ['Singh Shivam', 'neutral'],
#  ['kanchan kumar erie th', 'angry'],
#  ['Raja', 'sad'],
#  ['y Velie Kumar Soni reley', 'fear'],
#  ['NiteshwAfahari', 'sad'],
#  ['Harch Rai', 'neutral'],
#  ['HARSH CUIAPMA', 'neutral'],
#  ['Shukis Shvam', 'neutral'],
#  ['bikkyl facstelaee ia adleehry', 'neutral'],
#  ['rrAVsing KLMARI', 'neutral'],
#  ['ola t Kumar', 'neutral'],
#  ['Pooja Yadav', 'neutral'],
#  ['Singh  ATTK', 'happy'],
#  ['Sarkar Amar', 'neutral'],
#  ['jelaisell elated Mehta Mehta', 'angry'],
#  ['Manich  alles t om', 'neutral'],
#  ['a tlesteial Amit K', 'neutral'],
#  ['Neeraj Fels', 'neutral'],
#  ['istitielscin Sarita foy', 'neutral'],
#  ['st Barnabas st Barnabas', 'happy'],
#  ['Nitesh kum', 'happy'],
#  ['', 'neutral'],
#  ['Gupta Sonu', 'fear'],
#  ['Ruchi Panse', 'happy'],
#  ['irao purushottama r', 'angry'],
#  ['', 'neutral'],
#  ['SudhSnshu  Shrivastova', 'neutral'],
#  ['Garg Simran', 'neutral'],
#  ['Kumawat Kainal', 'sad'],
#  ['', 'happy'],
#  ['Nanani Shz', 'neutral'],
#  ['i Meena  melon  Neetu', 'neutral'],
#  ['ite Velsltla iva', 'happy'],
#  ['Cities ilerid', 'happy'],
#  ['Singh Shivam', 'neutral'],
#  ['kanchan kumar erie th', 'angry'],
#  ['Raja', 'sad'],
#  ['y Velie Kumar Soni reley', 'fear'],
#  ['Kumar', 'neutral'],
#  ['Harch Rai', 'neutral'],
#  ['HARSH CUIAPMA', 'neutral'],
#  ['mele Nifeewestshari', 'sad'],
#  ['Shukla Shvam', 'neutral'],
#  ['tis   Kumar Kumar', 'neutral'],
#  ['bikkyl facstelaee ia adleehry', 'neutral'],
#  ['rrAVsing KLMARI', 'neutral'],
#  ['Pooja Yadav', 'neutral'],
#  ['Sarkar Amar', 'neutral'],
#  ['jelaisell elated Mehta Mehta', 'angry'],
#  ['Manich  alles t om', 'neutral'],
#  ['Neeraj Fels', 'neutral'],
#  ['istitielscin Sarita foy', 'neutral'],
#  ['st Barnabas st Barnabas', 'happy'],
#  ['o mS lalelal AQIKI', 'happy'],
#  ['Nitesh kum', 'happy'],
#  ['', 'neutral'],
#  ['Gupta Sonu', 'sad'],
#  ['Ruchi Panse', 'happy'],
#  ['irao purushottama r', 'angry'],
#  ['', 'neutral'],
#  ['SudhSnshu  Shrivastova', 'neutral'],
#  ['Garg Simran', 'neutral'],
#  ['Kumawat Kainal', 'sad'],
#  ['Nandani Shz', 'neutral'],
#  ['', 'sad'],
#  ['Gite lelsitia iva', 'happy'],
#  ['Singh Shivam', 'neutral'],
#  ['Meena Neetu mey', 'neutral'],
#  ['kanchan kumar erie th', 'angry'],
#  ['Citiei  Siecle', 'happy'],
#  ['Raja', 'sad'],
#  ['Kumar Soni Seley Aditya', 'sad'],
#  ['Harsh Rai', 'neutral'],
#  ['Amit Miumar', 'neutral'],
#  ['HARSH CUIAPMA', 'neutral'],
#  ['jer ecisell eilat', 'neutral'],
#  ['mele Nifeewestshari', 'sad'],
#  ['Tl t Kumar', 'neutral'],
#  ['Shukla Shvam', 'neutral'],
#  ['Be tay leerleesericern', 'neutral'],
#  ['rrAVsing KLMARI', 'neutral'],
#  ['Pooja Yadav', 'neutral'],
#  ['Neeraj Fels', 'neutral'],
#  ['Manich  alles  am', 'neutral'],
#  ['istitielscin Sarita foy', 'neutral'],
#  ['Sarkar Amar', 'neutral'],
#  ['st Barnabas st Barnabas', 'happy'],
#  ['o om lalelal AQIKI', 'happy'],
#  ['Nitesh kum', 'happy'],
#  ['', 'neutral'],
#  ['Gupta Sonu Sey', 'fear'],
#  ['Ruchi Panse', 'happy'],
#  ['irao purushottama r', 'angry'],
#  ['', 'neutral'],
#  ['et ateistelal reyte kumar th', 'neutral'],
#  ['SudhSnshu  Shrivastova', 'neutral'],
#  ['Garg Simran', 'neutral'],
#  ['', 'sad'],
#  ['Kumawat Kainal', 'sad'],
#  ['Nandani Shz', 'neutral'],
#  ['Gite leisitia iva', 'happy'],
#  ['Singh Shivam', 'neutral'],
#  ['Meena Neetu mey', 'neutral'],
#  ['Citiei  Siecle', 'happy'],
#  ['Raja', 'sad'],
#  ['Kumar Soni Seley Aditya', 'sad'],
#  ['Harsh Rai', 'neutral'],
#  ['Amit Miumar', 'neutral'],
#  ['jer ecisell eilat', 'neutral'],
#  ['mele Nifeewestshari', 'sad'],
#  ['Tl t Kumar', 'neutral'],
#  ['Be tay llesllaeseriaerch', 'neutral'],
#  ['Shvam Shukis', 'neutral'],
#  ['rrAVsing KLMARI', 'neutral'],
#  ['Pooja Yadav', 'neutral'],
#  ['', 'neutral'],
#  ['Chaudhary Sarita', 'neutral'],
#  ['Neeraj Fels', 'neutral'],
#  ['Manich  alles  am', 'neutral'],
#  ['Sarkar Amar', 'neutral'],
#  ['st Barnabas st Barnabas', 'happy'],
#  ['SHARMA LARSL', 'neutral'],
#  ['o om lalelal AQIKI', 'happy'],
#  ['Nitesh kum', 'happy'],
#  ['Sonu Gupta', 'sad'],
#  ['irao purushottama r', 'angry'],
#  ['', 'neutral'],
#  ['Ruchi Panse', 'happy'],
#  ['et ateistelal reyte kumar th', 'neutral'],
#  ['SHleris Che', 'happy'],
#  ['Garg Thaales ial', 'neutral'],
#  ['', 'sad'],
#  ['Kumawat Kainal', 'sad'],
#  ['Nandani Shz', 'neutral'],
#  ['Sudhnshu Shrivastava', 'neutral'],
#  ['Gite leisitia iva', 'happy'],
#  ['Meena Neetu mey', 'neutral'],
#  ['Shrram Singh', 'neutral'],
#  ['Raja', 'sad'],
#  ['Kumar Soni Seley Aditya', 'sad'],
#  ['Harsh Rai', 'neutral'],
#  ['jel aisell elal', 'neutral'],
#  ['mele Nifeewestshari', 'sad'],
#  ['Tl t Kumar', 'neutral'],
#  ['Amit Kumar', 'neutral'],
#  ['Shyam Shukla  vo', 'neutral'],
#  ['Be tay leslaeseriaeerch', 'neutral'],
#  ['NAVNITA  KIIMARI', 'neutral'],
#  ['Meena Rey Neetu', 'neutral'],
#  ['Amar Sarkan', 'neutral'],
#  ['Pooja Yadav', 'neutral'],
#  ['', 'neutral'],
#  ['Chaudhary Sarita', 'neutral'],
#  ['Neeraj Fels', 'neutral'],
#  ['Manich  alles  am', 'neutral'],
#  ['st Barnabas st Barnabas', 'happy'],
#  ['SHARMA LARSL', 'neutral'],
#  ['o om lalelal AQIKI', 'happy'],
#  ['Sonu Gupta', 'sad'],
#  ['Nitesh kum', 'happy'],
#  ['Ruchi  Panse', 'happy'],
#  ['', 'neutral'],
#  ['et ateistelal reyte kumar th', 'neutral'],
#  ['oetllaltisteiaetiie ns rao', 'angry'],
#  ['Che Sagar', 'happy'],
#  ['Garg Thaales ial', 'neutral'],
#  ['', 'happy'],
#  ['Kumawat Kainal', 'sad'],
#  ['Sudhnshu Shrivastava', 'neutral'],
#  ['Nandsni St hah', 'neutral'],
#  ['Gite leisitia iva', 'happy'],
#  ['Kumar feleya Aditya Teta', 'fear'],
#  ['Shrram Singh', 'neutral'],
#  ['Raja', 'sad'],
#  ['Harsh Rai', 'neutral'],
#  ['Kumar Amit', 'neutral'],
#  ['jel aisell elal', 'neutral'],
#  ['Tl t Kumar', 'neutral'],
#  ['mely   NitstwAfahari', 'sad'],
#  ['Be tay lleslaeseriaerchn', 'neutral'],
#  ['Shvam Shukis', 'neutral'],
#  ['NAVNITA  KIIMARI', 'neutral'],
#  ['Meena Rey Neetu', 'neutral'],
#  ['Amar Sarkan', 'neutral'],
#  ['Pooja Yadav', 'neutral'],
#  ['', 'neutral'],
#  ['Chaudhary Sarita', 'neutral'],
#  ['Neeraj Fels', 'neutral'],
#  ['Manich  alles  am', 'neutral'],
#  ['SHARMA LARSL', 'neutral'],
#  ['st Barnabas st Barnabas', 'happy'],
#  ['otislelal o', 'happy'],
#  ['Sonu Gupta', 'angry'],
#  ['Nitesh kum', 'happy'],
#  ['', 'sad'],
#  ['Ruchi  Panse', 'happy'],
#  ['', 'neutral'],
#  ['kanchan kumar rerte th', 'neutral'],
#  ['oetllaltisteiaetiie ns rao', 'angry'],
#  ['Kumawat Runal', 'sad'],
#  ['Garg Thaales ial', 'neutral'],
#  ['Ve S oe', 'neutral'],
#  ['Sudhnshu Shrivastava', 'neutral'],
#  ['Kumar feleya Aditya Teta', 'fear'],
#  ['ite lelsitia iva', 'happy'],
#  ['Chet Sagar Os', 'happy'],
#  ['Raja', 'sad'],
#  ['Singh Sham', 'neutral'],
#  ['Harsh Rai', 'neutral'],
#  ['jel aisell elal', 'neutral'],
#  ['eslia Kumar', 'neutral'],
#  ['Tl t Kumar', 'neutral'],
#  ['mely   NitstwAfahari', 'sad'],
#  ['Be tay lleslaeseriaerchn', 'neutral'],
#  ['Shvam Shukis', 'neutral'],
#  ['NAVNITA  KIIMARI', 'neutral'],
#  ['Meena Rey Neetu', 'neutral'],
#  ['Amar Sarkan', 'neutral'],
#  ['', 'neutral'],
#  ['Manich  loirmear', 'neutral'],
#  ['Chaudhary Sarita', 'neutral'],
#  ['Neeraj Fels', 'neutral'],
#  ['st Barnabas st Barnabas', 'happy'],
#  ['otislelal o', 'happy'],
#  ['Sonu Gupta', 'angry'],
#  ['HARSH SHARMA', 'neutral'],
#  ['Nitesh kum', 'happy'],
#  ['Pooja Yadav', 'neutral'],
#  ['', 'happy'],
#  ['Shrivaet  SodhSnchu TV', 'neutral'],
#  ['Ruchi Panse', 'happy'],
#  ['', 'neutral'],
#  ['oetllaltisteiaetiie ns rao', 'angry'],
#  ['Kumawat Runal', 'sad'],
#  ['Garg Thaales ial', 'neutral'],
#  ['i eatelst lat rerte kumar th', 'neutral'],
#  ['Ve S oe', 'neutral'],
#  ['Kumar feleya Aditya Teta', 'fear'],
#  ['ite lelsitia iva', 'happy'],
#  ['Chet Sagar Os', 'happy'],
#  ['Raja', 'sad'],
#  ['Singh Sham', 'neutral'],
#  ['Harsh Rai', 'neutral'],
#  ['Tl t Kumar', 'neutral'],
#  ['yYestia Kumar', 'neutral'],
#  ['mely   NitstwAfahari', 'sad'],
#  ['Bel tay sSlieertlc Ser leee ae', 'neutral'],
#  ['NAVNITA  KIIMARI', 'neutral'],
#  ['Amar Sarkan', 'neutral'],
#  ['Shvam Shukis', 'neutral'],
#  ['Manish  loormar', 'neutral'],
#  ['', 'neutral'],
#  ['Nitesh detlestel', 'happy'],
#  ['Neeraj Fels', 'neutral'],
#  ['Chaudhary Sarita', 'neutral'],
#  ['st Barnabas st Barnabas', 'happy'],
#  ['otislelal o', 'happy'],
#  ['be laisall eilait Mehta Mehta', 'neutral'],
#  ['HARSH SHARMA', 'neutral'],
#  ['Ruchi  Panse', 'sad'],
#  ['Pooja Yadav', 'neutral'],
#  ['', 'neutral'],
#  ['Sudhnshu Shrivasteyv', 'neutral'],
#  ['oetllaltisteiaetiie ns rao', 'angry'],
#  ['Kumawat Runal', 'sad'],
#  ['Garg Simran', 'neutral'],
#  ['i eatelst lat rerte kumar th', 'neutral'],
#  ['Ve S oe', 'neutral'],
#  ['Cities  Sagar', 'happy'],
#  ['iMeena   Neetu  Neetu', 'neutral'],
#  ['', 'sad'],
#  ['ite lelsitia iva', 'happy'],
#  ['Kumar Soni Aditya rele', 'fear'],
#  ['Raja', 'sad'],
#  ['Singh Sham', 'neutral'],
#  ['Harsh Rai', 'neutral'],
#  ['tle   Kumar', 'neutral'],
#  ['wy estia Kumar', 'neutral'],
#  ['mely   NitstwAfahari', 'sad'],
#  ['Bel tay stlieertle Ser icee ae', 'neutral'],
#  ['NAVNITA  KIIMARI', 'neutral'],
#  ['Amar Sarkan', 'neutral'],
#  ['Shvam Shukis', 'neutral'],
#  ['Manish  loormar', 'neutral'],
#  ['Nitesh detlestel', 'happy'],
#  ['', 'neutral'],
#  ['Neeraj Fels', 'neutral'],
#  ['Chaudhary Sarita', 'neutral'],
#  ['st Barnabas st Barnabas', 'happy'],
#  ['otislelal o', 'happy'],
#  ['be laisall eilait Mehta Mehta', 'neutral'],
#  ['HARSH SHARMA', 'neutral'],
#  ['Ruchi  Panse', 'sad'],
#  ['Pooja Yadav', 'neutral'],
#  ['', 'neutral'],
#  ['Nandsani S hah', 'neutral'],
#  ['Sudhnshu Shrivastoyv', 'neutral'],
#  ['oetllaltisteiaetiie ns rao', 'angry'],
#  ['Kumawat Runal', 'sad'],
#  ['Garg Simran', 'neutral'],
#  ['ie atelst lat rerte kumar th', 'neutral'],
#  ['i Meena   Neetu  Neetu', 'neutral'],
#  ['', 'happy'],
#  ['ite lelsitia iva', 'happy'],
#  ['Sagar fettie', 'happy'],
#  ['Kumar Soni Aditya rele', 'fear'],
#  ['Sanam  Singh', 'neutral'],
#  ['Raja', 'sad'],
#  ['Harsh Rai', 'neutral'],
#  ['HARSH SHARMA', 'neutral'],
#  ['Ment', 'neutral'],
#  ['tle   Kumar', 'neutral'],
#  ['Shvam Shukis', 'neutral'],
#  ['mely   NitstwAfahari', 'sad'],
#  ['Bel tay sSlieerlcg Ser leee ee', 'neutral'],
#  ['Amit Kumar', 'neutral'],
#  ['NAVNITA  KIIMARI', 'neutral'],
#  ['Manish  loormar', 'neutral'],
#  ['Nitesh detlestel', 'happy'],
#  ['', 'neutral'],
#  ['Pooja Yadav', 'neutral'],
#  ['Neeraj Fels', 'neutral'],
#  ['Chaudhary Sarita', 'neutral'],
#  ['st Barnabas st Barnabas', 'happy'],
#  ['', 'happy'],
#  ['Ruchi  Panse', 'sad'],
#  ['', 'neutral'],
#  ['Sudhnshu Shrivastoyv', 'neutral'],
#  ['oetllaltisteiaetiie ns rao', 'angry'],
#  ['Nanani SI hah', 'neutral'],
#  ['Kumawat Runal', 'sad'],
#  ['elalelal  Ait', 'angry'],
#  ['Sarkan Amar', 'neutral'],
#  ['Garg Simran', 'neutral'],
#  ['ie atelst lat rerte kumar th', 'neutral'],
#  ['i Meena   Neetu  Neetu', 'neutral'],
#  ['Gisele isisitia iva', 'happy'],
#  ['Kumar Soni Aditya rele', 'fear'],
#  ['fCitiest Saaar', 'happy'],
#  ['Sanam   Singh', 'neutral'],
#  ['Raja', 'sad'],
#  ['Harsh Rai', 'neutral'],
#  ['Ment', 'neutral'],
#  ['HARSH CUIAPMA', 'neutral'],
#  ['tle   Kumar', 'neutral'],
#  ['Shvam Shukis', 'neutral'],
#  ['mely   NitstwAfahari', 'sad'],
#  ['bikky maelgeseren Cua', 'neutral'],
#  ['Kumawat Kunal', 'neutral'],
#  ['Amit Kumar', 'neutral'],
#  ['KLMARI NAVNITA', 'neutral'],
#  ['Manish  loormar', 'neutral'],
#  ['Nitesh detlestel', 'happy'],
#  ['Pooja Yadav', 'neutral'],
#  ['Neeraj Fels', 'neutral'],
#  ['Chaudhary Sarita', 'neutral'],
#  ['', 'neutral'],
#  ['st Barnabas st Barnabas', 'happy'],
#  ['Ruchi  Panse', 'sad'],
#  ['', 'neutral'],
#  ['slalelal  may', 'angry'],
#  ['Shrivast Sudhnshu sel', 'neutral'],
#  ['oetllaltisteiaetiie ns rao', 'angry'],
#  ['Nanani SI hah', 'neutral'],
#  ['', 'sad'],
#  ['Sarkan Amar', 'neutral'],
#  ['Garg Simran', 'neutral'],
#  ['ie atelst lat rerte kumar th', 'neutral'],
#  ['i Meena   Neetu  Neetu', 'neutral'],
#  ['Gisele isisitia iva', 'happy'],
#  ['fCitiest Saaar', 'happy'],
#  ['Sanam   Singh', 'neutral'],
#  ['Raja', 'sad'],
#  ['y Velie Kumar feleyl Son', 'fear'],
#  ['Harsh Rai', 'neutral'],
#  ['Ment', 'neutral'],
#  ['Tl t Kumar', 'neutral'],
#  ['Shvam Shukla', 'neutral'],
#  ['mely   NitstwAfahari', 'sad'],
#  ['Amit Kumar', 'neutral'],
#  ['bikky aaelaee lm Cua', 'neutral'],
#  ['Kumawat Kunal', 'neutral'],
#  ['KUMARI NAVNITA', 'neutral'],
#  ['Manish  loormar', 'neutral'],
#  ['Nitesh detlestel', 'happy'],
#  ['Pooja Yadav', 'neutral'],
#  ['Neeraj Fels', 'neutral'],
#  ['', 'neutral'],
#  ['st Barnabas st Barnabas', 'happy'],
#  ['Chaudhary Sarita', 'neutral'],
#  ['Ruchi  Panse', 'sad'],
#  ['HARSH CLIAPMA', 'neutral'],
#  ['', 'neutral'],
#  ['slalelal  may', 'angry'],
#  ['Shrivast Sudhnshu sel', 'neutral'],
#  ['oetllaltisteiaetiie ns rao', 'angry'],
#  ['Nanani SI hah', 'neutral'],
#  ['', 'happy'],
#  ['i eatelst lat rerte kumar th', 'neutral'],
#  ['Sarkan Amar', 'neutral'],
#  ['Garg Simran', 'neutral'],
#  ['BS lers Cue', 'happy'],
#  ['i Meena   Neetu  Neetu', 'neutral'],
#  ['Gisele isisitia iva', 'happy'],
#  ['Sanam   Singh', 'neutral'],
#  ['Sangam ele', 'sad'],
#  ['y Velie Kumar feleyl Son', 'fear'],
#  ['Harsh Rai', 'neutral'],
#  ['Ment', 'neutral'],
#  ['Tl t Kumar', 'neutral'],
#  ['Shvam Shukla', 'neutral'],
#  ['mely   NitstwAfahari', 'sad'],
#  ['Amit Kumar', 'neutral'],
#  ['bikky aaelaee lm cular', 'neutral'],
#  ['rrAVibe KLMARI', 'neutral'],
#  ['Kumawat Kunal', 'neutral'],
#  ['Neeraj Fels', 'neutral'],
#  ['TWIARPCL CLIAPMA', 'neutral'],
#  ['Chaudhary Sarita O', 'neutral'],
#  ['', 'neutral'],
#  ['st Barnabas st Barnabas', 'happy'],
#  ['Nitesh kum', 'happy'],
#  ['Ruchi Panse', 'neutral'],
#  ['', 'happy'],
#  ['Pooja Yadav', 'neutral'],
#  ['', 'neutral'],
#  ['welatelal  may', 'angry'],
#  ['Shrivast Sudhnshu sel', 'neutral'],
#  ['oetllaltisteiaetiie ns rao', 'angry'],
#  ['i eatelst lat rerte kumar th', 'neutral'],
#  ['Sarkan Amar', 'neutral'],
#  ['Garg Simran', 'neutral'],
#  ['Ne ea oe', 'neutral'],
#  ['BSlers Cue', 'happy'],
#  ['i Meena   Neetu  Neetu', 'neutral'],
#  ['eyt', 'neutral'],
#  ['Gisele isisitia iva', 'happy'],
#  ['Sangam ele', 'sad'],
#  ['y Velie Kumar feleyl Son', 'fear'],
#  ['Shivam  Singh', 'neutral'],
#  ['Harsh Rai', 'neutral'],
#  ['Ment', 'neutral'],
#  ['Tl t Kumar', 'neutral'],
#  ['Amit ilar', 'neutral'],
#  ['Shvam his Flare  Yo', 'neutral'],
#  ['mely   NitstwAfahari', 'sad'],
#  ['rrAVibe KLMARI', 'neutral'],
#  ['bikky aaelaee lm cular', 'neutral'],
#  ['Kumawat Kunal', 'neutral'],
#  ['Neeraj Fels', 'neutral'],
#  ['TWIARPCL CLIAPMA', 'neutral'],
#  ['Chaudhary Sarita O', 'neutral'],
#  ['Nitesh kum', 'happy'],
#  ['st Barnabas st Barnabas', 'happy'],
#  ['Ruchi Panse', 'happy'],
#  ['', 'neutral'],
#  ['ela lal   Aki', 'happy'],
#  ['Pooja Yadav', 'neutral'],
#  ['', 'neutral'],
#  ['', 'happy'],
#  ['Shrivast Sudhnshu sel', 'neutral'],
#  ['oetllaltisteiaetiie ns rao', 'angry'],
#  ['i eatelst lat rerte kumar th', 'neutral'],
#  ['Sarkan Amar', 'neutral'],
#  ['Garg Simran', 'neutral'],
#  ['Nanton Sha', 'neutral'],
#  ['BSlers Cue', 'happy'],
#  ['iMeena   Neetu  Neetu', 'neutral'],
#  ['eyt', 'neutral'],
#  ['Gales ielsltia iva', 'happy'],
#  ['Sangam ele', 'sad'],
#  ['y Velie Kumar feleyl Son', 'fear'],
#  ['Shriram   Singh', 'neutral'],
#  ['Harsh Rai', 'neutral'],
#  ['bikkyl jeselecoes', 'neutral'],
#  ['Amit ilar', 'neutral'],
#  ['Shvam Shukla', 'neutral'],
#  ['mely   NifstwAfahari', 'sad'],
#  ['Tatt Kumar O', 'neutral'],
#  ['Mehta jel aisall eilat', 'neutral'],
#  ['Kumawat Kunal', 'neutral'],
#  ['KUMARI NAVNITA', 'neutral'],
#  ['HARSH SHARMA', 'neutral'],
#  ['Malahcincle ase Ss lU', 'neutral'],
#  ['Neeraj Fels', 'neutral'],
#  ['Chaudhary Sarita O', 'neutral'],
#  ['Nitesh kum', 'happy'],
#  ['st Barnabas st Barnabas', 'happy'],
#  ['Ruchi Panse', 'neutral'],
#  ['', 'neutral'],
#  ['ela lal   Aki', 'happy'],
#  ['', 'happy'],
#  ['Pooja Yadav', 'neutral'],
#  ['', 'neutral'],
#  ['oetllaltisteiaetiie ns rao', 'angry'],
#  ['i eatelst lat rerte kumar th', 'neutral'],
#  ['Garg Simran', 'neutral'],
#  ['Amar  Sarkan', 'angry'],
#  ['Nantian Sha', 'neutral'],
#  ['Sagar Cue', 'happy'],
#  ['iMeena   Neetu  Neetu', 'neutral'],
#  ['eyt', 'neutral'],
#  ['Gales ielsltia iva', 'happy'],
#  ['Sangam ele', 'sad'],
#  ['y Velie Kumar feleyl Son', 'fear'],
#  ['Shriram   Singh', 'neutral'],
#  ['Harsh Rai', 'neutral'],
#  ['bikkyl Seselesoe', 'neutral'],
#  ['Amit ilar', 'neutral'],
#  ['Shvam Shukla', 'neutral'],
#  ['mely   NifstwAfahari', 'sad'],
#  ['Tatt Kumar O', 'neutral'],
#  ['Mehta jel aisall eilat', 'neutral'],
#  ['Meena Neetu mey', 'neutral'],
#  ['KUMARI NAVNITA', 'neutral'],
#  ['aseiris Runa', 'neutral'],
#  ['HARSH SHARMA', 'neutral'],
#  ['', 'neutral'],
#  ['Nitesh kum', 'happy'],
#  ['Shrivastava se oS lU', 'neutral'],
#  ['Neeraj Fels', 'neutral'],
#  ['Chaudhary Sarita O', 'neutral'],
#  ['st Barnabas st Barnabas', 'happy'],
#  ['Ruchi Panse', 'happy'],
#  ['Sonu Gupta ey', 'fear'],
#  ['PSingh   Aki', 'happy'],
#  ['Pooja Yadav', 'neutral'],
#  ['', 'neutral'],
#  ['weltatitsleiaeliie hs rao', 'happy'],
#  ['i eatelst lat rerte kumar th', 'neutral'],
#  ['Garg Simran', 'neutral'],
#  ['', 'happy'],
#  ['Amar  Sarkan', 'angry'],
#  ['Nantian Sha', 'neutral'],
#  ['Sagar Cue', 'happy'],
#  ['eyt', 'neutral'],
#  ['Gales ielsltia iva', 'happy'],
#  ['Singh   Shaver', 'neutral'],
#  ['Sangam ele', 'sad'],
#  ['y Velie Kumar feleyl Son', 'fear'],
#  ['Harsh Rai', 'neutral'],
#  ['bikkyl jeselecoe es', 'neutral'],
#  ['Shvam Shukla', 'neutral'],
#  ['mely   NifstwAfahari', 'sad'],
#  ['Tatt Kumar O', 'neutral'],
#  ['Mehta is latsell eiel is latsell eiel', 'neutral'],
#  ['Meena Neetu mey', 'neutral'],
#  ['KUMARI NAVNITA', 'neutral'],
#  ['aseiris Runa', 'neutral'],
#  ['', 'neutral'],
#  ['Nitesh kum', 'happy'],
#  ['Shrivastava se oS lU', 'neutral'],
#  ['Ruchi Panse', 'happy'],
#  ['Neeraj Fels', 'neutral'],
#  ['Chaudhary Sarita O', 'neutral'],
#  ['HARSH CLIADMAA', 'neutral'],
#  ['st Barnabas st Barnabas', 'happy'],
#  ['Manish  loomar', 'neutral'],
#  ['Sonu Gupta ey', 'fear'],
#  ['PSingh   Aki', 'happy'],
#  ['Pooja Yadav', 'neutral'],
#  ['', 'neutral'],
#  ['puruchottama  rao', 'happy'],
#  ['', 'happy'],
#  ['Amit Kumar', 'neutral'],
#  ['Garg Simran', 'neutral'],
#  ['i eatelst lat rerte kumar th', 'neutral'],
#  ['Sarkar Amar', 'neutral'],
#  ['Ve aa', 'neutral'],
#  ['Sagar Che', 'happy'],
#  ['sles ielsltia iva', 'happy'],
#  ['Sangam ele', 'sad'],
#  ['Singh sti iaal', 'neutral'],
#  ['Aditya releya Kumar Son', 'fear'],
#  ['Harsch Rai', 'neutral'],
#  ['bikkyl Seselesoe se', 'neutral'],
#  ['Shvam Shikia  Yr', 'neutral'],
#  ['mely   NifstwAfahari', 'sad'],
#  ['Mehta is latsell eiel is latsell eiel', 'neutral'],
#  ['Tatt Kumar O', 'neutral'],
#  ['late lal o lata', 'angry'],
#  ['Meena Neetu mey', 'neutral'],
#  ['KLMARI NAVNITA', 'neutral'],
#  ['aseiris Runa', 'neutral'],
#  ['', 'neutral'],
#  ['Nitesh kum', 'happy'],
#  ['Ruchi Panse', 'happy'],
#  ['Neeraj Fels', 'neutral'],
#  ['Chaudhary Sarita O', 'neutral'],
#  ['HARSH CLIADMAA', 'neutral'],
#  ['st Barnabas st Barnabas', 'happy'],
#  ['Manish  lomar', 'neutral'],
#  ['Shrivacr SudhSnshu Vel', 'neutral'],
#  ['Sonu Gupta ey', 'fear'],
#  ['Pooja Yadav', 'neutral'],
#  ['', 'neutral'],
#  ['puruchottama  rao', 'happy'],
#  ['Amit Kumar', 'neutral'],
#  ['kanchan', 'neutral'],
#  ['', 'happy'],
#  ['Garg Simran', 'neutral'],
#  ['Nanani SI seial', 'neutral'],
#  ['Sarkar Amar', 'neutral'],
#  ['Sagar Che', 'happy'],
#  ['sles ielsltia iva', 'happy'],
#  ['Sangam ele', 'sad'],
#  ['Singh sti iaal', 'neutral'],
#  ['Aditya releya Kumar Son', 'fear'],
#  ['Harsh Rai', 'neutral'],
#  ['Shvam Shikia  Yr', 'neutral'],
#  ['mely   NifstwAfahari', 'sad'],
#  ['Tatt Kumar O', 'neutral'],
#  ['Mehta be laisall lal be laisall lal', 'neutral'],
#  ['iste lal el abe', 'angry'],
#  ['Meena Neetu  mey', 'neutral'],
#  ['KUMARI NAVNITA', 'neutral'],
#  ['oscil bikkyl Sharh', 'neutral'],
#  ['', 'neutral'],
#  ['Nitesh kum', 'happy'],
#  ['Neeraj Fels', 'neutral'],
#  ['Chaudhary Sarita', 'neutral'],
#  ['HARSH CLIADMAA', 'neutral'],
#  ['', 'happy'],
#  ['st Barnabas st Barnabas', 'happy'],
#  ['Manish  loormar', 'neutral'],
#  ['Sonu Gupta', 'angry'],
#  ['Shrivacr SudhSnshu  TVa', 'neutral'],
#  ['Ruchi Panse', 'sad'],
#  ['Pooja Yadav', 'neutral'],
#  ['', 'neutral'],
#  ['puruchottama  rao', 'happy'],
#  ['Amit Kumar', 'neutral'],
#  ['Mlsrivc ls Raunal', 'neutral'],
#  ['Cities Sagar', 'happy'],
#  ['kanchan', 'neutral'],
#  ['Garg Simran', 'neutral'],
#  ['Nanani SI seial', 'neutral'],
#  ['Sarkar Amar', 'neutral'],
#  ['sles ielsltia iva', 'happy'],
#  ['Singh   Saar', 'neutral'],
#  ['Sangam ele', 'sad'],
#  ['Aditya releya Kumar Son', 'fear'],
#  ['Harsh Rai', 'neutral'],
#  ["HARSH 'CLIADMA", 'neutral'],
#  ['Shvam Shukla', 'neutral'],
#  ['mely   NifstwAfahari', 'sad'],
#  ['Tatt Kumar O', 'neutral'],
#  ['Mehta i latsell clei i latsell clei', 'neutral'],
#  ['u Meena mm ey Neetu', 'neutral'],
#  ['Siatelal el abe', 'angry'],
#  ['KUMARI NAVNITA', 'neutral'],
#  ['iar bikkyl Sharh', 'neutral'],
#  ['', 'neutral'],
#  ['Nitesh kum', 'happy'],
#  ['Neeraj Fels', 'neutral'],
#  ['Gupta Sonu', 'angry'],
#  ['st Barnabas st Barnabas', 'happy'],
#  ['Manish  loormar', 'neutral'],
#  ['Chaudhary Sarita', 'neutral'],
#  ['Shrivacr SudhSnshu  TVa', 'neutral'],
#  ['Mlsrivc ls Raunal', 'neutral'],
#  ['Ruchi  Panse', 'sad'],
#  ['purushottama r rao', 'happy'],
#  ['Amit Kumar', 'neutral'],
#  ['Pooja Yadav', 'neutral'],
#  ['fCitieis Sagar', 'happy'],
#  ['', 'neutral'],
#  ['kanchan', 'neutral'],
#  ['Garg Simran', 'neutral'],
#  ['', 'happy'],
#  ['Nanani SI seial', 'neutral'],
#  ['Sark Amar', 'neutral'],
#  ['sles ielsltia iva', 'happy'],
#  ['Singh   Saar', 'neutral'],
#  ['Sangam ele', 'sad'],
#  ['Aditya releya dase Son', 'fear'],
#  ['Harsh Rai', 'neutral'],
#  ["HARSH 'CLIADMA", 'neutral'],
#  ['Shukla Shvam  Yoo', 'neutral'],
#  ['mel   NifstwAfahari', 'sad'],
#  ['tls   Kumar', 'neutral'],
#  ['Mehta i latsell clei i latsell clei', 'neutral'],
#  ['i Meena mm ey Neetu', 'neutral'],
#  ['Siatelal el abe', 'angry'],
#  ['NAVNITA KLIMARI', 'neutral'],
#  ['iar bikkyl Sharh', 'neutral'],
#  ['', 'neutral'],
#  ['Nitesh kum', 'happy'],
#  ['Neeraj Fels', 'neutral'],
#  ['Chaudhary Sarita', 'neutral'],
#  ['st Barnabas st Barnabas', 'happy'],
#  ['', 'happy'],
#  ['Shrivacr SudhSnshu  TVa', 'neutral'],
#  ['Ruchi  Panse', 'sad'],
#  ['Pooja Yadav', 'neutral'],
#  ['Amit Kumar', 'neutral'],
#  ['Mlsrivc ls Raunal', 'neutral'],
#  ['', 'neutral'],
#  ['Sonu Gupta ey', 'surprise'],
#  ['Sagar Ciiet', 'happy'],
#  ['Garg Simran', 'neutral'],
#  ['Sark Amar', 'neutral'],
#  ['kanchan rerte kumar th', 'neutral'],
#  ['Nandsani St', 'neutral'],
#  ['purushottama  rao', 'angry'],
#  ['rey', 'neutral'],
#  ['sles ielsltia iva', 'happy'],
#  ['Singh   Saar', 'neutral'],
#  ['Sangam ele', 'sad'],
#  ['Kumar Sor Aditya foley', 'fear'],
#  ['Harsh Rai', 'neutral'],
#  ["HARSH 'CLIADMA", 'neutral'],
#  ['Shvam Shukis  Yc', 'neutral'],
#  ['mel   NifstwAfahari', 'sad'],
#  ['tls   Kumar', 'neutral'],
#  ['Mehta i latsell clei i latsell clei', 'neutral'],
#  ['NAVNITA KLIMARI', 'neutral'],
#  ['iar bikkyl Sharh', 'neutral'],
#  ['', 'neutral'],
#  ['Nitesh kum', 'happy'],
#  ['Neeraj Fels', 'neutral'],
#  ['Chaudhary Sarita', 'neutral'],
#  ['st Barnabas st Barnabas', 'happy'],
#  ['', 'happy'],
#  ['Ruchi  Panse', 'sad'],
#  ['Shrivacr SudhSnshu  TVa', 'neutral'],
#  ['Amit i allestle', 'neutral'],
#  ['Pooja Yadav', 'neutral'],
#  ['Mlsrivc ls Raunal', 'neutral'],
#  ['', 'neutral'],
#  ['Sonu Gupta ey', 'surprise'],
#  ['Garg Simran', 'neutral'],
#  ['puruchottama  rao', 'happy'],
#  ['Amar Sarkan', 'neutral'],
#  ['kanchan rerte kumar th', 'neutral'],
#  ['Ne aS', 'neutral'],
#  ['iMveena   Neetu  Neetu', 'neutral'],
#  ['rey', 'neutral'],
#  ['Singh o Skit', 'sad'],
#  ['isle Velaltia riva', 'happy'],
#  ['Sagar Che', 'happy'],
#  ['Singh   Saver', 'neutral'],
#  ['Sangam ele', 'sad'],
#  ['Kumar Sor Aditya foley', 'fear'],
#  ['Harsh Rai', 'neutral'],
#  ['charryma cis bikkyl y Kun', 'neutral'],
#  ['Shvam Shukis', 'neutral'],
#  ['mel   NifstwAfahari', 'sad'],
#  ['tls   Kumar', 'neutral'],
#  ['Mehta i latsell clei i latsell clei', 'neutral'],
#  ['NAVNITA KLIMARI', 'neutral'],
#  ['', 'neutral'],
#  ["HARSH 'CLIADMAA", 'neutral'],
#  ['Nitesh kum', 'happy'],
#  ['Neeraj Fels', 'neutral'],
#  ['Chaudhary Sarita', 'neutral'],
#  ['st Barnabas st Barnabas', 'happy'],
#  ['Pooja Vaday', 'neutral'],
#  ['Ruchi  Panse', 'sad'],
#  ['Shrivacr SudhSnshu  TVa', 'neutral'],
#  ['Amit i ablestle', 'neutral'],
#  ['Mlsrivc ls Raunal', 'neutral'],
#  ['', 'neutral'],
#  ['Garg Simran', 'neutral'],
#  ['', 'happy'],
#  ['Gupta Sonu', 'angry'],
#  ['Amar Sarkan', 'neutral'],
#  ['purushottamar rao', 'happy'],
#  ['kanchan rerte kumar th', 'neutral'],
#  ['Nandsani St', 'neutral'],
#  ['iMvMeena   Neetu  Neetu', 'neutral'],
#  ['Sagar Cities', 'happy'],
#  ['rey', 'neutral'],
#  ['Singh o kit', 'sad'],
#  ['isle Velaltia riva', 'happy'],
#  ['Sangam ele', 'sad'],
#  ['Shawvam  Singh', 'neutral'],
#  ['Aditya foley Kumar Son', 'fear'],
#  ['Harsh Rai', 'neutral'],
#  ['charms bikkyl yar', 'neutral'],
#  ['Shvam Shukla  a', 'neutral'],
#  ['tls   Kumar', 'neutral'],
#  ['mel   NifstwAfahari', 'sad'],
#  ['Mehta elatsallelatt elatsallelatt', 'neutral'],
#  ['NAVNITA KLIMARI', 'neutral'],
#  ['', 'neutral'],
#  ["HARSH 'CLIADMAA", 'neutral'],
#  ['Nitesh kum', 'happy'],
#  ['Boiss ce Birelst le taltl ava', 'neutral'],
#  ['Neeraj Fels', 'neutral'],
#  ['Ruchi Panse', 'happy'],
#  ['Chaudhary Sarita', 'neutral'],
#  ['st Barnabas st Barnabas', 'happy'],
#  ['Pooja Vaday', 'neutral'],
#  ['Amit i ablestle', 'neutral'],
#  ['Gupta Sonu', 'surprise'],
#  ['Mlsrivc ls Raunal', 'neutral'],
#  ['', 'neutral'],
#  ['Garg Simran', 'neutral'],
#  ['', 'happy'],
#  ['kanchan rerte kumar th', 'neutral'],
#  ['Amar Sarkan', 'neutral'],
#  ['eitalisteiaetiiee rao', 'angry'],
#  ['Nandsani St', 'neutral'],
#  ['iMeena   Neetu  Neetu', 'neutral'],
#  ['rey', 'neutral'],
#  ['Singh o Skit', 'sad'],
#  ['isle Velaltia riva', 'happy'],
#  ['ote BSler', 'happy'],
#  ['Sangam ele', 'sad'],
#  ['Shrram Beis', 'neutral'],
#  ['Kumar Sor Aditya foley', 'fear'],
#  ['Harsh Rai', 'neutral'],
#  ['charms bikkyl yar', 'neutral'],
#  ['tls   Kumar', 'neutral'],
#  ['Shvam Shukla  a', 'neutral'],
#  ['mel   NifstwAfahari', 'sad'],
#  ['Mehta iS latsell eile iS latsell eile', 'neutral'],
#  ['Amar Sarkar', 'neutral'],
#  ['', 'neutral'],
#  ['NAVNITA KLIMARI', 'neutral'],
#  ["HARSH 'CLIADMAA", 'neutral'],
#  ['Nitesh kum', 'happy'],
#  ['Boisigi ce BS Trelste le taltl Tava', 'neutral'],
#  ['Neeraj Fels', 'neutral'],
#  ['st Barnabas st Barnabas', 'happy'],
#  ['Chaudhary Sarita', 'neutral'],
#  ['Ruchi  Panse', 'sad'],
#  ['Pooja Vaday', 'neutral'],
#  ['Gupta Sonu', 'surprise'],
#  ['Amit Kumar', 'neutral'],
#  ['Mlsrivc ls Raunal', 'neutral'],
#  ['weltatitsleiaeliie ns rao', 'happy'],
#  ['', 'neutral'],
#  ['Garg Simran', 'neutral'],
#  ['Nanton i SI shah', 'angry'],
#  ['', 'happy'],
#  ['etatelselal kumar certo th', 'neutral'],
#  ['Girls isisitias iva', 'happy'],
#  ['iMeena   Neetu  Neetu', 'neutral'],
#  ['ote BStler', 'happy'],
#  ['Singh o Skit', 'sad'],
#  ['rey', 'neutral'],
#  ['Sangam ele', 'sad'],
#  ['SaArwam   Singh', 'neutral'],
#  ['Kumar Sor Aditya foley', 'fear'],
#  ['Harsh Rai', 'neutral'],
#  ['charms bikkyl moar', 'neutral'],
#  ['Shvam bs Flare', 'neutral'],
#  ['tls   Kumar', 'neutral'],
#  ['mel   NifstwAfahari', 'sad'],
#  ['Amar Sarkar', 'neutral'],
#  ['', 'neutral'],
#  ['NAVNITA KLIMARI', 'neutral'],
#  ['Ment Il aisall lel Il aisall lel', 'neutral'],
#  ["HARSH 'CLIADMAA", 'neutral'],
#  ['Nitesh kum', 'happy'],
#  ['Ruchi Panse', 'sad'],
#  ['Shrivast BS Trelste le taltl Tava', 'neutral'],
#  ['Neeraj Fels', 'neutral'],
#  ['st Barnabas st Barnabas', 'happy'],
#  ['Chaudhary Sarita', 'neutral'],
#  ['o eotistelal Aarkit', 'happy'],
#  ['Pooja Vaday', 'neutral'],
#  ['Kumar Amit', 'neutral'],
#  ['Mlsrivc ls Raunal', 'neutral'],
#  ['', 'neutral'],
#  ['', 'happy'],
#  ...]

# %% [markdown]
# import csv
#
# header = ['Names', 'Emotions']
#
# f = open('tt.csv', 'w')
#
# writer = csv.writer(f)       // create the csv writer
#
# writer.writerow(header)      // write a row to the csv file
#
# f.close                      // close the file

# %%
import pandas as pd

dict = {'name': names, 'emotion': emotions}
df = pd.DataFrame(dict)
	
# saving the dataframe
df.to_csv('names.csv')
# GFG.csv
df
# Out:
#                            name  emotion
# 0     eset iceerl bikkyl leskle  neutral
# 1                 NiteshAfahari      sad
# 2                aseivris eanal      sad
# 3                  HARSH SHARMA  neutral
# 4                    Harsch Rai  neutral
# ...                         ...      ...
# 1007                 Sagar cies    happy
# 1008                        rey  neutral
# 1009                 Sangam ele      sad
# 1010              Shivam  Singh  neutral
# 1011                    i llast     fear
#
# [1012 rows x 2 columns]

# %%
unique_emotions = set(emotions)

# %%
unique_emotions  = list(unique_emotions)
unique_emotions
# Out:
# ['neutral', 'angry', 'happy', 'fear', 'surprise', 'sad']

# %%
count_emotion = []
for i in range(len(unique_emotions)):
  count=0
  for j in range(len(emotions)):
    if unique_emotions[i]==emotions[j]:
      count=count+1
  count_emotion.append(count)

# %%
dict = {'emotion': unique_emotions,'count':count_emotion}	
dfc = pd.DataFrame(dict)
dfc.to_csv('count.csv')
dfc
# Out:
#     emotion  count
# 0   neutral    637
# 1     angry     46
# 2     happy    184
# 3      fear     35
# 4  surprise      4
# 5       sad    106

# %%
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = px.data.tips()
fig = px.pie(dfc, values='count', names='emotion')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c204f862-23bc-403b-bc3b-879f188753ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c204f862-23bc-403b-bc3b-879f188753ce")) {                    Plotly.newPlot(                        "c204f862-23bc-403b-bc3b-879f188753ce",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"emotion=%{label}<br>count=%{value}<extra></extra>","labels":["neutral","angry","happy","fear","surprise","sad"],"legendgroup":"","name":"","showlegend":true,"values":[637,46,184,35,4,106],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"ty ...

# %%
# x-coordinates of left sides of bars 
left = [1, 2, 3, 4, 5]
  
# heights of bars
height = [10, 24, 36, 40, 5]
  
# labels for bars
#tick_label = ['one', 'two', 'three', 'four', 'five']
  
# plotting a bar chart
plt.bar(unique_emotions, count_emotion, 
        width = 0.8)
  
# naming the x-axis
plt.xlabel('x - axis')
# naming the y-axis
plt.ylabel('y - axis')
# plot title
plt.title('Overall Class')
  
# function to show the plot
plt.show()

# %%
unique_names  = list(unique_names)

# %%
count_names = []
for i in range(len(unique_names)):
  count=0
  for j in range(len(names)):
    if unique_names[i]==names[j]:
      count=count+1
  count_names.append(count)

# %%
dict = {'name': unique_names,'count':count_names}	
dfn = pd.DataFrame(dict)
dfn.to_csv('count.csv')
dfn
# Out:
#                               name  count
# 0    Shrivast BStrelst ls alll TVa      1
# 1                                      90
# 2                    BC lee Simran      1
# 3            Shrivast Sudhnshu sel      4
# 4               Gales ielsltia iva      3
# ..                             ...    ...
# 271            i Meena mm ey Neetu      1
# 272                          Ve aa      1
# 273          eltattsseiseliiee rao      1
# 274                   Sagar Cities      1
# 275              Gite lelsitia iva      1
#
# [276 rows x 2 columns]

# %%
files.download('count.csv')

# %%
search_names=[]
for i in range(len(count_names)):
  if count_names[i]>=23 and count_names[i]<=30:
    search_names.append(unique_names[i])

# %%
#search_names.remove('st Barnabas st Barnabas')
search_names.append('Ruchi Panse')

# %%
name_emotion=[]
for i in range(len(search_names)):
  name_s=search_names[i]
  temp=[]
  for j in range(len(names)):
    if(name_s==names[j]):
      temp.append(emotions[j])
  name_emotion.append(temp)

# %%
dict = {'name_search': search_names,'Emotions':name_emotion}	
dfne = pd.DataFrame(dict)
dfne.to_csv('name_emotion.csv')
dfne
# Out:
#                name_search                                           Emotions
# 0                Harsh Rai  [neutral, neutral, neutral, neutral, neutral, ...
# 1              Pooja Yadav  [neutral, neutral, neutral, neutral, neutral, ...
# 2              Neeraj Fels  [neutral, neutral, neutral, neutral, neutral, ...
# 3  st Barnabas st Barnabas  [happy, happy, happy, happy, happy, happy, hap...
# 4               Nitesh kum  [happy, happy, happy, happy, happy, happy, hap...
# 5              Garg Simran  [neutral, neutral, neutral, neutral, neutral, ...
# 6              Ruchi Panse  [happy, happy, happy, happy, happy, happy, hap...

# %%
import matplotlib.pyplot as plt
# surprise 	4
# 1 	fear 	35
# 2 	neutral 	637
# 3 	sad 	106
# 4 	angry 	46
# 5 	happy 	
y_axis=[]
for i in range(len(name_emotion)):
  temp=[]
  for j in range(len(name_emotion[i])):
    if name_emotion[i][j]=='surprise':
      temp.append(0)
    elif name_emotion[i][j]=='fear':
      temp.append(1)
    elif name_emotion[i][j]=='neutral':
      temp.append(2)
    elif name_emotion[i][j]=='sad':
      temp.append(3)
    elif name_emotion[i][j]=='angry':
      temp.append(4)
    elif name_emotion[i][j]=='happy':
      temp.append(5)
  y_axis.append(temp)

# %%
len(y_axis[5])
# Out:
# 25

# %%
import matplotlib.pyplot as plt
for i in range(len(search_names)):
  x = list(range(1, len(y_axis[i])+1))
  # corresponding y axis values
  #y = []
  y=y_axis[i]
  # plotting the points 
    

  plt.plot(x,y)
  # set tick positions, adjust label text
  plt.yticks(y,name_emotion[i])
  plt.xlabel('Frames')
  plt.ylabel('Emotions')
  plt.margins(x=0,y=0.1)

  plt.title(search_names[i])
  plt.show()

# %%
import matplotlib.pyplot as plt
l=0
for i in range(len(search_names)):
  l = l+1
  x = list(range(1, len(y_axis[i])+1))
  # corresponding y axis values
  #y = []
  y=y_axis[i]
  # plotting the points 
  #plt.rcParams["figure.figsize"] = [10.00, 3.50]
  #plt.rcParams["figure.autolayout"] = True

  plt.subplot(4, 2, l)

  # set tick positions, adjust label text
  plt.yticks(y,name_emotion[i])
  plt.xlabel('Frames')
  plt.ylabel('Emotions')
  plt.margins(x=0,y=0.1)

  plt.title(search_names[i])
  plt.plot(x,y)
  plt.subplots_adjust(left=0.2,
                    bottom=0.2, 
                    right=2.0, 
                    top=2.5, 
                    wspace=0.5, 
                    hspace=0.5)
plt.show()
